# %% [markdown]
# <a href="https://colab.research.google.com/github/fabriziobasso/Closet_Index_Tracking/blob/master/S4E5_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regression with an Abalone Dataset
# Playground Series - Season 4, Episode 4
#
#
# ####**Dataset Description**
# The dataset for this competition (both train and test) was generated from a deep learning model trained on the Abalone dataset. Feature distributions are close to, but not exactly the same, as the original. Feel free to use the original dataset as part of this competition, both to explore differences as well as to see whether incorporating the original in training improves model performance.
#
# Files
# **train.csv** - the training dataset; Rings is the integer target
# **test.csv** - the test dataset; your objective is to predict the value of Rings for each row
# **sample_submission.csv** - a sample submission file in the correct format

# %% [markdown]
# #### **The Data**
#
# Here are some further information about the features:
#
# Predicting the age of abalone from physical measurements.  The age of abalone is determined by cutting the shell through the cone, staining it, and counting the number of rings through a microscope -- a boring and time-consuming task.  Other measurements, which are easier to obtain, are used to predict the age.  Further information, such as weather patterns and location (hence food availability) may be required to solve the problem.
#
# From the original data examples with missing values were removed (the majority having the predicted value missing), and the ranges of the continuous values have been scaled for use with an ANN (by dividing by 200).
#
# * Sex / nominal / -- / M, F, and I (infant)
# * Length / continuous / mm / Longest shell measurement
# * Diameter	/ continuous / mm / perpendicular to length
# * Height / continuous / mm / with meat in shell
# * Whole weight / continuous / grams / whole abalone
# * Shucked weight / continuous	 / grams / weight of meat
# * Viscera weight / continuous / grams / gut weight (after bleeding)
# * Shell weight / continuous / grams / after being dried
# * Rings / integer / -- / +1.5 gives the age in years

# %%
# %%capture
run_n = 0
if run_n==0:
  #!pip install tensorflow-addons
  #!pip install shap
  #!pip install eli5
  #!pip install tf-nightly
  #!pip install -U scikit-learn==1.2.0
  # !pip install catboost
  #!pip install haversine
  #!pip install pytorch-forecasting
  #!pip install umap-learn
  #!pip install reverse_geocoder
  #!pip install --upgrade protobuf
  # !pip install colorama
  #!pip install imbalanced-learn
  # !pip install optuna
  # !pip install optuna-integration
  #!pip install pygam
  # !pip install keras-tuner --upgrade
  #!pip install pycaret
  #!pip install lightning==2.0.1
  # !pip install keras-nlp
  #!pip install MiniSom
  # !pip install category_encoders
  # !pip install BorutaShap
  # !pip install feature-engine
  # !pip install scikit-learn==1.4.1
  # !pip install scikit-lego

# %%
#importing modules

import warnings
warnings.filterwarnings('ignore')
import time
t = time.time()

from IPython.display import display_html, clear_output;
clear_output();

print('Importing started...')

# basic moduele
import os
import numpy as np
import pandas as pd
from copy import deepcopy
import re
#from scipy import stats
from random import randint
from prettytable import PrettyTable
import random
import math
import os
import gc
import pickle
from glob import glob
from IPython import display as ipd
from tqdm import tqdm
from datetime import datetime
from joblib import dump, load
import sklearn as sk
#from imblearn.over_sampling import SMOTE, RandomOverSampler
from functools import partial
import itertools
import joblib
from itertools import combinations
import IPython
import statsmodels.api as sm
import IPython.display
#from umap import UMAP

# visualization moduels
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
from matplotlib_venn import venn2_unweighted
import seaborn as sns
import missingno as msno
#import imblearn
import scipy.stats as stats
from scipy.special import boxcox, boxcox1p


# Palette Setup
colors = ['#FB5B68','#FFEB48','#2676A1','#FFBDB0',]
colormap_0 = mpl.colors.LinearSegmentedColormap.from_list("",colors)
palette_1 = sns.color_palette("coolwarm", as_cmap=True)
palette_2 = sns.color_palette("YlOrBr", as_cmap=True)
palette_3 = sns.light_palette("red", as_cmap=True)
palette_4 = sns.color_palette("viridis", as_cmap=True)
palette_5 = sns.color_palette("rocket", as_cmap=True)
palette_6 = sns.color_palette("GnBu", as_cmap=True)
palette_7 = sns.color_palette("tab20c", as_cmap=False)
palette_8 = sns.color_palette("Set2", as_cmap=False)

palette_custom = ['#fbb4ae','#b3cde3','#ccebc5','#decbe4','#fed9a6','#ffffcc','#e5d8bd','#fddaec','#f2f2f2']
palette_9 = sns.color_palette(palette_custom, as_cmap=False)

sns.set_style("whitegrid",{"grid.linestyle":"--", 'grid.linewidth':0.2, 'grid.alpha':0.5})
#sns.set_theme(style="ticks", context="notebook")
sns.despine(left=True, bottom=True, top=False, right=False)

mpl.rcParams['axes.spines.left'] = True
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.bottom'] = True

# Style Import
from colorama import Style, Fore
red = Style.BRIGHT + Fore.RED
blu = Style.BRIGHT + Fore.BLUE
mgt = Style.BRIGHT + Fore.MAGENTA
gld = Style.BRIGHT + Fore.YELLOW
res = Style.RESET_ALL

# preprocessing modules
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, cross_val_score, GroupKFold, GridSearchCV, RepeatedStratifiedKFold

from sklearn.preprocessing import (LabelEncoder,
                                   StandardScaler,
                                   MinMaxScaler,
                                   OrdinalEncoder,
                                   RobustScaler,
                                   PowerTransformer,
                                   OneHotEncoder,
                                   LabelEncoder,
                                   OrdinalEncoder,
                                   QuantileTransformer,
                                   PolynomialFeatures)

from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.compose import ColumnTransformer, make_column_transformer

from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import FunctionTransformer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer


# metrics
from sklearn.metrics import (mean_squared_error,
                             r2_score,
                             mean_absolute_error,
                             mean_absolute_percentage_error,
                             classification_report,
                             confusion_matrix,
                             ConfusionMatrixDisplay,
                             multilabel_confusion_matrix,
                             accuracy_score,
                             roc_auc_score,
                             auc,
                             roc_curve,
                             log_loss,
                             make_scorer)


# modeling algos
from sklearn.linear_model import (LogisticRegression,
                                  Lasso,
                                  ridge_regression,
                                  LinearRegression,
                                  Ridge,
                                  RidgeCV,
                                  ElasticNet,
                                  BayesianRidge,
                                  TweedieRegressor,
                                  ARDRegression,
                                  PoissonRegressor,
                                  GammaRegressor)

from sklearn.neighbors import KNeighborsRegressor

from sklearn.tree import DecisionTreeRegressor
from sklearn.isotonic import IsotonicRegression

from sklearn.ensemble import (AdaBoostRegressor,
                              AdaBoostClassifier,
                              RandomForestRegressor,
                              RandomForestClassifier,
                              VotingRegressor,
                              GradientBoostingRegressor,
                              GradientBoostingClassifier,
                              StackingRegressor,
                              HistGradientBoostingClassifier,
                              HistGradientBoostingRegressor,
                              ExtraTreesClassifier)

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.inspection import permutation_importance
from sklearn.impute import SimpleImputer, KNNImputer

from category_encoders import MEstimateEncoder, CatBoostEncoder, OrdinalEncoder

# Other Models
#from pygam import LogisticGAM, s, te
import xgboost as xgb
from xgboost import XGBRegressor, XGBClassifier
import lightgbm as lgb
from lightgbm import (LGBMRegressor,
                      LGBMClassifier,
                      early_stopping,
                      record_evaluation,
                      log_evaluation)

#import catboost as cat
from catboost import CatBoost, CatBoostRegressor
from catboost import CatBoostClassifier

#from catboost.utils import get_roc_curve

from lightgbm import early_stopping
# check installed version
#import pycaret
warnings.filterwarnings("ignore")
#from minisom import MiniSom

from sklearn.base import clone ## sklearn base models for stacked ensemble model
from sklearn.calibration import CalibratedClassifierCV, CalibrationDisplay

#Interpretiability of the model
#import shap
#import eli5
#from eli5.sklearn import PermutationImportance


## miss
from sklearn.pipeline import (make_pipeline,
                              Pipeline)


import feature_engine as fe
from feature_engine.creation import MathFeatures

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow.keras.backend as K
#import tensorflow_addons as tfa
from keras.utils import FeatureSpace
import keras_nlp

# Import libraries for Hypertuning
import kerastuner as kt
from kerastuner.tuners import RandomSearch, GridSearch, BayesianOptimization
# Model Tuning tools:
import optuna
from optuna.integration import TFKerasPruningCallback
from optuna.trial import TrialState
from optuna.visualization import plot_intermediate_values
from optuna.visualization import plot_optimization_history
from optuna.visualization import plot_param_importances
from optuna.visualization import plot_contour
# Feature selection
from BorutaShap import BorutaShap
# %matplotlib inline
SEED = 1984
N_SPLITS = 10

# Personal Library

print('Done, All the required modules are imported. Time elapsed: {} sec'.format(time.time()-t))
# Out:
# Importing started...
# Done, All the required modules are imported. Time elapsed: 17.47155523300171 sec

# %%
# %%time

# Setting rc parameters in seaborn for plots and graphs-
# Reference - https://matplotlib.org/stable/tutorials/introductory/customizing.html:-
# To alter this, refer to matplotlib.rcParams.keys()

sns.set({"axes.facecolor"       : "#ffffff",
         "figure.facecolor"     : "#ffffff",
         "axes.edgecolor"       : "#000000",
         "grid.color"           : "#ffffff",
         "font.family"          : ['Cambria'],
         "axes.labelcolor"      : "#000000",
         "xtick.color"          : "#000000",
         "ytick.color"          : "#000000",
         "grid.linewidth"       : 0.75,
         "grid.linestyle"       : "--",
         "axes.titlecolor"      : '#0099e6',
         'axes.titlesize'       : 8.5,
         'axes.labelweight'     : "bold",
         'legend.fontsize'      : 7.0,
         'legend.title_fontsize': 7.0,
         'font.size'            : 7.5,
         'xtick.labelsize'      : 7.5,
         'ytick.labelsize'      : 7.5,
        });

# Color printing
def PrintColor(text:str, color = Fore.BLUE, style = Style.BRIGHT):
    "Prints color outputs using colorama using a text F-string";
    print(style + color + text + Style.RESET_ALL);

# Making sklearn pipeline outputs as dataframe:-
pd.set_option('display.max_columns', 100);
pd.set_option('display.max_rows', 50);

sns.set_style("whitegrid",{"grid.linestyle":"--", 'grid.linewidth':0.2, 'grid.alpha':0.5})
#sns.set_theme(style="ticks", context="notebook")
sns.despine(left=True, bottom=True, top=False, right=False)

mpl.rcParams['axes.spines.left'] = True
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.bottom'] = True

print();
gc.collect();
# Out:
# CPU times: user 364 ms, sys: 5.85 ms, total: 370 ms
# Wall time: 807 ms
# 159

# %%
# Check Versions:
print("CHECK VERSIONS:")
print(f"sns: {sns.__version__}")
print(f"mpl: {mpl.__version__}")
print(f"tensorflow: {tf.__version__}")
print(f"pandas: {pd.__version__}")
print(f"numpy: {np.__version__}")
print(f"scikit-learn: {sk.__version__}")
print(f"statsmodels: {sm.__version__}")
print(f"missingno: {msno.__version__}")
#print(f"TF-addon: {tfa.__version__}")
#print(f"Inbalance_Learning: {imblearn.__version__}")
print(f"XGBoost: {xgb.__version__}")
#print(f"CatBoost: {cat.__version__}")
#print(f"PyCaret: {pycaret.__version__}")
# Out:
# CHECK VERSIONS:
# sns: 0.13.1
# mpl: 3.7.1
# tensorflow: 2.16.1
# pandas: 2.2.2
# numpy: 1.25.2
# scikit-learn: 1.4.2
# statsmodels: 0.14.2
# missingno: 0.5.2
# XGBoost: 2.0.3

# %%
print(f"scikit-learn: {sk.__version__}")
# Out:
# scikit-learn: 1.4.2

# %%
# Configuration class:-
class CFG:
    """
    Configuration class for parameters and CV strategy for tuning and training
    Some parameters may be unused here as this is a general configuration class
    """;

    # Data preparation:-
    version_nb         = 4;
    test_req           = "N";
    test_sample_frac   = 0.025;
    gpu_switch         = "OFF";
    state              = 42;
    target             = ["Rings"];
    episode            = 5;
    season             = 4;
    path               = f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S{season}E{episode}_Flood";
    orig_path          = f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S{season}E{episode}_Plates/flood.csv";
    public_subs_path   = None;

    dtl_preproc_req    = "Y";
    adv_cv_req         = "N";
    ftre_plots_req     = 'Y';
    ftre_imp_req       = "Y";

    # Data transforms and scaling:-
    conjoin_orig_data  = "Y";
    drop_nulls         = "N";
    sec_ftre_req       = "Y";
    scale_req          = "N";
    # NOTE---Keep a value here even if scale_req = N, this is used for linear models:-
    scl_method         = "Z";
    enc_method         = 'Label';
    OH_cols            = ["MTRANS"];
    tgt_mapper         = {0 : 0,
                          1 : 1,
                          };

    # Model Training:-
    baseline_req       = "N";
    pstprcs_oof        = "N";
    pstprcs_train      = "N";
    pstprcs_test       = "N";
    ML                 = "Y";

    pseudo_lbl_req     = "N";
    pseudolbl_up       = 0.975;
    pseudolbl_low      = 0.00;

    use_orig_allfolds  = "N";
    n_splits           = 3 if test_req == "Y" else 10;
    n_repeats          = 1 ;
    nbrnd_erly_stp     = 75;
    mdlcv_mthd         = 'RSKF';

    # Ensemble:-
    ensemble_req       = "Y";
    hill_climb_req     = "N";
    optuna_req         = "Y";
    LAD_req            = "N";
    enscv_mthd         = "RSKF";
    metric_obj         = 'maximize';
    ntrials            = 10 if test_req == "Y" else 150;

    # Global variables for plotting:-
    grid_specs = {'visible': True, 'which': 'both', 'linestyle': '--',
                           'color': 'lightgrey', 'linewidth': 0.75};
    title_specs = {'fontsize': 9, 'fontweight': 'bold', 'color': 'tab:blue'};

#print();
PrintColor(f"--> Configuration done!\n");
gc.collect();

CFG.ntrials
# Out:
# --> Configuration done!
# 150

# %% [markdown]
# ### 0.0 Connect Drives:

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %% [markdown]
# Connect to Google Drive:

# %%
# %%capture
# Connect to Colab:
from google.colab import drive
drive.mount('/content/drive')

# %%
folder_script = models_folders = "/content/drive/MyDrive/Exercises/Studies_Structured_Data/Scripts/S4E5_Flood"
os.chdir(folder_script)
import data_analysis as da

da.info_on_functions()

run_graph=1
# Out:
# This tool provides the following functionalities:
#
#  1. connect_drives():
# Reconnect to Google Drives
#
#  2. load_data() and read_data()[Class method]:
# Upload the relevant datasets
# Inputs:
# - train_dataset='train.csv',
# - test_dataset='test.csv',
# - old_dataset=None,
# - exp_name='S4E1_BankChurn',
# - is_csv=True,
# - index_col=0,
# - to_drop=[],
# - submission='sample_submission.csv',
# - base='C:/Users/Fabrizio/Documents/Jupyter Notebook/Kaggle'
# The class also gives access to the following functions:
#  a - check_nana() to verify the presence of NaN,
#  b - summary(self,on='train',cmap='Reds'): Provides basic info on the Dataframe
#  c - adversarial_validation(self,kind='train_test',missing_values=np.nan,strategy_num='median',strategy_obj='most_frequent',drop_features=['Exited']): test the possibility to merge old and new train set
#  d -  merge_trail_old(self): it merges old and new train set
#  e - reduce_mem_usage(self, verbose=True): it changes datatypes to reduce the size of the dataset
#  f - check_duplicates(self): it checks the existence of duplicates between train, test and old training data.
#
#  3. seed_everything(seed,tensorflow_init=True,pytorch_init=True):
# To ensure reproducibility
#
#  4. fill_nan_strategy():
# To fill missing values in the dataset
# Inputs:
#  a - strategy= either 'simple', 'iterative' or 'knn',
#  b - strategy_value='median' it applies to simple strategy,
#  c - random_state=None,
#  d - estimator=None to provide if 'strategy' is iterative and if desired estimator is not ridge,
#  e - max_iter=10 for iterative strategy,
#  f - features='auto' if no imput provide missing values will be filled for numeric features only,
#  g - target='target' defines name of target feature,
#  h - n_neighbors=5 for knn strategy)

# %%
da.seed_everything(seed=42, tensorflow_init=True,pytorch_init=False)

# %% [markdown]
# ### 0.1 Functions:

# %%
def add_features(df_):

  df = df_.copy()
  # Shape_dimension
  df["Area"] = np.log(1/(df["Length"].multiply(df['Diameter']).multiply(df['Diameter'])))

  # Weight_dimension
  df["Total_weight"] = df["Shell weight"]+df["Whole weight.2"]+df["Whole weight.1"]
  df["Total_weight_diff"] = df["Whole weight"].div(df["Total_weight"])
  df["Total_weight_diff"] = np.log(df["Total_weight_diff"]+0.01)
  df["Density"] = np.log(df["Total_weight"].div(df["Area"]*100))
  df["Shell_weight_ratio"] = df["Shell weight"].div(df["Total_weight"])
  df["weight_1_ratio"] = df["Whole weight.1"].div(df["Total_weight"])
  df["weight_2_ratio"] = df["Whole weight.2"].div(df["Total_weight"])

  return df

class add_cluster_features(BaseEstimator, TransformerMixin):

    def __init__(self, num_clusters=8, random_state=None, features=None, target="target", name="x_cluster"):

        self.clustes=num_clusters
        self.random_state = random_state
        self.features = features
        self._name = name
        self.target=target
        self.strategy = KMeans(n_clusters=self.clustes, random_state=self.random_state)

    def fit(self, X, y):
        # only numerical columns:

        temp = X.loc[:, self.features].copy()

        self.strategy.fit(temp)

        return self


    def transform(self, X):
        Xt = X.copy()

        Xt.loc[:, self._name] = self.strategy.predict(Xt.loc[:, self.features])

        return Xt

    def fit_transform(self, X, y):
        Xt = X.copy()
        self.fit(Xt, y)
        return self.transform(Xt)

    def elbow_test(self, X, y, k=(3,12),metric="distortion"):
        Xt = X[self.features].copy()
        model = KMeans()
        visualizer = KElbowVisualizer(self.strategy, k=k,metric=metric)
        visualizer.fit(Xt)        # Fit the data to the visualizer
        visualizer.show()        # Finalize and render the figure

def create_features():

  #df=df_.copy()

  # size Features:
  list_sec = ["Whole weight",	"Whole weight.1",	"Whole weight.2",	"Shell weight","Length",	"Diameter",	"Height"]

  math_func = ["mean", "std", "max", "min"]
  new_names_size = ["mean_size", "std_size", "max_size", "min_size"]

  size_create = MathFeatures(variables = list_sec, func=math_func, new_variables_names=new_names_size)

  new_list_sec = ["Whole weight",	"Whole weight.1",	"Whole weight.2",	"Shell weight","Length",	"Diameter",	"Height"]
  size_clusters = add_cluster_features(num_clusters=7, random_state=42, features=new_list_sec, target="target", name="size_cluster")

  # Create Pipeline:
  pipe = make_pipeline(size_create, size_clusters)

  return pipe

# %% [markdown]
# ## 1.0 Upload Dataset:

# %%
dataset_manager = da.load_data.read_data(to_drop=[],base="/content/drive/MyDrive/Exercises/Studies_Structured_Data/", exp_name="S4E5_Flood", old_dataset="flood.csv")
train_df = dataset_manager.train_dataset
test_df = dataset_manager.test_dataset
old_df = dataset_manager.old

old_df = old_df.reset_index()
dataset_manager.old=old_df
old_df = dataset_manager.old
# Out:
# /content/drive/MyDrive/Exercises/Studies_Structured_Data//Data/S4E5_Flood already exists
# /content/drive/MyDrive/Exercises/Studies_Structured_Data//Data/Models/S4E5_Flood already exists
# /content/drive/MyDrive/Exercises/Studies_Structured_Data//Models/S4E5_Flood/neural_networks/ already exists
# /content/drive/MyDrive/Exercises/Studies_Structured_Data//Script/S4E5_Flood/trees_models/ already exists
#
# Current Directory:/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E5_Flood

# %%
train_df.head(3)
# Out:
#     MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# id
# 0                  5                   8                5              8
# 1                  6                   7                4              4
# 2                  6                   5                6              7
#
#     Urbanization  ClimateChange  DamsQuality  Siltation  \
# id
# 0              6              4            4          3
# 1              8              8            3          5
# 2              3              7            1          5
#
#     AgriculturalPractices  Encroachments  IneffectiveDisasterPreparedness  \
# id
# 0                       3              4                                2
# 1                       4              6                                9
# 2                       4              5                                6
#
#     DrainageSystems  CoastalVulnerability  Landslides  Watersheds  \
# id
# 0                 5                     3           3           5
# 1                 7                     2           0           3
# 2                 7                     3           7           5
#
#     DeterioratingInfrastructure  PopulationScore  WetlandLoss  \
# id
# 0                             4                7            5
# 1                             5                3            3
# 2                             6                8            2
#
#     InadequatePlanning  PoliticalFactors  FloodProbability
# id
# 0                    7                 3             0.445
# 1                    4                 3             0.450
# 2                    3                 3             0.530

# %%
test_df.head(3)
# Out:
#          MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# id
# 1117957                 4                   6                3              5
# 1117958                 4                   4                2              9
# 1117959                 1                   3                6              5
#
#          Urbanization  ClimateChange  DamsQuality  Siltation  \
# id
# 1117957             6              7            8          7
# 1117958             5              5            4          7
# 1117959             7              2            4          6
#
#          AgriculturalPractices  Encroachments  \
# id
# 1117957                      8              4
# 1117958                      5              4
# 1117959                      4              2
#
#          IneffectiveDisasterPreparedness  DrainageSystems  \
# id
# 1117957                                8                5
# 1117958                                2                4
# 1117959                                7                9
#
#          CoastalVulnerability  Landslides  Watersheds  \
# id
# 1117957                     7           5           6
# 1117958                     7           4           5
# 1117959                     2           5           5
#
#          DeterioratingInfrastructure  PopulationScore  WetlandLoss  \
# id
# 1117957                            3                6            4
# 1117958                            1                7            4
# 1117959                            2                3            6
#
#          InadequatePlanning  PoliticalFactors
# id
# 1117957                   4                 5
# 1117958                   4                 3
# 1117959                   8                 3

# %%
old_df.head(3)
# Out:
#    MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                 3                   8                6              6
# 1                 8                   4                5              7
# 2                 3                  10                4              1
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             4              4            6          2                      3
# 1             7              9            1          5                      5
# 2             7              5            4          7                      4
#
#    Encroachments  IneffectiveDisasterPreparedness  DrainageSystems  \
# 0              2                                5               10
# 1              4                                6                9
# 2              9                                2                7
#
#    CoastalVulnerability  Landslides  Watersheds  DeterioratingInfrastructure  \
# 0                     7           4           2                            3
# 1                     2           6           2                            1
# 2                     4           4           8                            6
#
#    PopulationScore  WetlandLoss  InadequatePlanning  PoliticalFactors  \
# 0                4            3                   2                 6
# 1                1            9                   1                 3
# 2                1            8                   3                 6
#
#    FloodProbability
# 0             0.450
# 1             0.475
# 2             0.515

# %% [markdown]
# ### 1.1 Preliminary Analsys:

# %%
dataset_manager.summary()
# Out:
# data shape: (1117957, 21)
# <style type="text/css">
# #T_68c16_row0_col1, #T_68c16_row0_col2, #T_68c16_row0_col3, #T_68c16_row0_col4, #T_68c16_row1_col1, #T_68c16_row1_col2, #T_68c16_row1_col4, #T_68c16_row2_col1, #T_68c16_row2_col2, #T_68c16_row2_col3, #T_68c16_row2_col4, #T_68c16_row3_col1, #T_68c16_row3_col2, #T_68c16_row3_col4, #T_68c16_row4_col1, #T_68c16_row4_col2, #T_68c16_row4_col4, #T_68c16_row5_col1, #T_68c16_row5_col2, #T_68c16_row5_col4, #T_68c16_row6_col1, #T_68c16_row6_col2, #T_68c16_row6_col3, #T_68c16_row6_col4, #T_68c16_row7_col1, #T_68c16_row7_col2, #T_68c16_row7_col3, #T_68c16_row7_col4, #T_68c16_row8_col1, #T_68c16_row8_col2, #T_68c16_row8_col3, #T_68c16_row8_col4, #T_68c16_row9_col1, #T_68c16_row9_col2, #T_68c16_row9_col4, #T_68c16_row10_col1, #T_68c16_row10_col2, #T_68c16_row10_col3, #T_68c16_row10_col4, #T_68c16_row11_col1, #T_68c16_row11_col2, #T_68c16_row11_col4, #T_68c16_row12_col1, #T_68c16_row12_col2, #T_68c16_row12_col4, #T_68c16_row13_col1, #T_68c16_row13_col2, #T_68c16_row13_col3, #T_68c16_row13_col4, #T_68c16_row14_col1, #T_68c16_row14_col2, #T_68c16_row14_col3, #T_68c16_row14_col4, #T_68c16_row15_col1, #T_68c16_row15_col2, #T_68c16_row15_col4, #T_68c16_row16_col1, #T_68c16_row16_col2, #T_68c16_row16_col4, #T_68c16_row17_col1, #T_68c16_row17_col2, #T_68c16_row17_col4, #T_68c16_row18_col1, #T_68c16_row18_col2, #T_68c16_row18_col3, #T_68c16_row18_col4, #T_68c16_row19_col1, #T_68c16_row19_col2, #T_68c16_row19_col3, #T_68c16_row19_col4, #T_68c16_row20_col1, #T_68c16_row20_col2, #T_68c16_row20_col5, #T_68c16_row20_col6, #T_68c16_row20_col7 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_68c16_row0_col5, #T_68c16_row2_col5, #T_68c16_row6_col5, #T_68c16_row7_col5, #T_68c16_row8_col5, #T_68c16_row10_col5, #T_68c16_row13_col5, #T_68c16_row14_col5, #T_68c16_row18_col5, #T_68c16_row19_col5 {
#   background-color: #b11218;
#   color: #f1f1f1;
# }
# #T_68c16_row0_col6, #T_68c16_row1_col6, #T_68c16_row2_col6, #T_68c16_row2_col7, #T_68c16_row3_col6, #T_68c16_row3_col7, #T_68c16_row4_col6, #T_68c16_row4_col7, #T_68c16_row5_col6, #T_68c16_row6_col6, #T_68c16_row6_col7, #T_68c16_row7_col6, #T_68c16_row8_col6, #T_68c16_row8_col7, #T_68c16_row9_col6, #T_68c16_row9_col7, #T_68c16_row10_col6, #T_68c16_row10_col7, #T_68c16_row11_col6, #T_68c16_row11_col7, #T_68c16_row12_col6, #T_68c16_row12_col7, #T_68c16_row13_col6, #T_68c16_row14_col6, #T_68c16_row15_col6, #T_68c16_row16_col6, #T_68c16_row17_col5, #T_68c16_row17_col6, #T_68c16_row17_col7, #T_68c16_row18_col6, #T_68c16_row18_col7, #T_68c16_row19_col6, #T_68c16_row19_col7, #T_68c16_row20_col3, #T_68c16_row20_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_68c16_row0_col7, #T_68c16_row1_col7, #T_68c16_row5_col7, #T_68c16_row7_col7, #T_68c16_row13_col7, #T_68c16_row14_col7, #T_68c16_row15_col7, #T_68c16_row16_col7 {
#   background-color: #69000d;
#   color: #f1f1f1;
# }
# #T_68c16_row1_col3, #T_68c16_row9_col3, #T_68c16_row16_col3 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_68c16_row1_col5, #T_68c16_row9_col5, #T_68c16_row16_col5 {
#   background-color: #820711;
#   color: #f1f1f1;
# }
# #T_68c16_row3_col3, #T_68c16_row4_col3, #T_68c16_row5_col3, #T_68c16_row11_col3, #T_68c16_row12_col3, #T_68c16_row15_col3 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_68c16_row3_col5, #T_68c16_row4_col5, #T_68c16_row5_col5, #T_68c16_row11_col5, #T_68c16_row12_col5, #T_68c16_row15_col5 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
# }
# #T_68c16_row17_col3 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# </style>
# <table id="T_68c16" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68c16_level0_col0" class="col_heading level0 col0" >data type</th>
#       <th id="T_68c16_level0_col1" class="col_heading level0 col1" >#missing</th>
#       <th id="T_68c16_level0_col2" class="col_heading level0 col2" >%missing</th>
#       <th id="T_68c16_level0_col3" class="col_heading level0 col3" >#unique</th>
#       <th id="T_68c16_level0_col4" class="col_heading level0 col4" >min</th>
#       <th id="T_68c16_level0_col5" class="col_heading level0 col5" >max</th>
#       <th id="T_68c16_level0_col6" class="col_heading level0 col6" >median</th>
#       <th id="T_68c16_level0_col7" class="col_heading level0 col7" >mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68c16_level0_row0" class="row_heading level0 row0" >MonsoonIntensity</th>
#       <td id="T_68c16_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_68c16_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_68c16_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_68c16_row0_col3" class="data row0 col3" >17</td>
#       <td id="T_68c16_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_68c16_row0_col5" class="data row0 col5" >16.000000</td>
#       <td id="T_68c16_row0_col6" class="data row0 col6" >5.000000</td>
#       <td id="T_68c16_row0_col7" class="data row0 col7" >4.921450</td>
#     </tr>
#     <tr>
#       <th id="T_68c16_level0_row1" class="row_heading level0 row1" >TopographyDrainage</th>
#       <td id="T_68c16_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_68c16_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_68c16_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_68c16_row1_col3" class="data row1 col3" >19</td>
#       <td id="T_68c16_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_68c16_row1_col5" class="data row1 col5" >18.000000</td>
#       <td id="T_68c16_row1_col6" class="data row1 col6" >5.000000</td>
#       <td id="T_68c16_row1_col7" class="data row1 col7" >4.926671</td>
#     </tr>
#     <tr>
#       <th id="T_68c16_level0_row2" class="row_heading level0 row2" >RiverManagement</th>
#       <td id="T_68c16_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_68c16_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_68c16_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_68c16_row2_col3" class="data row2 col3" >17</td>
#       <td id="T_68c16_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_68c16_row2_col5" class="data row2 col5" >16.000000</td>
#       <td id="T_68c16_row2_col6" class="data row2 col6" >5.000000</td>
#       <td id="T_68c16_row2_col7" class="data row2 col7" >4.955322</td>
#     </tr>
#     <tr>
#       <th id="T_68c16_level0_row3" class="row_heading level0 row3" >Deforestation</th>
#       <td id="T_68c16_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_68c16_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_68c16_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_68c16_row3_col3" class="data row3 col3" >18</td>
#       <td id="T_68c16_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_68c16_row3_col5" class="data row3 col5" >17.000000</td>
#       <td id="T_68c16_row3_col6" class="data row3 col6" >5.000000</td>
#       <td id="T_68c16_row3_col7" class="data row3 col7" >4.942240</td>
#     </tr>
#     <tr>
#       <th id="T_68c16_level0_row4" class="row_heading level0 row4" >Urbanization</th>
#       <td id="T_68c16_row4_col0" class="data row4 col0" >int64</td>
#       <td id="T_68c16_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_68c16_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_68c16_row4_col3" class="data row4 col3" >18</td>
#       <td id="T_68c16_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_68c16_row4_col5" class="data row4 col5" >17.000000</td>
#       <td id="T_68c16_row4_col6" class="data row4 col6" >5.000000</td>
#       <td id="T_68c16_row4_col7" class="data row4 col7" >4.942517</td>
#     </tr>
#     <tr>
#       <th id="T_68c16_level0_row5" class="row_heading level0 row5" >ClimateChange</th>
#       <td id="T_68c16_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_68c16_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_68c16_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_68c16_row5_col3" class="data row5 col3" >18</td>
#       <td id="T_68c16_row5_col4" class="data row5 col4" >0.

# %%
dataset_manager.summary(on="test",cmap="Reds")
# Out:
# data shape: (745305, 20)
# <style type="text/css">
# #T_3a728_row0_col1, #T_3a728_row0_col2, #T_3a728_row0_col3, #T_3a728_row0_col4, #T_3a728_row0_col5, #T_3a728_row0_col6, #T_3a728_row0_col7, #T_3a728_row1_col1, #T_3a728_row1_col2, #T_3a728_row1_col4, #T_3a728_row1_col6, #T_3a728_row2_col1, #T_3a728_row2_col2, #T_3a728_row2_col3, #T_3a728_row2_col4, #T_3a728_row2_col5, #T_3a728_row2_col6, #T_3a728_row3_col1, #T_3a728_row3_col2, #T_3a728_row3_col4, #T_3a728_row3_col6, #T_3a728_row4_col1, #T_3a728_row4_col2, #T_3a728_row4_col4, #T_3a728_row4_col6, #T_3a728_row5_col1, #T_3a728_row5_col2, #T_3a728_row5_col4, #T_3a728_row5_col6, #T_3a728_row6_col1, #T_3a728_row6_col2, #T_3a728_row6_col3, #T_3a728_row6_col4, #T_3a728_row6_col5, #T_3a728_row6_col6, #T_3a728_row7_col1, #T_3a728_row7_col2, #T_3a728_row7_col3, #T_3a728_row7_col4, #T_3a728_row7_col5, #T_3a728_row7_col6, #T_3a728_row8_col1, #T_3a728_row8_col2, #T_3a728_row8_col3, #T_3a728_row8_col4, #T_3a728_row8_col5, #T_3a728_row8_col6, #T_3a728_row9_col1, #T_3a728_row9_col2, #T_3a728_row9_col4, #T_3a728_row9_col6, #T_3a728_row10_col1, #T_3a728_row10_col2, #T_3a728_row10_col3, #T_3a728_row10_col4, #T_3a728_row10_col5, #T_3a728_row10_col6, #T_3a728_row11_col1, #T_3a728_row11_col2, #T_3a728_row11_col4, #T_3a728_row11_col6, #T_3a728_row12_col1, #T_3a728_row12_col2, #T_3a728_row12_col4, #T_3a728_row12_col6, #T_3a728_row13_col1, #T_3a728_row13_col2, #T_3a728_row13_col3, #T_3a728_row13_col4, #T_3a728_row13_col5, #T_3a728_row13_col6, #T_3a728_row14_col1, #T_3a728_row14_col2, #T_3a728_row14_col3, #T_3a728_row14_col4, #T_3a728_row14_col5, #T_3a728_row14_col6, #T_3a728_row15_col1, #T_3a728_row15_col2, #T_3a728_row15_col4, #T_3a728_row15_col6, #T_3a728_row16_col1, #T_3a728_row16_col2, #T_3a728_row16_col4, #T_3a728_row16_col6, #T_3a728_row17_col1, #T_3a728_row17_col2, #T_3a728_row17_col4, #T_3a728_row17_col6, #T_3a728_row18_col1, #T_3a728_row18_col2, #T_3a728_row18_col3, #T_3a728_row18_col4, #T_3a728_row18_col5, #T_3a728_row18_col6, #T_3a728_row19_col1, #T_3a728_row19_col2, #T_3a728_row19_col3, #T_3a728_row19_col4, #T_3a728_row19_col5, #T_3a728_row19_col6 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_3a728_row1_col3, #T_3a728_row3_col3, #T_3a728_row4_col3, #T_3a728_row5_col3, #T_3a728_row9_col3, #T_3a728_row11_col3, #T_3a728_row12_col3, #T_3a728_row15_col3 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_3a728_row1_col5, #T_3a728_row3_col5, #T_3a728_row4_col5, #T_3a728_row5_col5, #T_3a728_row9_col5, #T_3a728_row11_col5, #T_3a728_row12_col5, #T_3a728_row15_col5 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_3a728_row1_col7 {
#   background-color: #fca183;
#   color: #000000;
# }
# #T_3a728_row2_col7, #T_3a728_row16_col3, #T_3a728_row17_col3, #T_3a728_row17_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_3a728_row3_col7 {
#   background-color: #dd2a25;
#   color: #f1f1f1;
# }
# #T_3a728_row4_col7 {
#   background-color: #fa6547;
#   color: #f1f1f1;
# }
# #T_3a728_row5_col7 {
#   background-color: #fc8969;
#   color: #f1f1f1;
# }
# #T_3a728_row6_col7 {
#   background-color: #77040f;
#   color: #f1f1f1;
# }
# #T_3a728_row7_col7, #T_3a728_row13_col7 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_3a728_row8_col7 {
#   background-color: #e22e27;
#   color: #f1f1f1;
# }
# #T_3a728_row9_col7 {
#   background-color: #bf151b;
#   color: #f1f1f1;
# }
# #T_3a728_row10_col7 {
#   background-color: #d42121;
#   color: #f1f1f1;
# }
# #T_3a728_row11_col7, #T_3a728_row19_col7 {
#   background-color: #eb372a;
#   color: #f1f1f1;
# }
# #T_3a728_row12_col7 {
#   background-color: #860811;
#   color: #f1f1f1;
# }
# #T_3a728_row14_col7 {
#   background-color: #fc9d7f;
#   color: #000000;
# }
# #T_3a728_row15_col7 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_3a728_row16_col5 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_3a728_row16_col7 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_3a728_row17_col7 {
#   background-color: #ce1a1e;
#   color: #f1f1f1;
# }
# #T_3a728_row18_col7 {
#   background-color: #f6563d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3a728" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a728_level0_col0" class="col_heading level0 col0" >data type</th>
#       <th id="T_3a728_level0_col1" class="col_heading level0 col1" >#missing</th>
#       <th id="T_3a728_level0_col2" class="col_heading level0 col2" >%missing</th>
#       <th id="T_3a728_level0_col3" class="col_heading level0 col3" >#unique</th>
#       <th id="T_3a728_level0_col4" class="col_heading level0 col4" >min</th>
#       <th id="T_3a728_level0_col5" class="col_heading level0 col5" >max</th>
#       <th id="T_3a728_level0_col6" class="col_heading level0 col6" >median</th>
#       <th id="T_3a728_level0_col7" class="col_heading level0 col7" >mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a728_level0_row0" class="row_heading level0 row0" >MonsoonIntensity</th>
#       <td id="T_3a728_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_3a728_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_3a728_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_3a728_row0_col3" class="data row0 col3" >17</td>
#       <td id="T_3a728_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_3a728_row0_col5" class="data row0 col5" >16.000000</td>
#       <td id="T_3a728_row0_col6" class="data row0 col6" >5.000000</td>
#       <td id="T_3a728_row0_col7" class="data row0 col7" >4.915610</td>
#     </tr>
#     <tr>
#       <th id="T_3a728_level0_row1" class="row_heading level0 row1" >TopographyDrainage</th>
#       <td id="T_3a728_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_3a728_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_3a728_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_3a728_row1_col3" class="data row1 col3" >18</td>
#       <td id="T_3a728_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_3a728_row1_col5" class="data row1 col5" >17.000000</td>
#       <td id="T_3a728_row1_col6" class="data row1 col6" >5.000000</td>
#       <td id="T_3a728_row1_col7" class="data row1 col7" >4.930288</td>
#     </tr>
#     <tr>
#       <th id="T_3a728_level0_row2" class="row_heading level0 row2" >RiverManagement</th>
#       <td id="T_3a728_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_3a728_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_3a728_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_3a728_row2_col3" class="data row2 col3" >17</td>
#       <td id="T_3a728_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_3a728_row2_col5" class="data row2 col5" >16.000000</td>
#       <td id="T_3a728_row2_col6" class="data row2 col6" >5.000000</td>
#       <td id="T_3a728_row2_col7" class="data row2 col7" >4.960027</td>
#     </tr>
#     <tr>
#       <th id="T_3a728_level0_row3" class="row_heading level0 row3" >Deforestation</th>
#       <td id="T_3a728_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_3a728_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_3a728_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_3a728_row3_col3" class="data row3 col3" >18</td>
#       <td id="T_3a728_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_3a728_row3_col5" class="data row3 col5" >17.000000</td>
#       <td id="T_3a728_row3_col6" class="data row3 col6" >5.000000</td>
#       <td id="T_3a728_row3_col7" class="data row3 col7" >4.946084</td>
#     </tr>
#     <tr>
#       <th id="T_3a728_level0_row4" class="row_heading level0 row4" >Urbanization</th>
#       <td id="T_3a728_row4_col0" class="data row4 col0" >int64</td>
#       <td id="T_3a728_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_3a728_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_3a728_row4_col3" class="data row4 col3" >18</td>
#       <td id="T_3a728_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_3a728_row4_col5" class="data row4 col5" >17.000000</td>
#       <td id="T_3a728_row4_col6" class="data row4 col6" >5.000000</td>
#       <td id="T_3a728_row4_col7" class="data row4 c

# %%
dataset_manager.summary(on="old",cmap="Reds")
# Out:
# data shape: (50000, 21)
# <style type="text/css">
# #T_539d7_row0_col1, #T_539d7_row0_col2, #T_539d7_row0_col3, #T_539d7_row0_col4, #T_539d7_row1_col1, #T_539d7_row1_col2, #T_539d7_row1_col4, #T_539d7_row2_col1, #T_539d7_row2_col2, #T_539d7_row2_col3, #T_539d7_row2_col4, #T_539d7_row3_col1, #T_539d7_row3_col2, #T_539d7_row3_col4, #T_539d7_row4_col1, #T_539d7_row4_col2, #T_539d7_row4_col4, #T_539d7_row5_col1, #T_539d7_row5_col2, #T_539d7_row5_col4, #T_539d7_row6_col1, #T_539d7_row6_col2, #T_539d7_row6_col3, #T_539d7_row6_col4, #T_539d7_row7_col1, #T_539d7_row7_col2, #T_539d7_row7_col3, #T_539d7_row7_col4, #T_539d7_row8_col1, #T_539d7_row8_col2, #T_539d7_row8_col3, #T_539d7_row8_col4, #T_539d7_row9_col1, #T_539d7_row9_col2, #T_539d7_row9_col4, #T_539d7_row10_col1, #T_539d7_row10_col2, #T_539d7_row10_col3, #T_539d7_row10_col4, #T_539d7_row11_col1, #T_539d7_row11_col2, #T_539d7_row11_col4, #T_539d7_row12_col1, #T_539d7_row12_col2, #T_539d7_row12_col4, #T_539d7_row13_col1, #T_539d7_row13_col2, #T_539d7_row13_col3, #T_539d7_row13_col4, #T_539d7_row14_col1, #T_539d7_row14_col2, #T_539d7_row14_col3, #T_539d7_row14_col4, #T_539d7_row15_col1, #T_539d7_row15_col2, #T_539d7_row15_col4, #T_539d7_row16_col1, #T_539d7_row16_col2, #T_539d7_row16_col4, #T_539d7_row17_col1, #T_539d7_row17_col2, #T_539d7_row17_col4, #T_539d7_row18_col1, #T_539d7_row18_col2, #T_539d7_row18_col3, #T_539d7_row18_col4, #T_539d7_row19_col1, #T_539d7_row19_col2, #T_539d7_row19_col3, #T_539d7_row19_col4, #T_539d7_row20_col1, #T_539d7_row20_col2, #T_539d7_row20_col5, #T_539d7_row20_col6, #T_539d7_row20_col7 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_539d7_row0_col5, #T_539d7_row2_col5, #T_539d7_row6_col5, #T_539d7_row7_col5, #T_539d7_row8_col5, #T_539d7_row10_col5, #T_539d7_row13_col5, #T_539d7_row14_col5, #T_539d7_row18_col5, #T_539d7_row19_col5 {
#   background-color: #d42121;
#   color: #f1f1f1;
# }
# #T_539d7_row0_col6, #T_539d7_row1_col6, #T_539d7_row2_col6, #T_539d7_row2_col7, #T_539d7_row3_col6, #T_539d7_row3_col7, #T_539d7_row4_col6, #T_539d7_row5_col6, #T_539d7_row6_col6, #T_539d7_row6_col7, #T_539d7_row7_col6, #T_539d7_row8_col6, #T_539d7_row8_col7, #T_539d7_row9_col6, #T_539d7_row9_col7, #T_539d7_row10_col6, #T_539d7_row10_col7, #T_539d7_row11_col6, #T_539d7_row11_col7, #T_539d7_row12_col6, #T_539d7_row12_col7, #T_539d7_row13_col6, #T_539d7_row14_col6, #T_539d7_row15_col6, #T_539d7_row16_col6, #T_539d7_row17_col5, #T_539d7_row17_col6, #T_539d7_row17_col7, #T_539d7_row18_col6, #T_539d7_row19_col6, #T_539d7_row20_col3, #T_539d7_row20_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_539d7_row0_col7, #T_539d7_row1_col7, #T_539d7_row4_col7, #T_539d7_row5_col7, #T_539d7_row7_col7, #T_539d7_row13_col7, #T_539d7_row15_col7, #T_539d7_row16_col7, #T_539d7_row18_col7, #T_539d7_row19_col7 {
#   background-color: #69000d;
#   color: #f1f1f1;
# }
# #T_539d7_row1_col3, #T_539d7_row3_col3, #T_539d7_row4_col3, #T_539d7_row5_col3, #T_539d7_row9_col3, #T_539d7_row11_col3, #T_539d7_row12_col3, #T_539d7_row15_col3, #T_539d7_row16_col3 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_539d7_row1_col5, #T_539d7_row9_col5 {
#   background-color: #b81419;
#   color: #f1f1f1;
# }
# #T_539d7_row3_col5, #T_539d7_row4_col5, #T_539d7_row5_col5, #T_539d7_row11_col5, #T_539d7_row12_col5, #T_539d7_row15_col5 {
#   background-color: #c7171c;
#   color: #f1f1f1;
# }
# #T_539d7_row14_col7 {
#   background-color: #6b010e;
#   color: #f1f1f1;
# }
# #T_539d7_row16_col5 {
#   background-color: #aa1016;
#   color: #f1f1f1;
# }
# #T_539d7_row17_col3 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# </style>
# <table id="T_539d7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_539d7_level0_col0" class="col_heading level0 col0" >data type</th>
#       <th id="T_539d7_level0_col1" class="col_heading level0 col1" >#missing</th>
#       <th id="T_539d7_level0_col2" class="col_heading level0 col2" >%missing</th>
#       <th id="T_539d7_level0_col3" class="col_heading level0 col3" >#unique</th>
#       <th id="T_539d7_level0_col4" class="col_heading level0 col4" >min</th>
#       <th id="T_539d7_level0_col5" class="col_heading level0 col5" >max</th>
#       <th id="T_539d7_level0_col6" class="col_heading level0 col6" >median</th>
#       <th id="T_539d7_level0_col7" class="col_heading level0 col7" >mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_539d7_level0_row0" class="row_heading level0 row0" >MonsoonIntensity</th>
#       <td id="T_539d7_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_539d7_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_539d7_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_539d7_row0_col3" class="data row0 col3" >17</td>
#       <td id="T_539d7_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_539d7_row0_col5" class="data row0 col5" >16.000000</td>
#       <td id="T_539d7_row0_col6" class="data row0 col6" >5.000000</td>
#       <td id="T_539d7_row0_col7" class="data row0 col7" >4.991480</td>
#     </tr>
#     <tr>
#       <th id="T_539d7_level0_row1" class="row_heading level0 row1" >TopographyDrainage</th>
#       <td id="T_539d7_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_539d7_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_539d7_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_539d7_row1_col3" class="data row1 col3" >18</td>
#       <td id="T_539d7_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_539d7_row1_col5" class="data row1 col5" >18.000000</td>
#       <td id="T_539d7_row1_col6" class="data row1 col6" >5.000000</td>
#       <td id="T_539d7_row1_col7" class="data row1 col7" >4.984100</td>
#     </tr>
#     <tr>
#       <th id="T_539d7_level0_row2" class="row_heading level0 row2" >RiverManagement</th>
#       <td id="T_539d7_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_539d7_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_539d7_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_539d7_row2_col3" class="data row2 col3" >17</td>
#       <td id="T_539d7_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_539d7_row2_col5" class="data row2 col5" >16.000000</td>
#       <td id="T_539d7_row2_col6" class="data row2 col6" >5.000000</td>
#       <td id="T_539d7_row2_col7" class="data row2 col7" >5.015940</td>
#     </tr>
#     <tr>
#       <th id="T_539d7_level0_row3" class="row_heading level0 row3" >Deforestation</th>
#       <td id="T_539d7_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_539d7_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_539d7_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_539d7_row3_col3" class="data row3 col3" >18</td>
#       <td id="T_539d7_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_539d7_row3_col5" class="data row3 col5" >17.000000</td>
#       <td id="T_539d7_row3_col6" class="data row3 col6" >5.000000</td>
#       <td id="T_539d7_row3_col7" class="data row3 col7" >5.008480</td>
#     </tr>
#     <tr>
#       <th id="T_539d7_level0_row4" class="row_heading level0 row4" >Urbanization</th>
#       <td id="T_539d7_row4_col0" class="data row4 col0" >int64</td>
#       <td id="T_539d7_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_539d7_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_539d7_row4_col3" class="data row4 col3" >18</td>
#       <td id="T_539d7_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_539d7_row4_col5" class="data row4 col5" >17.000000</td>
#       <td id="T_539d7_row4_col6" class="data row4 col6" >5.000000</td>
#       <td id="T_539d7_row4_col7" class="data row4 col7" >4.989060</td>
#     </tr>
#     <tr>
#       <th id="T_539d7_level0_row5" class="row_heading level0 row5" >ClimateChange</th>
#       <td id="T_539d7_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_539d7_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_539d7_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_539d7_row5_col3" class="data row5 col3" >18</td>
#       <td

# %%
old_df = dataset_manager.old

#old_df.rename(columns={"Whole_weight":"Whole weight","Shucked_weight":"Whole weight.1","Viscera_weight":"Whole weight.2","Shell_weight":"Shell weight"},inplace=True)

#dataset_manager.old = old_df

# %% [markdown]
# ### 1.2 Adversial Validation

# %%
dataset_manager.adversarial_validation(kind='train_old', missing_values=np.nan,strategy_num='median',strategy_obj='most_frequent',drop_features=['FloodProbability'])

# %%
new_train = dataset_manager.merge_train_old()
new_train.shape
# Out:
# (94792, 9)

# %% [markdown]
# ### 1.3 NaN Review:

# %%
dataset_manager.check_nana()
# Out:
# Train Dataset:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Whole weight.1    0
# Whole weight.2    0
# Shell weight      0
# Rings             0
# dtype: int64
#
# Test Dataset:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Whole weight.1    0
# Whole weight.2    0
# Shell weight      0
# dtype: int64
#
# Old Dataset:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Whole weight.1    0
# Whole weight.2    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# ### 1.4 Check for Duplicates

# %%
dataset_manager.define_target(["Rings"])
dataset_manager.check_duplicates();
# Out:
# Identified Duplicates in test data: 215

# %%
test_dup = dataset_manager.duplicates_dataset[1]

# %%
new_train[(new_train.Sex=="F")&(new_train.Length==0.690)&(new_train.Diameter==0.525)&(new_train.Height==0.190)&(new_train["Whole weight"]==1.4920)]
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Whole weight.1  \
# 948     F    0.69     0.525    0.19         1.492          0.6425
# 94130   F    0.69     0.525    0.19         1.492          0.6425
#
#        Whole weight.2  Shell weight  Rings
# 948            0.3905          0.42     11
# 94130          0.3905          0.42     12

# %%
train_dup = dataset_manager.duplicates_dataset[0]

train_dup.plot(kind="scatter",x="Rings",y="Rings_o")
plt.plot(np.linspace(2,30),np.linspace(2,30),c="r");
plt.title("Duplicates Target Analysis", fontsize=15);

# %%
print("Duplicate Incidence: Train Data - {:.4%}, Test Data - {:.4%}".format(len(train_dup)/len(new_train), len(test_dup)/len(test_df)))
# Out:
# Duplicate Incidence: Train Data - 0.3007%, Test Data - 0.3559%

# %% [markdown]
# * **Create Dummy For Duplicate**

# %%
test_dup.isna().sum()
# Out:
# Sex                 0
# Length              0
# Diameter            0
# Height              0
# Whole weight        0
# Whole weight.1      0
# Whole weight.2      0
# Shell weight        0
# Rings             215
# Rings_o             0
# dtype: int64

# %%
new_train["duplicate"] = 0
new_train.loc[train_dup.index,"duplicate"]=train_dup.loc[train_dup.index,"Rings_o"]

# %%
new_train[new_train.duplicate!=0].shape
# Out:
# (285, 10)

# %%
test_df["duplicate"] = 0
test_df.loc[test_dup.index,"duplicate"]=test_dup.loc[test_dup.index,"Rings_o"]
