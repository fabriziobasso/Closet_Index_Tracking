# %% [markdown]
# <a href="https://colab.research.google.com/github/fabriziobasso/Closet_Index_Tracking/blob/master/EDA_V0_(6).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **S4E12 - Insurance Premium Prediction Dataset**
#
# ## Problem Statement
#
# The goal of this dataset is to facilitate the development and testing of regression models for predicting insurance premiums based on various customer characteristics and policy details. Insurance companies often rely on data-driven approaches to estimate premiums, taking into account factors such as age, income, health status, and claim history. This synthetic dataset simulates real-world scenarios to help practitioners practice feature engineering, data cleaning, and model training.
#
# ## Dataset Overview
#
# This dataset contains 2Lk+ and 20 features with a mix of categorical, numerical, and text data. It includes missing values, incorrect data types, and skewed distributions to mimic the complexities faced in real-world datasets. The target variable for prediction is the "Premium Amount".
#
# ### Features
#
# 1. Age: Age of the insured individual (Numerical)
# 2. Gender: Gender of the insured individual (Categorical: Male, Female)
# 3. Annual Income: Annual income of the insured individual (Numerical, skewed)
# 4. Marital Status: Marital status of the insured individual (Categorical: Single, Married, Divorced)
# 5. Number of Dependents: Number of dependents (Numerical, with missing values)
# 6. Education Level: Highest education level attained (Categorical: High School, Bachelor's, Master's, PhD)
# 7. Occupation: Occupation of the insured individual (Categorical: Employed, Self-Employed, Unemployed)
# 8. Health Score: A score representing the health status (Numerical, skewed)
# 9. Location: Type of location (Categorical: Urban, Suburban, Rural)
# 10. Policy Type: Type of insurance policy (Categorical: Basic, Comprehensive, Premium)
# 11. Previous Claims: Number of previous claims made (Numerical, with outliers)
# 12. Vehicle Age: Age of the vehicle insured (Numerical)
# 13. Credit Score: Credit score of the insured individual (Numerical, with missing values)
# 14. Insurance Duration: Duration of the insurance policy (Numerical, in years)
# 15. Premium Amount: Target variable representing the insurance premium amount (Numerical, skewed)
# 16. Policy Start Date: Start date of the insurance policy (Text, improperly formatted)
# 17. Customer Feedback: Short feedback comments from customers (Text)
# 18. Smoking Status: Smoking status of the insured individual (Categorical: Yes, No)
# 19. Exercise Frequency: Frequency of exercise (Categorical: Daily, Weekly, Monthly, Rarely)
# 20. Property Type: Type of property owned (Categorical: House, Apartment, Condo)
#
# # Data Characteristics
#
# - Missing Values: Certain features contain missing values to simulate real-world data collection issues.
# - Incorrect Data Types: Some fields are intentionally set to incorrect data types to practice data cleaning.
# - Skewed Distributions: Numerical features like **Annual Income** and **Premium Amount** have skewed distributions, which can be addressed through transformations.

# %%
# %%capture
# !pip install -qq pytorch_tabnet
# !pip install optuna
# !pip install catboost
# !pip install optuna-integration-pytorch-tabnet

from pytorch_tabnet.tab_model import TabNetRegressor

# !pip install category-encoders
# !pip install optuna-integration

# !pip install keras-tuner --upgrade
# !pip install keras-nlp
# !pip install BorutaShap
# !pip install scikit-lego
# !pip install skops

from pytorch_tabnet.tab_model import TabNetRegressor

# %%
# Setup notebook
from pathlib import Path
import ipywidgets as widgets
import pandas as pd
import numpy as np
from pickle import load, dump
import json
import joblib
#import calplot as cal

# Graphic Libraries:
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.image as mpimg
# Set Style
sns.set_style("whitegrid",{"grid.linestyle":"--", 'grid.linewidth':0.2, 'grid.alpha':0.5});
sns.despine(left=True, bottom=True, top=False, right=False);
mpl.rcParams['figure.dpi'] = 120;
mpl.rc('axes', labelsize=12);
plt.rc('xtick',labelsize=10);
plt.rc('ytick',labelsize=10);

mpl.rcParams['axes.spines.top'] = False;
mpl.rcParams['axes.spines.right'] = False;
mpl.rcParams['axes.spines.left'] = True;

# Palette Setup
colors = ['#FB5B68','#FFEB48','#2676A1','#FFBDB0',]
colormap_0 = mpl.colors.LinearSegmentedColormap.from_list("",colors)
palette_1 = sns.color_palette("coolwarm", as_cmap=True)
palette_2 = sns.color_palette("YlOrBr", as_cmap=True)
palette_3 = sns.light_palette("red", as_cmap=True)
palette_4 = sns.color_palette("viridis", as_cmap=True)
palette_5 = sns.color_palette("rocket", as_cmap=True)
palette_6 = sns.color_palette("GnBu", as_cmap=True)
palette_7 = sns.color_palette("tab20c", as_cmap=False)
palette_8 = sns.color_palette("Set2", as_cmap=False)

palette_custom = ['#fbb4ae','#b3cde3','#ccebc5','#decbe4','#fed9a6','#ffffcc','#e5d8bd','#fddaec','#f2f2f2']
palette_9 = sns.color_palette(palette_custom, as_cmap=False)

# tool for Excel:
from openpyxl import load_workbook, Workbook
from openpyxl.drawing.image import Image
from openpyxl.styles import Border, Side, PatternFill, Font, GradientFill, Alignment
from openpyxl.worksheet.cell_range import CellRange

from openpyxl.formatting import Rule
from openpyxl.styles import Font, PatternFill, Border
from openpyxl.styles.differential import DifferentialStyle

# Bloomberg
#from xbbg import blp
from catboost import CatBoostRegressor, Pool, CatBoostClassifier
import xgboost as xgb
from xgboost import XGBRegressor, XGBClassifier
from xgboost.callback import EarlyStopping

import lightgbm as lgb
from lightgbm import (LGBMRegressor,
                      LGBMClassifier,
                      early_stopping,
                      record_evaluation,
                      log_evaluation)

# Time Management
from tqdm import tqdm
from datetime import date
from datetime import datetime
from pandas.tseries.offsets import BMonthEnd, QuarterEnd
import datetime
from pandas.tseries.offsets import BDay # BDay is business day, not birthday...
import datetime as dt
import click
import glob
import os
import gc
import re
import string

from ipywidgets import AppLayout
from ipywidgets import Dropdown, Layout, HTML, AppLayout, VBox, Label, HBox, BoundedFloatText, interact, Output

#from my_func import *

import optuna
from optuna.integration import TFKerasPruningCallback
from optuna.trial import TrialState
from optuna.visualization import plot_intermediate_values
from optuna.visualization import plot_optimization_history
from optuna.visualization import plot_param_importances
from optuna.visualization import plot_contour

os.environ["KERAS_BACKEND"] = "tensorflow"

import numpy as np
import tensorflow as tf
import keras
from keras import ops
from keras import layers

from keras.layers import Input, LSTM, Dense, Lambda, RepeatVector, Reshape
from keras.models import Model
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError

from keras.utils import FeatureSpace, plot_model

# Import libraries for Hypertuning
import kerastuner as kt
from kerastuner.tuners import RandomSearch, GridSearch, BayesianOptimization

#from my_func import *

# preprocessing modules
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, cross_val_score, cross_validate, GroupKFold, GridSearchCV, RepeatedStratifiedKFold, cross_val_predict

from sklearn.preprocessing import (LabelEncoder,
                                   StandardScaler,
                                   MinMaxScaler,
                                   OrdinalEncoder,
                                   RobustScaler,
                                   PowerTransformer,
                                   OneHotEncoder,
                                   QuantileTransformer,
                                   PolynomialFeatures)

# metrics
import sklearn
import skops.io as sio
from sklearn.metrics import (mean_squared_error,
                             root_mean_squared_error,
                             root_mean_squared_log_error,
                             r2_score,
                             mean_absolute_error,
                             mean_absolute_percentage_error,
                             classification_report,
                             confusion_matrix,
                             ConfusionMatrixDisplay,
                             multilabel_confusion_matrix,
                             accuracy_score,
                             roc_auc_score,
                             auc,
                             roc_curve,
                             log_loss,
                             make_scorer)
# modeling algos
from sklearn.linear_model import (LogisticRegression,
                                  Lasso,
                                  ridge_regression,
                                  LinearRegression,
                                  Ridge,
                                  RidgeCV,
                                  ElasticNet,
                                  BayesianRidge,
                                  HuberRegressor,
                                  TweedieRegressor,
                                  QuantileRegressor,
                                  ARDRegression,
                                  TheilSenRegressor,
                                  PoissonRegressor,
                                  GammaRegressor)

from sklearn.ensemble import (AdaBoostRegressor,
                              AdaBoostClassifier,
                              RandomForestRegressor,
                              RandomForestClassifier,
                              VotingRegressor,
                              GradientBoostingRegressor,
                              GradientBoostingClassifier,
                              StackingRegressor,
                              StackingClassifier,
                              HistGradientBoostingClassifier,
                              HistGradientBoostingRegressor,
                              ExtraTreesClassifier)

from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import FunctionTransformer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
# %matplotlib inline

from sklearn.linear_model import LinearRegression
import numpy as np
import seaborn as sns
from statsmodels.tsa.deterministic import CalendarFourier, DeterministicProcess

from sklearn.multioutput import RegressorChain
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBRegressor

import itertools
import warnings
from openpyxl import load_workbook

from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor

import statsmodels.api as sm
from pylab import rcParams
import scipy.stats as ss

warnings.filterwarnings('ignore')
#plt.style.use('fivethirtyeight')

# %%
sns.set({"axes.facecolor"       : "#ffffff",
         "figure.facecolor"     : "#ffffff",
         "axes.edgecolor"       : "#000000",
         "grid.color"           : "#ffffff",
         "font.family"          : ['Cambria'],
         "axes.labelcolor"      : "#000000",
         "xtick.color"          : "#000000",
         "ytick.color"          : "#000000",
         "grid.linewidth"       : 0.5,
         'grid.alpha'           :0.5,
         "grid.linestyle"       : "--",
         "axes.titlecolor"      : 'black',
         'axes.titlesize'       : 12,
         'axes.labelweight'     : "bold",
         'legend.fontsize'      : 7.0,
         'legend.title_fontsize': 7.0,
         'font.size'            : 7.5,
         'xtick.labelsize'      : 7.5,
         'ytick.labelsize'      : 7.5,
        });

sns.set_style("whitegrid",{"grid.linestyle":"--", 'grid.linewidth':0.2, 'grid.alpha':0.5})
# Set Style
mpl.rcParams['figure.dpi'] = 120;

# Making sklearn pipeline outputs as dataframe:-
pd.set_option('display.max_columns', 100);
pd.set_option('display.max_rows', 50);

sns.despine(left=True, bottom=True, top=False, right=False)

mpl.rcParams['axes.spines.left'] = True
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.bottom'] = True

# %%
from tqdm import tqdm
from itertools import product

import numpy as np
import pandas as pd
import gc
import matplotlib.pyplot as plt
import seaborn as sns

from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor

from sklearn.model_selection import GroupKFold
from sklearn.impute import SimpleImputer
import torch

import warnings
warnings.filterwarnings("ignore")

# Connect to Colab:#
from google.colab import drive
import os
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <div style="text-align:center; border-radius:15px; padding:15px; margin:0; font-size:100%; font-family:Arial, sans-serif; background-color:#A8DADC; color:#1D3557; overflow:hidden; box-shadow:0 3px 6px rgba(0, 0, 0, 0.2);">
#     <h3>Loading and Preprocessing Data for Compatibility</h3>
# </div>

# %%
df_train = pd.read_csv(
    '/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/train.csv',
     index_col='id',
     parse_dates=['Policy Start Date'],
)

df_test = pd.read_csv(
    '/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/test.csv',
     index_col='id',
     parse_dates=['Policy Start Date'],
)

df_subm = pd.read_csv(
    "/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/sample_submission.csv",
     index_col='id',
)

df_orig = pd.read_csv(
    "/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/Insurance Premium Prediction Dataset.csv",
     parse_dates=['Policy Start Date'],
    #     index_col='id',
)

# %%
df_train.shape, df_test.shape, df_subm.shape, df_orig.shape, df_orig.shape
# Out:
# ((1200000, 20), (800000, 19), (800000, 1), (278860, 20), (278860, 20))

# %%
print("Pytorch Version: {}".format(torch.__version__))
print("SKLearn Version: {}".format(sklearn.__version__))
# Out:
# Pytorch Version: 2.5.1+cu121
# SKLearn Version: 1.5.2

# %%
100*df_train.isnull().sum()/df_train.shape[0]
# Out:
# Age                      1.558750
# Gender                   0.000000
# Annual Income            3.745750
# Marital Status           1.544083
# Number of Dependents     9.139333
# Education Level          0.000000
# Occupation              29.839583
# Health Score             6.173000
# Location                 0.000000
# Policy Type              0.000000
# Previous Claims         30.335750
# Vehicle Age              0.000500
# Credit Score            11.490167
# Insurance Duration       0.000083
# Policy Start Date        0.000000
# Customer Feedback        6.485333
# Smoking Status           0.000000
# Exercise Frequency       0.000000
# Property Type            0.000000
# Premium Amount           0.000000
# dtype: float64

# %%
100*df_train.isnull().sum()/df_train.shape[0]
# Out:
# Age                      1.558750
# Gender                   0.000000
# Annual Income            3.745750
# Marital Status           1.544083
# Number of Dependents     9.139333
# Education Level          0.000000
# Occupation              29.839583
# Health Score             6.173000
# Location                 0.000000
# Policy Type              0.000000
# Previous Claims         30.335750
# Vehicle Age              0.000500
# Credit Score            11.490167
# Insurance Duration       0.000083
# Policy Start Date        0.000000
# Customer Feedback        6.485333
# Smoking Status           0.000000
# Exercise Frequency       0.000000
# Property Type            0.000000
# Premium Amount           0.000000
# dtype: float64

# %%
categorical_cols = ['Gender', 'Marital Status', 'Education Level', 'Occupation', 'Location', 'Policy Type', 'Customer Feedback', 'Smoking Status', 'Exercise Frequency', 'Property Type']
numerical_cols = ['Age', 'Annual Income', 'Health Score', 'Number of Dependents', 'Vehicle Age', 'Credit Score', 'Insurance Duration', 'Previous Claims']
time_cols = ['Policy Start Date']
target = ['Premium Amount']

len(categorical_cols+numerical_cols+target+time_cols),len(df_train.columns)
# Out:
# (20, 20)

# %% [markdown]
# ## BASELINE MODELS:

# %%
#df_train.info()

# %%
df = pd.concat([df_train, df_test], axis=0)

# Convert `Policy Start Date` column to datetime64 format
df['Policy Start Date'] = pd.to_datetime(df['Policy Start Date'])

# Calculate the difference in days between today and the `Policy Start Date` column
today = pd.to_datetime('today')
difference_in_days = today - df['Policy Start Date']

# Divide the difference in days by 365 to get the difference in years
difference_in_years = difference_in_days / pd.Timedelta(days=365)

# Convert the `Policy Start Date` column to the number of years since the policy start date
df['Policy Start Date'] = difference_in_years

numerical_cols = numerical_cols+time_cols

# %%
df_train = df.iloc[:df_train.shape[0], :]
df_test = df.iloc[df_train.shape[0]:, :]

df_train.shape, df_test.shape
# Out:
# ((1200000, 20), (800000, 20))

# %%
df_train.head(3)
# Out:
#      Age  Gender  Annual Income Marital Status  Number of Dependents  \
# id
# 0   19.0  Female        10049.0        Married                   1.0
# 1   39.0  Female        31678.0       Divorced                   3.0
# 2   23.0    Male        25602.0       Divorced                   3.0
#
#    Education Level     Occupation  Health Score  Location    Policy Type  \
# id
# 0       Bachelor's  Self-Employed     22.598761     Urban        Premium
# 1         Master's            NaN     15.569731     Rural  Comprehensive
# 2      High School  Self-Employed     47.177549  Suburban        Premium
#
#     Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# id
# 0               2.0         17.0         372.0                 5.0
# 1               1.0         12.0         694.0                 2.0
# 2               1.0         14.0           NaN                 3.0
#
#     Policy Start Date Customer Feedback Smoking Status Exercise Frequency  \
# id
# 0            0.962289              Poor             No             Weekly
# 1            1.493795           Average            Yes            Monthly
# 2            1.192426              Good            Yes             Weekly
#
#    Property Type  Premium Amount
# id
# 0          House          2869.0
# 1          House          1483.0
# 2          House           567.0

# %%
# Imputers for missing values
categorical_imputer = SimpleImputer(strategy='most_frequent')
numerical_imputer = SimpleImputer(strategy='median')

# Encoder for categorical features
encoder = OrdinalEncoder()

# ColumnTransformer for imputing missing values
imputer = ColumnTransformer(
    transformers=[
        ('categorical', categorical_imputer, categorical_cols),
        ('numerical', numerical_imputer, numerical_cols)
                  ],remainder='passthrough')

# Pipeline
pipeline = Pipeline([
    ('imputer', imputer)
])

# %%
train_df = pd.DataFrame(data=pipeline.fit_transform(df_train), columns=categorical_cols+numerical_cols+target)
test_df = pd.DataFrame(data=pipeline.transform(df_test), columns=categorical_cols+numerical_cols+target)

train_df[numerical_cols+target] = train_df[numerical_cols+target].astype(float)
test_df[numerical_cols+target] = test_df[numerical_cols+target].astype(float)

# %%
#train_df.isnull().sum()/train_df.shape[0]
gc.collect()
# Out:
# 243

# %%
#test_df.isnull().sum()/test_df.shape[0]

# %%
# Initialize a dictionary to keep track of label encoders
label_encoders = {}

# Loop through each categorical column and label encode
for col in categorical_cols:
    le = LabelEncoder()
    # Combine data to fit on both train and test to handle unseen categories
    combined_data = pd.concat([train_df[[col]], test_df[[col]]], axis=0)
    le.fit(combined_data)
    train_df[col] = le.transform(train_df[[col]])
    test_df[col] = le.transform(test_df[[col]])
    label_encoders[col] = le  # Save the encoder for future use if needed

# %%
train_df.head()
# Out:
#    Gender  Marital Status  Education Level  Occupation  Location  Policy Type  \
# 0       0               1                0           1         2            2
# 1       0               0                2           0         0            1
# 2       1               0                1           1         1            2
# 3       1               1                0           0         0            0
# 4       1               2                0           1         0            2
#
#    Customer Feedback  Smoking Status  Exercise Frequency  Property Type   Age  \
# 0                  2               0                   3              2  19.0
# 1                  0               1                   1              2  39.0
# 2                  1               1                   3              2  23.0
# 3                  2               1                   0              0  21.0
# 4                  2               1                   3              2  21.0
#
#    Annual Income  Health Score  Number of Dependents  Vehicle Age  \
# 0        10049.0     22.598761                   1.0         17.0
# 1        31678.0     15.569731                   3.0         12.0
# 2        25602.0     47.177549                   3.0         14.0
# 3       141855.0     10.938144                   2.0          0.0
# 4        39651.0     20.376094                   1.0          8.0
#
#    Credit Score  Insurance Duration  Previous Claims  Policy Start Date  \
# 0         372.0                 5.0              2.0           0.962289
# 1         694.0                 2.0              1.0           1.493795
# 2         595.0                 3.0              1.0           1.192426
# 3         367.0                 1.0              1.0           0.491056
# 4         598.0                 4.0              0.0           3.022563
#
#    Premium Amount
# 0          2869.0
# 1          1483.0
# 2           567.0
# 3           765.0
# 4          2022.0

# %%
#print(train_df.head().to_markdown(index=False, numalign="left", stralign="left"))
df_subm.head()
# Out:
#          Premium Amount
# id
# 1200000        1102.545
# 1200001        1102.545
# 1200002        1102.545
# 1200003        1102.545
# 1200004        1102.545

# %% [markdown]
# ### **1.0 Stacked Model**

# %%
# Define a common random seed for reproducibility
RANDOM_SEED = 42
N_ESTIMATORS = 3000  # Number of estimators for the ensemble models

X = train_df.drop(columns="Premium Amount").copy()
y = np.log(train_df["Premium Amount"].copy())

X_test = test_df.drop(columns="Premium Amount").copy()
X_test = X_test.values

df_subm_stack = df_subm.copy()

cv = KFold(5, shuffle=True, random_state=RANDOM_SEED)
rmsle = []

# Initialize the Stack
df_subm_stack['Premium Amount'] = 0.0

i=0

oof_results_stack = pd.DataFrame(columns=list(range(5)), index=X.index)

for idx_train, idx_valid in cv.split(X, y):

    print(f"Fold {i}")

    # Split the data into training and validation sets for the current fold
    X_train, y_train = X.iloc[idx_train].to_numpy(), y.iloc[idx_train].to_numpy()
    X_valid, y_valid = X.iloc[idx_valid].to_numpy(), y.iloc[idx_valid].to_numpy()

    # Define base estimators with random seed and number of estimators
    estimators = [
        ('lgbm', LGBMRegressor(random_state=RANDOM_SEED, n_estimators=N_ESTIMATORS,subsample=0.9, colsample_bytree=0.95, learning_rate=0.015)),
        ('xgb', XGBRegressor(random_state=RANDOM_SEED, n_estimators=N_ESTIMATORS, colsample_bytree = 0.95, subsample= 0.90, learning_rate=0.015)),
        ('catboost', CatBoostRegressor(random_seed=RANDOM_SEED, iterations=N_ESTIMATORS, subsample=0.9, learning_rate=0.015))
    ]

    meta_model = Ridge(alpha=0.1, positive=True)

    # Create StackingRegressor
    stacking_model = StackingRegressor(estimators=estimators, final_estimator=meta_model)
    if i >= 5:
        #print(stacking_model.get_params())
        # Fit the StackingRegressor
        stacking_model.fit(X_train, y_train)
        obj = sio.dump(stacking_model, f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/staked_base_{i}.skops")

    else:
        unknown_types = sio.get_untrusted_types(file=f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/staked_base_{i}.skops")
        stacking_model = sio.load(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/staked_base_{i}.skops", trusted=unknown_types)


    stack_preds = np.exp(stacking_model.predict(X_valid))

    oof_results_stack.iloc[idx_valid,i] = stack_preds.flatten()
    # Prepare the test data and make predictions
    error = root_mean_squared_log_error(np.exp(y_valid), stack_preds)

    rmsle.append(error)
    print(f"RMSLE fold {i}: {error}")

    # Aggregate the predictions across the 5 folds (averaging for ensemble)
    df_subm_stack['Premium Amount'] += np.exp(stacking_model.predict(X_test)) / 5
    i += 1
# Out:
# Fold 0
# RMSLE fold 0: 1.052410941872681
# Fold 1
# RMSLE fold 1: 1.0511305904924753
# Fold 2
# RMSLE fold 2: 1.0517762581133
# Fold 3
# RMSLE fold 3: 1.0499723732074164
# Fold 4
# RMSLE fold 4: 1.051855551705375

# %%
np.mean(rmsle), np.std(rmsle)
# Out:
# (1.0514291430782496, 0.0008339729181012842)

# %%
oof_results_stack["average"] = oof_results_stack.mean(axis=1)
oof_results_stack["average"].min(),oof_results_stack["average"].max()
# Out:
# (131.9267142545023, 1683.316885579223)

# %%
plt.hist(oof_results_stack["average"], bins=100, alpha=0.5)
plt.hist(train_df["Premium Amount"], bins=100, color="salmon", alpha=0.5)
plt.xlabel("Premium Amount")
plt.ylabel("Frequency")
plt.title("Distribution of Predicted Premium Amounts")
plt.show()

# %%
train_df["Premium Amount"].min(),train_df["Premium Amount"].max(),train_df["Premium Amount"].mean(),train_df["Premium Amount"].median()
# Out:
# (20.0, 4999.0, 1102.5448216666666, 872.0)

# %% [markdown]
# ##### Save Results:

# %%
df_subm_stack.head()
# Out:
#          Premium Amount
# id
# 1200000      660.936255
# 1200001      808.389610
# 1200002      798.937480
# 1200003      800.620026
# 1200004      753.849486

# %%
#df_subm_stack.to_csv('/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/Submissions/submission_stack_baseline.csv')

# %%
#oof_results_stack["average"] = oof_results_stack.mean(axis=1)
oof_results_stack.head()
# Out:
#            0            1    2           3    4      average
# 0        NaN  1005.345352  NaN         NaN  NaN  1005.345352
# 1        NaN   739.732049  NaN         NaN  NaN   739.732049
# 2  822.09531          NaN  NaN         NaN  NaN    822.09531
# 3        NaN    768.72906  NaN         NaN  NaN    768.72906
# 4        NaN          NaN  NaN  776.124028  NaN   776.124028

# %%
oof_results_stack.isna().sum()
# Out:
# 0          960000
# 1          960000
# 2          960000
# 3          960000
# 4          960000
# average         0
# dtype: int64

# %%
train_results_df_ = oof_results_stack["average"].astype("float").copy()
train_results_df_.columns = ["stack_baseline"]
#train_results_df_.to_csv(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/Submissions/train_stack_baseline.csv")

# %% [markdown]
# ### **2.0 TabNet Regressor**

# %% [markdown]
# ##### **Grouped Features**
# It is possible to specify attention groups (using grouped_features). Attention is done at the group level and not feature level. This is especially useful if a dataset has a lot of columns coming from on single source of data

# %%
train_df.columns
# Out:
# Index(['Gender', 'Marital Status', 'Education Level', 'Occupation', 'Location',
#        'Policy Type', 'Customer Feedback', 'Smoking Status',
#        'Exercise Frequency', 'Property Type', 'Age', 'Annual Income',
#        'Health Score', 'Number of Dependents', 'Vehicle Age', 'Credit Score',
#        'Insurance Duration', 'Previous Claims', 'Policy Start Date',
#        'Premium Amount'],
#       dtype='object')

# %%
grouped_features = []
feature_cols = train_df.columns.to_list()
target_col = 'Premium Amount'
feature_cols.remove(target_col)

group_person = ['Age', 'Gender', 'Marital Status', 'Education Level', 'Health Score', 'Smoking Status', 'Exercise Frequency']
group_income = ['Annual Income', 'Number of Dependents', 'Occupation', 'Credit Score', 'Property Type', 'Location']
group_policy = ['Policy Type', 'Previous Claims', 'Vehicle Age', 'Insurance Duration', 'Policy Start Date', 'Customer Feedback']

# Iterate through each set of related columns (e.g., blood glucose, insulin, etc.)
for colset in [group_person, group_income, group_policy]:
    group_idxs = [idx for idx, col in enumerate(feature_cols) if col in colset]
    grouped_features.append(group_idxs)

# %%
grouped_features
# Out:
# [[0, 1, 2, 7, 8, 10, 12], [3, 4, 9, 11, 13, 15], [5, 6, 14, 16, 17, 18]]

# %% [markdown]
# ##### **Training & Inference**

# %%
train_df.head()
# Out:
#    Gender  Marital Status  Education Level  Occupation  Location  Policy Type  \
# 0       0               1                0           1         2            2
# 1       0               0                2           0         0            1
# 2       1               0                1           1         1            2
# 3       1               1                0           0         0            0
# 4       1               2                0           1         0            2
#
#    Customer Feedback  Smoking Status  Exercise Frequency  Property Type   Age  \
# 0                  2               0                   3              2  19.0
# 1                  0               1                   1              2  39.0
# 2                  1               1                   3              2  23.0
# 3                  2               1                   0              0  21.0
# 4                  2               1                   3              2  21.0
#
#    Annual Income  Health Score  Number of Dependents  Vehicle Age  \
# 0        10049.0     22.598761                   1.0         17.0
# 1        31678.0     15.569731                   3.0         12.0
# 2        25602.0     47.177549                   3.0         14.0
# 3       141855.0     10.938144                   2.0          0.0
# 4        39651.0     20.376094                   1.0          8.0
#
#    Credit Score  Insurance Duration  Previous Claims  Policy Start Date  \
# 0         372.0                 5.0              2.0           0.955634
# 1         694.0                 2.0              1.0           1.487141
# 2         595.0                 3.0              1.0           1.185771
# 3         367.0                 1.0              1.0           0.484401
# 4         598.0                 4.0              0.0           3.015908
#
#    Premium Amount
# 0          2869.0
# 1          1483.0
# 2           567.0
# 3           765.0
# 4          2022.0

# %%
X_ = train_df[feature_cols]
y = train_df[[target_col]]

# %%
# X.columns

# print(feature_cols)

X_.isna().sum().sum()
# Out:
# 0

# %%
categorical_cols = ['Gender', 'Marital Status', 'Education Level', 'Occupation', 'Location', 'Policy Type', 'Customer Feedback', 'Smoking Status', 'Exercise Frequency', 'Property Type']
numerical_cols = ['Age', 'Annual Income', 'Health Score', 'Number of Dependents', 'Vehicle Age', 'Credit Score', 'Insurance Duration', 'Previous Claims', 'Policy Start Date']

# %%
FOLDS = 5
RANDOM_SEED = 42
X = train_df.drop(columns="Premium Amount").copy()
y = train_df["Premium Amount"].copy()

X_test = test_df.drop(columns="Premium Amount").copy()

df_subm_tabnet = df_subm.copy()

cv = KFold(FOLDS, shuffle=True, random_state=RANDOM_SEED)
rmsle = []

# Initialize the Stack
df_subm_tabnet['Premium Amount'] = 0.0

i=0

oof_results = pd.DataFrame(columns=list(range(FOLDS)), index=X.index)

for idx_train, idx_valid in cv.split(X, y):

    print(f"Fold {i}")

    # Split the data into training and validation sets for the current fold
    X_train, y_train = X.iloc[idx_train], y.iloc[idx_train].to_numpy().reshape(-1,1)
    X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid].to_numpy().reshape(-1,1)

    scaler = MinMaxScaler()
    X_train[numerical_cols] = scaler.fit_transform(X_train[numerical_cols])
    X_valid[numerical_cols] = scaler.transform(X_valid[numerical_cols])

    X_train = X_train.to_numpy()
    X_valid = X_valid.to_numpy()

    # Initialize the TabNet Regressor model
    params = {} #'n_d': 10, 'n_a': 10, 'n_steps': 3, 'gamma': 1.37, 'lambda_sparse': 0.0016
    reg = TabNetRegressor(
        grouped_features=grouped_features,
        optimizer_fn=torch.optim.Adam,
        optimizer_params=dict(lr=0.01),
        scheduler_params={"patience":5, # how to use learning rate scheduler
                          "factor":0.5,
                          "min_lr":0.0001},
        scheduler_fn=torch.optim.lr_scheduler.ReduceLROnPlateau,
        **params)

    # Train the model using the training set and validate using the validation set
    if i>5:
      reg.fit(
          X_train, y_train,
          eval_set=[(X_valid, y_valid)],
          eval_metric=['rmsle'],
          batch_size=1024,
          max_epochs=100,
          patience=17
          )

      torch.save(reg, f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/Glucose/Tabnet_v6/tabnet_model_{i}.pth")

    else:
      reg = torch.load(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/Glucose/Tabnet_v6/tabnet_model_{i}.pth")

    tab_preds = reg.predict(X_valid)

    oof_results.iloc[idx_valid,i] = tab_preds.flatten()

    # Prepare the test data and make predictions
    error = root_mean_squared_log_error(y_valid, tab_preds)
    rmsle.append(error)
    print(f"RMSLE fold {i}: {error}")

    X_test_ = X_test.copy()
    X_test_[numerical_cols] = scaler.transform(X_test_[numerical_cols])
    X_test_ = X_test_.to_numpy()

    # Aggregate the predictions across the 5 folds (averaging for ensemble)
    df_subm_tabnet['Premium Amount'] += reg.predict(X_test_)[:, 0] / FOLDS
    i += 1

    del scaler, reg, X_test_, X_train, y_train, X_valid, y_valid
    gc.collect()


#df_subm.to_csv('submission_tabnet.csv')
# Out:
# Fold 0
# RMSLE fold 0: 1.1478972492470383
# Fold 1
# RMSLE fold 1: 1.1510460788166026
# Fold 2
# RMSLE fold 2: 1.1449163282070463
# Fold 3
# RMSLE fold 3: 1.1504960346944604
# Fold 4
# RMSLE fold 4: 1.152191966789925

# %%
rmsle
# Out:
# [1.1478972492470383,
#  1.1510460788166026,
#  1.1449163282070463,
#  1.1504960346944604,
#  1.152191966789925]

# %%
np.mean(rmsle), np.std(rmsle)
# Out:
# (1.1493095315510145, 0.0026087006707983746)

# %%
oof_results["average"] = oof_results.mean(axis=1)
oof_results["average"].min(),oof_results["average"].max()
# Out:
# (260.32696533203125, 2565.853759765625)

# %%
plt.hist(oof_results["average"], bins=100, alpha=0.5)
plt.hist(train_df["Premium Amount"], bins=100, color="salmon", alpha=0.5)
plt.xlabel("Premium Amount")
plt.ylabel("Frequency")
plt.title("Distribution of Predicted Premium Amounts")
plt.show()

# %%
train_df["Premium Amount"].min(),train_df["Premium Amount"].max(),train_df["Premium Amount"].mean(),train_df["Premium Amount"].median()
# Out:
# (20.0, 4999.0, 1102.5448216666666, 872.0)

# %% [markdown]
# ##### Save Results:

# %%
df_subm_tabnet.head()
# Out:
#          Premium Amount
# id
# 1200000     1383.073257
# 1200001     1101.690735
# 1200002     1052.458755
# 1200003     1074.403259
# 1200004     1028.962479

# %%
#df_subm_tabnet.to_csv('/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/Submissions/submission_tabnet_baseline.csv')

# %%
#oof_results_stack["average"] = oof_results_stack.mean(axis=1)
oof_results.head()
# Out:
#             0            1    2            3    4      average
# 0         NaN  1175.173828  NaN          NaN  NaN  1175.173828
# 1         NaN  1012.414062  NaN          NaN  NaN  1012.414062
# 2  1008.60022          NaN  NaN          NaN  NaN   1008.60022
# 3         NaN  1109.294556  NaN          NaN  NaN  1109.294556
# 4         NaN          NaN  NaN  1053.674438  NaN  1053.674438

# %%
oof_results.isna().sum()
# Out:
# 0          960000
# 1          960000
# 2          960000
# 3          960000
# 4          960000
# average         0
# dtype: int64

# %%
train_results_df_ = oof_results["average"].astype("float").copy()
train_results_df_.columns = ["stack_baseline"]
#train_results_df_.to_csv(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/Submissions/train_tabnet_baseline.csv")

# %% [markdown]
# ### Occupation:

# %%
df = pd.concat([df_train, df_test], axis=0)

occ_null = df[df['Occupation'].isnull()]

occ_null.isnull().sum()/occ_null.shape[0]
# Out:
# Age                     0.015971
# Gender                  0.000000
# Annual Income           0.036998
# Marital Status          0.015380
# Number of Dependents    0.090851
# Education Level         0.000000
# Occupation              1.000000
# Health Score            0.060152
# Location                0.000000
# Policy Type             0.000000
# Previous Claims         0.303674
# Vehicle Age             0.000003
# Credit Score            0.114061
# Insurance Duration      0.000003
# Policy Start Date       0.000000
# Customer Feedback       0.065116
# Smoking Status          0.000000
# Exercise Frequency      0.000000
# Property Type           0.000000
# Premium Amount          0.400410
# dtype: float64

# %%
occ_null[occ_null["Previous Claims"]>=8]
# Out:
#           Age  Gender  Annual Income Marital Status  Number of Dependents  \
# id
# 491125   38.0    Male        18093.0       Divorced                   4.0
# 1044268  63.0  Female        64514.0         Single                   1.0
# 1218189  55.0    Male        52637.0            NaN                   2.0
# 1302311  48.0  Female         2392.0       Divorced                   NaN
# 1556373  50.0    Male        44284.0         Single                   2.0
# 1704168  20.0    Male       102339.0        Married                   NaN
#
#         Education Level Occupation  Health Score  Location    Policy Type  \
# id
# 491125       Bachelor's        NaN           NaN     Urban        Premium
# 1044268     High School        NaN     10.176816  Suburban  Comprehensive
# 1218189      Bachelor's        NaN     31.149848     Rural        Premium
# 1302311        Master's        NaN     25.838981     Urban        Premium
# 1556373             PhD        NaN      8.787593  Suburban          Basic
# 1704168     High School        NaN     13.727870     Urban        Premium
#
#          Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# id
# 491125               9.0         13.0           NaN                 9.0
# 1044268              8.0         10.0         641.0                 3.0
# 1218189              8.0         18.0         561.0                 3.0
# 1302311              9.0         16.0         697.0                 4.0
# 1556373              9.0          6.0         552.0                 8.0
# 1704168              8.0          9.0         456.0                 7.0
#
#          Policy Start Date Customer Feedback Smoking Status  \
# id
# 491125            3.829607              Poor            Yes
# 1044268           2.325497              Good            Yes
# 1218189           5.309059           Average             No
# 1302311           5.037826              Good             No
# 1556373           0.750155              Poor            Yes
# 1704168           2.317278              Good            Yes
#
#         Exercise Frequency Property Type  Premium Amount
# id
# 491125               Daily     Apartment          1614.0
# 1044268            Monthly         Condo          3042.0
# 1218189             Rarely         Condo             NaN
# 1302311             Weekly         House             NaN
# 1556373             Weekly         House             NaN
# 1704168            Monthly     Apartment             NaN

# %%
del occ_null
gc.collect()
# Out:
# 17863

# %%
# fig, axs = plt.subplots(2,2,figsize=(12,10))
# axs = np.ravel(axs)

# sns.barplot(df, x="Previous Claims", y="Annual Income", hue="Occupation", ax=axs[0], palette=palette_9)
# sns.barplot(df, x="Previous Claims", y="Annual Income", ax=axs[1], palette=palette_9)

# sns.barplot(df, x="Previous Claims", y="Credit Score", hue="Occupation", ax=axs[2], palette=palette_9)
# sns.barplot(df, x="Previous Claims", y="Credit Score", ax=axs[3], palette=palette_9)

# plt.show()

# %%
df_train.Occupation.unique()
# Out:
# array(['Self-Employed', nan, 'Employed', 'Unemployed'], dtype=object)

# %%
grouped_means = df.groupby('Occupation').mean(numeric_only=True)
grouped_median = df.groupby('Occupation').median(numeric_only=True)
display(grouped_means)
display(grouped_median)
# Out:
#                      Age  Annual Income  Number of Dependents  Health Score  \
# Occupation
# Employed       41.126494   32799.165561              2.008159     25.589230
# Self-Employed  41.196764   32885.895129              2.008113     25.581261
# Unemployed     41.152831   32926.823404              2.007877     25.702127
#
#                Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# Occupation
# Employed              1.008377     9.571687    592.561871            5.015142
# Self-Employed         1.003723     9.587983    592.148717            5.015989
# Unemployed            1.007665     9.563437    592.114174            5.027487
#
#                Policy Start Date  Premium Amount
# Occupation
# Employed                2.813427     1107.400895
# Self-Employed           2.819751     1106.609284
# Unemployed              2.811996     1105.369023
#                 Age  Annual Income  Number of Dependents  Health Score  \
# Occupation
# Employed       41.0        23959.5                   2.0     24.534650
# Self-Employed  41.0        23982.0                   2.0     24.578729
# Unemployed     41.0        23982.0                   2.0     24.719403
#
#                Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# Occupation
# Employed                   1.0         10.0         595.0                 5.0
# Self-Employed              1.0         10.0         594.0                 5.0
# Unemployed                 1.0         10.0         594.0                 5.0
#
#                Policy Start Date  Premium Amount
# Occupation
# Employed                2.810429           881.0
# Self-Employed           2.821387           874.0
# Unemployed              2.807689           874.0

# %%
grouped_counts = df.groupby('Occupation')[categorical_cols].count()
grouped_counts
# Out:
#                Gender  Marital Status  Education Level  Occupation  Location  \
# Occupation
# Employed       471324          464221           471324      471324    471324
# Self-Employed  470636          463178           470636      470636    470636
# Unemployed     460840          453721           460840      460840    460840
#
#                Policy Type  Customer Feedback  Smoking Status  \
# Occupation
# Employed            471324             440735          471324
# Self-Employed       470636             439951          470636
# Unemployed          460840             430901          460840
#
#                Exercise Frequency  Property Type
# Occupation
# Employed                   471324         471324
# Self-Employed              470636         470636
# Unemployed                 460840         460840

# %%
categorical_cols_no_occ = ['Gender', 'Marital Status', 'Education Level', 'Location', 'Policy Type', 'Customer Feedback', 'Smoking Status', 'Exercise Frequency', 'Property Type']
numerical_cols = ['Age', 'Annual Income', 'Health Score', 'Number of Dependents', 'Vehicle Age', 'Credit Score', 'Insurance Duration', 'Previous Claims', 'Policy Start Date']

# Preprocessing for categorical features: Imputation + OneHotEncoding
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('Ordinal', OneHotEncoder(sparse_output=False))
])

# Preprocessing for numerical features: Imputation + Scaling
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# Combine both transformations
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols_no_occ)
    ],
    remainder='drop', # Drop any columns not specified in transformers
    verbose_feature_names_out=True
)

# %%
le = OrdinalEncoder(encoded_missing_value=np.nan)
df["Occupation"] = le.fit_transform(df[["Occupation"]])

# %%
df["Occupation"].unique()
# Out:
# array([ 1., nan,  0.,  2.])

# %%
df[df.Occupation.isna()==True]
# Out:
#           Age  Gender  Annual Income Marital Status  Number of Dependents  \
# id
# 1        39.0  Female        31678.0       Divorced                   3.0
# 3        21.0    Male       141855.0        Married                   2.0
# 5        29.0    Male        45963.0        Married                   1.0
# 6        41.0    Male        40336.0        Married                   0.0
# 8        21.0    Male         1733.0       Divorced                   3.0
# ...       ...     ...            ...            ...                   ...
# 1999992  33.0  Female          788.0        Married                   1.0
# 1999995  50.0  Female        38782.0        Married                   1.0
# 1999996   NaN  Female        73462.0         Single                   0.0
# 1999998  34.0  Female        45661.0         Single                   3.0
# 1999999  25.0    Male        24843.0       Divorced                   3.0
#
#         Education Level  Occupation  Health Score  Location    Policy Type  \
# id
# 1              Master's         NaN     15.569731     Rural  Comprehensive
# 3            Bachelor's         NaN     10.938144     Rural          Basic
# 5            Bachelor's         NaN     33.053198     Urban        Premium
# 6                   PhD         NaN           NaN     Rural          Basic
# 8            Bachelor's         NaN     17.869551     Urban        Premium
# ...                 ...         ...           ...       ...            ...
# 1999992      Bachelor's         NaN     47.921197     Urban        Premium
# 1999995      Bachelor's         NaN     14.498639     Rural        Premium
# 1999996        Master's         NaN      8.145748     Rural          Basic
# 1999998        Master's         NaN     15.937248     Urban        Premium
# 1999999     High School         NaN     24.893939  Suburban  Comprehensive
#
#          Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# id
# 1                    1.0         12.0         694.0                 2.0
# 3                    1.0          0.0         367.0                 1.0
# 5                    2.0          4.0         614.0                 5.0
# 6                    2.0          8.0         807.0                 6.0
# 8                    1.0         10.0         685.0                 8.0
# ...                  ...          ...           ...                 ...
# 1999992              0.0         18.0         722.0                 5.0
# 1999995              NaN          8.0         309.0                 2.0
# 1999996              2.0          0.0           NaN                 2.0
# 1999998              2.0         17.0         467.0                 7.0
# 1999999              NaN         15.0           NaN                 8.0
#
#          Policy Start Date Customer Feedback Smoking Status  \
# id
# 1                 1.487141           Average            Yes
# 3                 0.484401              Poor            Yes
# 5                 2.550155           Average             No
# 6                 4.793990              Poor             No
# 8                 3.980292           Average             No
# ...                    ...               ...            ...
# 1999992           0.525497           Average             No
# 1999995           3.413168           Average            Yes
# 1999996           1.695360              Good             No
# 1999998           2.580292           Average             No
# 1999999           3.555634              Good             No
#
#         Exercise Frequency Property Type  Premium Amount
# id
# 1                  Monthly         House          1483.0
# 3                    Daily     Apartment           765.0
# 5                   Weekly         House          3202.0
# 6                   Weekly         House           439.0
# 8                  Monthly         Condo           213.0
# ...                    ...           ...             ...
# 1999992            Monthly         House             NaN
# 1999995              Daily         Condo             NaN
# 1999996              Daily     Apartment             NaN
# 1999998             Weekly         Condo             NaN
# 1999999             Rarely         House             NaN
#
# [597200 rows x 20 columns]

# %% [markdown]
# #### **Model HGBC**

# %%
X_ = df[df.Occupation.isna()==False].copy()
X_test = df[df.Occupation.isna()==True].copy()

RANDOM_SEED=42

X_test = X_test.drop(columns=["Occupation","Premium Amount"])
X = X_.drop(columns=["Occupation","Premium Amount"])
y = X_["Occupation"].copy()

cv = KFold(FOLDS, shuffle=True, random_state=RANDOM_SEED)
accuracy_fold = []

# Initialize the Stack
occ_test_pred_hgbc = pd.DataFrame(index=X_test.index, columns=list(range(FOLDS)))

i=0

oof_results = pd.DataFrame(columns=["Occ_oof"], index=X.index)

for idx_train, idx_valid in cv.split(X, y):

    print(f"Fold {i}")

    # Split the data into training and validation sets for the current fold
    X_train, y_train = X.iloc[idx_train], y.iloc[idx_train].to_numpy().reshape(-1,1)
    X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid].to_numpy().reshape(-1,1)

    # Initialize the TabNet Regressor model
    model_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                                      ("model",HistGradientBoostingClassifier(learning_rate=0.02,
                                                                              max_iter=500,
                                                                              max_leaf_nodes=31,
                                                                              max_depth=15,
                                                                              min_samples_leaf=20,
                                                                              l2_regularization=0.001,
                                                                              max_features=0.90,
                                                                              validation_fraction=0.15,
                                                                              max_bins=255,
                                                                              random_state=RANDOM_SEED,
                                                                              n_iter_no_change=31))])

    # Train the model using the training set and validate using the validation set
    if i >= 0:
        # Fit the StackingRegressor
        model_pipeline.fit(X_train, y_train)
        obj = sio.dump(model_pipeline, f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/hgbc_occ_base_{i}.skops")

    else:
        unknown_types = sio.get_untrusted_types(file=f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/hgbc_occ_base_{i}.skops")
        model_pipeline = sio.load(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/hgbc_occ_base_{i}.skops", trusted=unknown_types)

    occ_preds = model_pipeline.predict(X_valid)

    oof_results.iloc[idx_valid,:] = occ_preds.flatten().reshape(-1,1)

    # Prepare the test data and make predictions
    accuracy_ = accuracy_score(y_valid, occ_preds)
    accuracy_fold.append(accuracy_)
    print(f"Accuracy fold {i}: {accuracy_}")

    X_test_ = X_test.copy()

    # Aggregate the predictions across the 5 folds (averaging for ensemble)
    occ_test_pred_hgbc.loc[:,i] += model_pipeline.predict(X_test_) #[:, 0] / FOLDS
    i += 1

    del model_pipeline, X_test_, X_train, y_train, X_valid, y_valid
    gc.collect()
# Out:
# Fold 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-118-2effb09995c3> in <cell line: 20>()
#      43     if i >= 0:
#      44         # Fit the StackingRegressor
# ---> 45         model_pipeline.fit(X_train, y_train)
#      46         obj = sio.dump(model_pipeline, f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/hgbc_occ_base_{i}.skops")
#      47
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in fit(self, X, y, **params)
#     471             if self._final_estimator != "passthrough":
#     472                 last_step_params = routed_params[self.steps[-1][0]]
# --> 473                 self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     474
#     475         return self
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_hist_gradient_boosting/gradient_boosting.py in fit(self, X, y, sample_weight)
#     876                 )
#     877             else:
# --> 878                 self._loss.gradient_hessian(
#     879                     y_true=y_train,
#     880                     raw_prediction=raw_predictions,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/_loss/loss.py in gradient_hessian(self, y_true, raw_prediction, sample_weight, gradient_out, hessian_out, n_threads)
#     368             hessian_out = hessian_out.squeeze(1)
#     369
# --> 370         self.closs.gradient_hessian(
#     371             y_true=y_true,
#     372             raw_prediction=raw_prediction,
#
# KeyboardInterrupt:

# %% [markdown]
#     Fold 0
#     Accuracy fold 0: 0.3381879098944967
#     Fold 1
#     Accuracy fold 1: 0.3391823495865412
#     Fold 2
#     Accuracy fold 2: 0.3376710863986313
#     Fold 3
#     Accuracy fold 3: 0.340971628172227
#     Fold 4
#     Accuracy fold 4: 0.3381629597946963

# %% [markdown]
# #### **Model RF**

# %%
X_ = df[df.Occupation.isna()==False].copy()
X_test = df[df.Occupation.isna()==True].copy()

RANDOM_SEED=42

X_test = X_test.drop(columns=["Occupation","Premium Amount"])
X = X_.drop(columns=["Occupation","Premium Amount"])
y = X_["Occupation"].copy()

cv = KFold(FOLDS, shuffle=True, random_state=RANDOM_SEED)
accuracy_fold = []

# Initialize the Stack
occ_test_pred_rf = pd.DataFrame(index=X_test.index, columns=list(range(FOLDS)))

i=0

oof_results = pd.DataFrame(columns=["Occ_oof"], index=X.index)

for idx_train, idx_valid in cv.split(X, y):

    print(f"Fold {i}")

    # Split the data into training and validation sets for the current fold
    X_train, y_train = X.iloc[idx_train], y.iloc[idx_train].to_numpy().reshape(-1,1)
    X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid].to_numpy().reshape(-1,1)

    # Initialize the TabNet Regressor model
    model_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                                      ("model",RandomForestClassifier(n_estimators=250, criterion='gini', max_depth=10, min_samples_split=8, min_samples_leaf=5,
                                                                      max_features='sqrt',
                                                                      bootstrap=True, n_jobs=-1, random_state=RANDOM_SEED, max_samples=0.9))])

    # Train the model using the training set and validate using the validation set
    if i >= 5:
        # Fit the StackingRegressor
        model_pipeline.fit(X_train, y_train)
        obj = sio.dump(model_pipeline, f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/rf_occ_base_{i}.skops")

    else:
        unknown_types = sio.get_untrusted_types(file=f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/rf_occ_base_{i}.skops")
        model_pipeline = sio.load(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/rf_occ_base_{i}.skops", trusted=unknown_types)

    occ_preds = model_pipeline.predict(X_valid)

    oof_results.iloc[idx_valid,:] = occ_preds.flatten().reshape(-1,1)

    # Prepare the test data and make predictions
    accuracy_ = accuracy_score(y_valid, occ_preds)
    accuracy_fold.append(accuracy_)
    print(f"Accuracy fold {i}: {accuracy_}")

    X_test_ = X_test.copy()

    # Aggregate the predictions across the 5 folds (averaging for ensemble)
    occ_test_pred_rf.loc[:,i] += model_pipeline.predict(X_test_) #[:, 0] / FOLDS
    i += 1

    del model_pipeline, X_test_, X_train, y_train, X_valid, y_valid
    gc.collect()
# Out:
# Fold 0
# Accuracy fold 0: 0.33946749358426004
# Fold 1
# Accuracy fold 1: 0.33881522668947817
# Fold 2
# Accuracy fold 2: 0.3380203877958369
# Fold 3
# Accuracy fold 3: 0.3396278870829769
# Fold 4
# Accuracy fold 4: 0.33839463929284286

# %% [markdown]
# #### **MODEL XgbClass**

# %%
df[df.select_dtypes(include="object").columns] = df[df.select_dtypes(include="object").columns].astype("category")

# %%
X_ = df[df.Occupation.isna()==False].copy()
X_test = df[df.Occupation.isna()==True].copy()

RANDOM_SEED=42

X_test = X_test.drop(columns=["Occupation","Premium Amount"])
X = X_.drop(columns=["Occupation","Premium Amount"])
y = X_["Occupation"].copy()

cv = KFold(FOLDS, shuffle=True, random_state=RANDOM_SEED)
accuracy_fold = []

# Initialize the Stack
occ_test_pred_xgb = pd.DataFrame(index=X_test.index, columns=list(range(FOLDS)))

i=0

oof_results = pd.DataFrame(columns=["Occ_oof"], index=X.index)

for idx_train, idx_valid in cv.split(X, y):

    print(f"Fold {i}")

    # Split the data into training and validation sets for the current fold
    X_train, y_train = X.iloc[idx_train], y.iloc[idx_train].to_numpy().reshape(-1,1)
    X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid].to_numpy().reshape(-1,1)

    # Initialize the TabNet Regressor model
    early_stop = EarlyStopping(rounds=31, metric_name="mlogloss")
    model_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                                      ("model",XGBClassifier(learning_rate=0.01,
                                                             objective ="multi:softmax",
                                                              n_estimators=500,
                                                              max_depth=10,
                                                              min_child_weight=1,
                                                              subsample=0.85,
                                                              eval_metric='mlogloss',
                                                              colsample_bytree=0.9,
                                                              callbacks=[early_stop],
                                                              enable_categorical="True",
                                                              reg_lambda=0.001,
                                                              reg_alpha=0.001))])

    # Train the model using the training set and validate using the validation set
    if i >= 0:
        # Fit the StackingRegressor
        model_pipeline[:-1].fit(X_train, y_train)
        X_val_ = model_pipeline[:-1].transform(X_valid) # Transform X_val using the same steps as X
        eval_set = [(X_val_, y_valid)]


        model_pipeline.fit(X_train, y_train, model__eval_set=eval_set)
        obj = sio.dump(model_pipeline, f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/xgb_occ_base_{i}.skops")

    else:
        unknown_types = sio.get_untrusted_types(file=f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/xgb_occ_base_{i}.skops")
        model_pipeline = sio.load(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/xgb_occ_base_{i}.skops", trusted=unknown_types)

    occ_preds = model_pipeline.predict(X_valid)

    oof_results.iloc[idx_valid,:] = occ_preds.flatten().reshape(-1,1)

    # Prepare the test data and make predictions
    accuracy_ = accuracy_score(y_valid, occ_preds)
    accuracy_fold.append(accuracy_)
    print(f"Accuracy fold {i}: {accuracy_}")

    X_test_ = X_test.copy()

    # Aggregate the predictions across the 5 folds (averaging for ensemble)
    occ_test_pred_xgb.loc[:,i] = model_pipeline.predict(X_test_) #[:, 0] / FOLDS
    i += 1

    #del model_pipeline, X_test_, X_train, y_train, X_valid, y_valid
    gc.collect()
# Out:
# Fold 0
# [0]	validation_0-mlogloss:1.09861
# [1]	validation_0-mlogloss:1.09861
# [2]	validation_0-mlogloss:1.09861
# [3]	validation_0-mlogloss:1.09861
# [4]	validation_0-mlogloss:1.09860
# [5]	validation_0-mlogloss:1.09860
# [6]	validation_0-mlogloss:1.09860
# [7]	validation_0-mlogloss:1.09860
# [8]	validation_0-mlogloss:1.09860
# [9]	validation_0-mlogloss:1.09860
# [10]	validation_0-mlogloss:1.09859
# [11]	validation_0-mlogloss:1.09859
# [12]	validation_0-mlogloss:1.09859
# [13]	validation_0-mlogloss:1.09859
# [14]	validation_0-mlogloss:1.09859
# [15]	validation_0-mlogloss:1.09858
# [16]	validation_0-mlogloss:1.09858
# [17]	validation_0-mlogloss:1.09857
# [18]	validation_0-mlogloss:1.09857
# [19]	validation_0-mlogloss:1.09857
# [20]	validation_0-mlogloss:1.09857
# [21]	validation_0-mlogloss:1.09857
# [22]	validation_0-mlogloss:1.09856
# [23]	validation_0-mlogloss:1.09856
# [24]	validation_0-mlogloss:1.09856
# [25]	validation_0-mlogloss:1.09856
# [26]	validation_0-mlogloss:1.09855
# [27]	validation_0-mlogloss:1.09855
# [28]	validation_0-mlogloss:1.09855
# [29]	validation_0-mlogloss:1.09855
# [30]	validation_0-mlogloss:1.09855
# [31]	validation_0-mlogloss:1.09855
# [32]	validation_0-mlogloss:1.09854
# [33]	validation_0-mlogloss:1.09854
# [34]	validation_0-mlogloss:1.09854
# [35]	validation_0-mlogloss:1.09854
# [36]	validation_0-mlogloss:1.09854
# [37]	validation_0-mlogloss:1.09853
# [38]	validation_0-mlogloss:1.09853
# [39]	validation_0-mlogloss:1.09853
# [40]	validation_0-mlogloss:1.09853
# [41]	validation_0-mlogloss:1.09853
# [42]	validation_0-mlogloss:1.09853
# [43]	validation_0-mlogloss:1.09853
# [44]	validation_0-mlogloss:1.09853
# [45]	validation_0-mlogloss:1.09853
# [46]	validation_0-mlogloss:1.09852
# [47]	validation_0-mlogloss:1.09852
# [48]	validation_0-mlogloss:1.09852
# [49]	validation_0-mlogloss:1.09852
# [50]	validation_0-mlogloss:1.09852
# [51]	validation_0-mlogloss:1.09852
# [52]	validation_0-mlogloss:1.09852
# [53]	validation_0-mlogloss:1.09852
# [54]	validation_0-mlogloss:1.09851
# [55]	validation_0-mlogloss:1.09851
# [56]	validation_0-mlogloss:1.09851
# [57]	validation_0-mlogloss:1.09851
# [58]	validation_0-mlogloss:1.09850
# [59]	validation_0-mlogloss:1.09850
# [60]	validation_0-mlogloss:1.09850
# [61]	validation_0-mlogloss:1.09850
# [62]	validation_0-mlogloss:1.09850
# [63]	validation_0-mlogloss:1.09850
# [64]	validation_0-mlogloss:1.09850
# [65]	validation_0-mlogloss:1.09850
# [66]	validation_0-mlogloss:1.09850
# [67]	validation_0-mlogloss:1.09850
# [68]	validation_0-mlogloss:1.09849
# [69]	validation_0-mlogloss:1.09849
# [70]	validation_0-mlogloss:1.09849
# [71]	validation_0-mlogloss:1.09849
# [72]	validation_0-mlogloss:1.09849
# [73]	validation_0-mlogloss:1.09849
# [74]	validation_0-mlogloss:1.09849
# [75]	validation_0-mlogloss:1.09849
# [76]	validation_0-mlogloss:1.09849
# [77]	validation_0-mlogloss:1.09849
# [78]	validation_0-mlogloss:1.09849
# [79]	validation_0-mlogloss:1.09848
# [80]	validation_0-mlogloss:1.09848
# [81]	validation_0-mlogloss:1.09848
# [82]	validation_0-mlogloss:1.09848
# [83]	validation_0-mlogloss:1.09848
# [84]	validation_0-mlogloss:1.09848
# [85]	validation_0-mlogloss:1.09848
# [86]	validation_0-mlogloss:1.09848
# [87]	validation_0-mlogloss:1.09848
# [88]	validation_0-mlogloss:1.09847
# [89]	validation_0-mlogloss:1.09847
# [90]	validation_0-mlogloss:1.09847
# [91]	validation_0-mlogloss:1.09847
# [92]	validation_0-mlogloss:1.09847
# [93]	validation_0-mlogloss:1.09847
# [94]	validation_0-mlogloss:1.09847
# [95]	validation_0-mlogloss:1.09847
# [96]	validation_0-mlogloss:1.09847
# [97]	validation_0-mlogloss:1.09846
# [98]	validation_0-mlogloss:1.09846
# [99]	validation_0-mlogloss:1.09846
# [100]	validation_0-mlogloss:1.09846
# [101]	validation_0-mlogloss:1.09846
# [102]	validation_0-mlogloss:1.09846
# [103]	validation_0-mlogloss:1.09846
# [104]	validation_0-mlogloss:1.09846
# [105]	validation_0-mlogloss:1.09846
# [106]	validation_0-mlogloss:1.09845
# [107]	validation_0-mlogloss:1.09845
# [108]	validation_0-mlogloss:1.09845
# [109]	validation_0-mlogloss:1.09845
# [110]	validation_0-mlogloss:1.09845
# [111]	validation_0-mlogloss:1.09845
# [112]	validation_0-mlogloss:1.09844
# [113]	validation_0-mlogloss:1.09845
# [114]	validation_0-mlogloss:1.09845
# [115]	validation_0-mlogloss:1.09845
# [116]	validation_0-mlogloss:1.09844
# [117]	validation_0-mlogloss:1.09844
# [118]	validation_0-mlogloss:1.09844
# [119]	validation_0-mlogloss:1.09844
# [120]	validation_0-mlogloss:1.09844
# [121]	validation_0-mlogloss:1.09844
# [122]	validation_0-mlogloss:1.09844
# [123]	validation_0-mlogloss:1.09844
# [124]	validation_0-mlogloss:1.09844
# [125]	validation_0-mlogloss:1.09844
# [126]	validation_0-mlogloss:1.09844
# [127]	validation_0-mlogloss:1.09844
# [128]	validation_0-mlogloss:1.09844
# [129]	validation_0-mlogloss:1.09844
# [130]	validation_0-mlogloss:1.09844
# [16]	validation_0-mlogloss:1.09856
# [17]	validation_0-mlogloss:1.09856
# [18]	validation_0-mlogloss:1.09855
# [19]	validation_0-mlogloss:1.09855
# [20]	validation_0-mlogloss:1.09855
# [21]	validation_0-mlogloss:1.09854
# [22]	validation_0-mlogloss:1.09854
# [23]	validation_0-mlogloss:1.09854
# [24]	validation_0-mlogloss:1.09853
# [25]	validation_0-mlogloss:1.09853
# [26]	validation_0-mlogloss:1.09853
# [27]	validation_0-mlogloss:1.09853
# [28]	validation_0-mlogloss:1.09852
# [29]	validation_0-mlogloss:1.09852
# [30]	validation_0-mlogloss:1.09852
# [31]	validation_0-mlogloss:1.09851
# [32]	validation_0-mlogloss:1.09851
# [33]	validation_0-mlogloss:1.09851
# [34]	validation_0-mlogloss:1.09851
# [35]	validation_0-mlogloss:1.09851
# [36]	validation_0-mlogloss:1.09850
# [37]	validation_0-mlogloss:1.09850
# [38]	validation_0-mlogloss:1.09850
# [39]	validation_0-mlogloss:1.09850
# [40]	validation_0-mlogloss:1.09849
# [41]	validation_0-mlogloss:1.09849
# [42]	validation_0-mlogloss:1.09849
# [43]	validation_0-mlogloss:1.09849
# [44]	validation_0-mlogloss:1.09849
# [45]	validation_0-mlogloss:1.09848
# [46]	validation_0-mlogloss:1.09848
# [47]	validation_0-mlogloss:1.09848
# [48]	validation_0-mlogloss:1.09848
# [49]	validation_0-mlogloss:1.09848
# [50]	validation_0-mlogloss:1.09847
# [51]	validation_0-mlogloss:1.09847
# [52]	validation_0-mlogloss:1.09847
# [53]	validation_0-mlogloss:1.09846
# [54]	validation_0-mlogloss:1.09846
# [55]	validation_0-mlogloss:1.09846
# [56]	validation_0-mlogloss:1.09846
# [57]	validation_0-mlogloss:1.09846
# [58]	validation_0-mlogloss:1.09846
# [59]	validation_0-mlogloss:1.09846
# [60]	validation_0-mlogloss:1.09845
# [61]	validation_0-mlogloss:1.09845
# [62]	validation_0-mlogloss:1.09845
# [63]	validation_0-mlogloss:1.09845
# [64]	validation_0-mlogloss:1.09845
# [65]	validation_0-mlogloss:1.09845
# [66]	validation_0-mlogloss:1.09844
# [67]	validation_0-mlogloss:1.09844
# [68]	validation_0-mlogloss:1.09844
# [69]	validation_0-mlogloss:1.09844
# [70]	validation_0-mlogloss:1.09844
# [71]	validation_0-mlogloss:1.09844
# [72]	validation_0-mlogloss:1.09844
# [73]	validation_0-mlogloss:1.09843
# [74]	validation_0-mlogloss:1.09843
# [75]	validation_0-mlogloss:1.09843
# [76]	validation_0-mlogloss:1.09843
# [77]	validation_0-mlogloss:1.09843
# [78]	validation_0-mlogloss:1.09843
# [79]	validation_0-mlogloss:1.09843
# [80]	validation_0-mlogloss:1.09843
# [81]	validation_0-mlogloss:1.09843
# [82]	validation_0-mlogloss:1.09843
# [83]	validation_0-mlogloss:1.09843
# [84]	validation_0-mlogloss:1.09843
# [85]	validation_0-mlogloss:1.09842
# [86]	validation_0-mlogloss:1.09842
# [87]	validation_0-mlogloss:1.09842
# [88]	validation_0-mlogloss:1.09842
# [89]	validation_0-mlogloss:1.09842
# [90]	validation_0-mlogloss:1.09842
# [91]	validation_0-mlogloss:1.09841
# [92]	validation_0-mlogloss:1.09841
# [93]	validation_0-mlogloss:1.09841
# [94]	validation_0-mlogloss:1.09841
# [95]	validation_0-mlogloss:1.09841
# [96]	validation_0-mlogloss:1.09841
# [97]	validation_0-mlogloss:1.09841
# [98]	validation_0-mlogloss:1.09841
# [99]	validation_0-mlogloss:1.09841
# [100]	validation_0-mlogloss:1.09841
# [101]	validation_0-mlogloss:1.09841
# [102]	validation_0-mlogloss:1.09841
# [103]	validation_0-mlogloss:1.09840
# [104]	validation_0-mlogloss:1.09840
# [105]	validation_0-mlogloss:1.09840
# [106]	validation_0-mlogloss:1.09840
# [107]	validation_0-mlogloss:1.09840
# [108]	validation_0-mlogloss:1.09840
# [109]	validation_0-mlogloss:1.09840
# [110]	validation_0-mlogloss:1.09840
# [111]	validation_0-mlogloss:1.09840
# [112]	validation_0-mlogloss:1.09840
# [113]	validation_0-mlogloss:1.09840
# [114]	validation_0-mlogloss:1.09840
# [115]	validation_0-mlogloss:1.09839
# [116]	validation_0-mlogloss:1.09839
# [117]	validation_0-mlogloss:1.09840
# [118]	validation_0-mlogloss:1.09839
# [119]	validation_0-mlogloss:1.09839
# [120]	validation_0-mlogloss:1.09839
# [121]	validation_0-mlogloss:1.09839
# [122]	validation_0-mlogloss:1.09839
# [123]	validation_0-mlogloss:1.09839
# [124]	validation_0-mlogloss:1.09839
# [125]	validation_0-mlogloss:1.09839
# [126]	validation_0-mlogloss:1.09839
# [127]	validation_0-mlogloss:1.09839
# [128]	validation_0-mlogloss:1.09838
# [129]	validation_0-mlogloss:1.09839
# [130]	validation_0-mlogloss:1.09839
# [131]	validation_0-mlogloss:1.09838
# [132]	validation_0-mlogloss:1.09838
# [133]	validation_0-mlogloss:1.09838
# [134]	validation_0-mlogloss:1.09838
# [135]	validation_0-mlogloss:1.09838
# [136]	validation_0-mlogloss:1.09838
# [137]	validation_0-mlogloss:1.09838
# [138]	validation_0-mlogloss:1.09837
# [139]	validation_0-mlogloss:1.09837
# [140]	validation_0-mlogloss:1.09837
# [141]	validation_0-mlogloss:1.09837
# [142]	validation_0-mlogloss:1.09837
# [143]	validation_0-mlogloss:1.09837
# [144]	validation_0-mlogloss:1.09837
# [145]	validation_0-mlogloss:1.09837
# [146]	validation_0-mlogloss:1.09837
# [147]	validation_0-mlogloss:1.09837
# [148]	validation_0-mlogloss:1.09836
# [149]	validation_0-mlogloss:1.09836
# [150]	validation_0-mlogloss:1.09836
# [151]	validation_0-mlogloss:1.09836
# [152]	validation_0-mlogloss:1.09836
# [153]	validation_0-mlogloss:1.09836
# [154]	validation_0-mlogloss:1.09836
# [155]	validation_0-mlogloss:1.09836
# [156]	validation_0-mlogloss:1.09836
# [157]	validation_0-mlogloss:1.09836
# [158]	validation_0-mlogloss:1.09836
# [159]	validation_0-mlogloss:1.09835
# [160]	validation_0-mlogloss:1.09835
# [161]	validation_0-mlogloss:1.09835
# [162]	validation_0-mlogloss:1.09835
# [163]	validation_0-mlogloss:1.09835
# [164]	validation_0-mlogloss:1.09835
# [165]	validation_0-mlogloss:1.09835
# [166]	validation_0-mlogloss:1.09835
# [167]	validation_0-mlogloss:1.09835
# [168]	validation_0-mlogloss:1.09835
# [169]	validation_0-mlogloss:1.09835
# [170]	validation_0-mlogloss:1.09835
# [171]	validation_0-mlogloss:1.09835
# [172]	validation_0-mlogloss:1.09834
# [173]	validation_0-mlogloss:1.09834
# [174]	validation_0-mlogloss:1.09834
# [175]	validation_0-mlogloss:1.09834
# [176]	validation_0-mlogloss:1.09834
# [177]	validation_0-mlogloss:1.09834
# [178]	validation_0-mlogloss:1.09834
# [179]	validation_0-mlogloss:1.09834
# [180]	validation_0-mlogloss:1.09834
# [181]	validation_0-mlogloss:1.09834
# [182]	validation_0-mlogloss:1.09834
# [183]	validation_0-mlogloss:1.09834
# [184]	validation_0-mlogloss:1.09835
# [185]	validation_0-mlogloss:1.09834
# [186]	validation_0-mlogloss:1.09834
# [187]	validation_0-mlogloss:1.09834
# [188]	validation_0-mlogloss:1.09834
# [189]	validation_0-mlogloss:1.09834
# [190]	validation_0-mlogloss:1.09834
# [191]	validation_0-mlogloss:1.09834
# [192]	validation_0-mlogloss:1.09834
# [193]	validation_0-mlogloss:1.09834
# [194]	validation_0-mlogloss:1.09834
# [195]	validation_0-mlogloss:1.09833
# [196]	validation_0-mlogloss:1.09833
# [197]	validation_0-mlogloss:1.09833
# [198]	validation_0-mlogloss:1.09833
# [199]	validation_0-mlogloss:1.09833
# [200]	validation_0-mlogloss:1.09833
# [201]	validation_0-mlogloss:1.09833
# [202]	validation_0-mlogloss:1.09833
# [203]	validation_0-mlogloss:1.09833
# [204]	validation_0-mlogloss:1.09833
# [205]	validation_0-mlogloss:1.09833
# [206]	validation_0-mlogloss:1.09833
# [207]	validation_0-mlogloss:1.09833
# [208]	validation_0-mlogloss:1.09833
# [209]	validation_0-mlogloss:1.09832
# [210]	validation_0-mlogloss:1.09832
# [211]	validation_0-mlogloss:1.09833
# [212]	validation_0-mlogloss:1.09832
# [213]	validation_0-mlogloss:1.09833
# [214]	validation_0-mlogloss:1.09833
# [215]	validation_0-mlogloss:1.09833
# [216]	validation_0-mlogloss:1.09832
# [217]	validation_0-mlogloss:1.09832
# [218]	validation_0-mlogloss:1.09832
# [219]	validation_0-mlogloss:1.09833
# [220]	validation_0-mlogloss:1.09833
# [221]	validation_0-mlogloss:1.09833
# [222]	validation_0-mlogloss:1.09833
# [223]	validation_0-mlogloss:1.09833
# [224]	validation_0-mlogloss:1.09833
# [225]	validation_0-mlogloss:1.09833
# [226]	validation_0-mlogloss:1.09833
# [227]	validation_0-mlogloss:1.09833
# [228]	validation_0-mlogloss:1.09833
# [229]	validation_0-mlogloss:1.09833
# [230]	validation_0-mlogloss:1.09833
# [231]	validation_0-mlogloss:1.09833
# [232]	validation_0-mlogloss:1.09832
# [233]	validation_0-mlogloss:1.09832
# [234]	validation_0-mlogloss:1.09832
# [235]	validation_0-mlogloss:1.09832
# [236]	validation_0-mlogloss:1.09832
# [237]	validation_0-mlogloss:1.09833
# [238]	validation_0-mlogloss:1.09833
# [239]	validation_0-mlogloss:1.09833
# [240]	validation_0-mlogloss:1.09833
# [241]	validation_0-mlogloss:1.09833
# [242]	validation_0-mlogloss:1.09833
# [243]	validation_0-mlogloss:1.09833
# [244]	validation_0-mlogloss:1.09833
# [245]	validation_0-mlogloss:1.09833
# [246]	validation_0-mlogloss:1.09833
# [247]	validation_0-mlogloss:1.09833
# [248]	validation_0-mlogloss:1.09833
# [249]	validation_0-mlogloss:1.09833
# [250]	validation_0-mlogloss:1.09833
# [251]	validation_0-mlogloss:1.09833
# [252]	validation_0-mlogloss:1.09833
# [253]	validation_0-mlogloss:1.09833
# [254]	validation_0-mlogloss:1.09833
# [255]	validation_0-mlogloss:1.09833
# [256]	validation_0-mlogloss:1.09833
# [257]	validation_0-mlogloss:1.09833
# [258]	validation_0-mlogloss:1.09833
# [259]	validation_0-mlogloss:1.09833
# [260]	validation_0-mlogloss:1.09833
# [261]	validation_0-mlogloss:1.09833
# [262]	validation_0-mlogloss:1.09833
# [263]	validation_0-mlogloss:1.09833
# [264]	validation_0-mlogloss:1.09833
# Accuracy fold 1: 0.34354861705161105
# Fold 2
# [0]	validation_0-mlogloss:1.09861
# [1]	validation_0-mlogloss:1.09861
# [2]	validation_0-mlogloss:1.09860
# [3]	validation_0-mlogloss:1.09860
# [4]	validation_0-mlogloss:1.09860
# [5]	validation_0-mlogloss:1.09860
# [6]	validation_0-mlogloss:1.09860
# [7]	validation_0-mlogloss:1.09859
# [8]	validation_0-mlogloss:1.09859
# [9]	validation_0-mlogloss:1.09859
# [10]	validation_0-mlogloss:1.09858
# [11]	validation_0-mlogloss:1.09858
# [12]	validation_0-mlogloss:1.09857
# [13]	validation_0-mlogloss:1.09857
# [14]	validation_0-mlogloss:1.09857
# [15]	validation_0-mlogloss:1.09857
# [16]	validation_0-mlogloss:1.09856
# [17]	validation_0-mlogloss:1.09856
# [18]	validation_0-mlogloss:1.09856
# [19]	validation_0-mlogloss:1.09855
# [20]	validation_0-mlogloss:1.09855
# [21]	validation_0-mlogloss:1.09855
# [22]	validation_0-mlogloss:1.09854
# [23]	validation_0-mlogloss:1.09854
# [24]	validation_0-mlogloss:1.09854
# [25]	validation_0-mlogloss:1.09854
# [26]	validation_0-mlogloss:1.09853
# [27]	validation_0-mlogloss:1.09853
# [28]	validation_0-mlogloss:1.09853
# [29]	validation_0-mlogloss:1.09853
# [30]	validation_0-mlogloss:1.09853
# [31]	validation_0-mlogloss:1.09853
# [32]	validation_0-mlogloss:1.09852
# [33]	validation_0-mlogloss:1.09852
# [34]	validation_0-mlogloss:1.09852
# [35]	validation_0-mlogloss:1.09852
# [36]	validation_0-mlogloss:1.09851
# [37]	validation_0-mlogloss:1.09851
# [38]	validation_0-mlogloss:1.09851
# [39]	validation_0-mlogloss:1.09851
# [40]	validation_0-mlogloss:1.09851
# [41]	validation_0-mlogloss:1.09850
# [42]	validation_0-mlogloss:1.09850
# [43]	validation_0-mlogloss:1.09850
# [44]	validation_0-mlogloss:1.09850
# [45]	validation_0-mlogloss:1.09849
# [46]	validation_0-mlogloss:1.09849
# [47]	validation_0-mlogloss:1.09849
# [48]	validation_0-mlogloss:1.09849
# [49]	validation_0-mlogloss:1.09849
# [50]	validation_0-mlogloss:1.09849
# [51]	validation_0-mlogloss:1.09848
# [52]	validation_0-mlogloss:1.09848
# [53]	validation_0-mlogloss:1.09848
# [54]	validation_0-mlogloss:1.09848
# [55]	validation_0-mlogloss:1.09847
# [56]	validation_0-mlogloss:1.09847
# [57]	validation_0-mlogloss:1.09847
# [58]	validation_0-mlogloss:1.09847
# [59]	validation_0-mlogloss:1.09847
# [60]	validation_0-mlogloss:1.09847
# [61]	validation_0-mlogloss:1.09847
# [62]	validation_0-mlogloss:1.09847
# [63]	validation_0-mlogloss:1.09846
# [64]	validation_0-mlogloss:1.09846
# [65]	validation_0-mlogloss:1.09846
# [66]	validation_0-mlogloss:1.09846
# [67]	validation_0-mlogloss:1.09846
# [68]	validation_0-mlogloss:1.09846
# [69]	validation_0-mlogloss:1.09846
# [70]	validation_0-mlogloss:1.09846
# [71]	validation_0-mlogloss:1.09845
# [72]	validation_0-mlogloss:1.09845
# [73]	validation_0-mlogloss:1.09845
# [74]	validation_0-mlogloss:1.09845
# [75]	validation_0-mlogloss:1.09845
# [76]	validation_0-mlogloss:1.09845
# [77]	validation_0-mlogloss:1.09845
# [78]	validation_0-mlogloss:1.09845
# [79]	validation_0-mlogloss:1.09844
# [80]	validation_0-mlogloss:1.09844
# [81]	validation_0-mlogloss:1.09844
# [82]	validation_0-mlogloss:1.09844
# [83]	validation_0-mlogloss:1.09844
# [84]	validation_0-mlogloss:1.09844
# [85]	validation_0-mlogloss:1.09844
# [86]	validation_0-mlogloss:1.09844
# [87]	validation_0-mlogloss:1.09844
# [88]	validation_0-mlogloss:1.09844
# [89]	validation_0-mlogloss:1.09844
# [90]	validation_0-mlogloss:1.09844
# [91]	validation_0-mlogloss:1.09843
# [92]	validation_0-mlogloss:1.09843
# [93]	validation_0-mlogloss:1.09843
# [94]	validation_0-mlogloss:1.09843
# [95]	validation_0-mlogloss:1.09843
# [96]	validation_0-mlogloss:1.09843
# [97]	validation_0-mlogloss:1.09843
# [98]	validation_0-mlogloss:1.09843
# [99]	validation_0-mlogloss:1.09843
# [100]	validation_0-mlogloss:1.09843
# [101]	validation_0-mlogloss:1.09843
# [102]	validation_0-mlogloss:1.09843
# [103]	validation_0-mlogloss:1.09843
# [104]	validation_0-mlogloss:1.09842
# [105]	validation_0-mlogloss:1.09842
# [106]	validation_0-mlogloss:1.09842
# [107]	validation_0-mlogloss:1.09843
# [108]	validation_0-mlogloss:1.09843
# [109]	validation_0-mlogloss:1.09842
# [110]	validation_0-mlogloss:1.09842
# [111]	validation_0-mlogloss:1.09842
# [112]	validation_0-mlogloss:1.09842
# [113]	validation_0-mlogloss:1.09842
# [114]	validation_0-mlogloss:1.09842
# [115]	validation_0-mlogloss:1.09842
# [116]	validation_0-mlogloss:1.09842
# [117]	validation_0-mlogloss:1.09842
# [118]	validation_0-mlogloss:1.09842
# [119]	validation_0-mlogloss:1.09842
# [120]	validation_0-mlogloss:1.09841
# [121]	validation_0-mlogloss:1.09842
# [122]	validation_0-mlogloss:1.09842
# [123]	validation_0-mlogloss:1.09842
# [124]	validation_0-mlogloss:1.09842
# [125]	validation_0-mlogloss:1.09841
# [126]	validation_0-mlogloss:1.09841
# [127]	validation_0-mlogloss:1.09841
# [128]	validation_0-mlogloss:1.09841
# [129]	validation_0-mlogloss:1.09841
# [130]	validation_0-mlogloss:1.09841
# [131]	validation_0-mlogloss:1.09841
# [132]	validation_0-mlogloss:1.09841
# [133]	validation_0-mlogloss:1.09841
# [134]	validation_0-mlogloss:1.09841
# [135]	validation_0-mlogloss:1.09841
# [136]	validation_0-mlogloss:1.09841
# [137]	validation_0-mlogloss:1.09840
# [138]	validation_0-mlogloss:1.09840
# [139]	validation_0-mlogloss:1.09840
# [140]	validation_0-mlogloss:1.09840
# [141]	validation_0-mlogloss:1.09840
# [142]	validation_0-mlogloss:1.09840
# [143]	validation_0-mlogloss:1.09840
# [144]	validation_0-mlogloss:1.09840
# [145]	validation_0-mlogloss:1.09840
# [146]	validation_0-mlogloss:1.09840
# [147]	validation_0-mlogloss:1.09839
# [148]	validation_0-mlogloss:1.09839
# [149]	validation_0-mlogloss:1.09839
# [150]	validation_0-mlogloss:1.09839
# [151]	validation_0-mlogloss:1.09839
# [152]	validation_0-mlogloss:1.09839
# [153]	validation_0-mlogloss:1.09839
# [154]	validation_0-mlogloss:1.09839
# [155]	validation_0-mlogloss:1.09839
# [156]	validation_0-mlogloss:1.09839
# [157]	validation_0-mlogloss:1.09839
# [158]	validation_0-mlogloss:1.09839
# [159]	validation_0-mlogloss:1.09839
# [160]	validation_0-mlogloss:1.09839
# [161]	validation_0-mlogloss:1.09839
# [162]	validation_0-mlogloss:1.09839
# [163]	validation_0-mlogloss:1.09839
# [164]	validation_0-mlogloss:1.09839
# [165]	validation_0-mlogloss:1.09839
# [166]	validation_0-mlogloss:1.09839
# [167]	validation_0-mlogloss:1.09839
# [168]	validation_0-mlogloss:1.09839
# [169]	validation_0-mlogloss:1.09839
# [170]	validation_0-mlogloss:1.09839
# [171]	validation_0-mlogloss:1.09839
# [172]	validation_0-mlogloss:1.09839
# [173]	validation_0-mlogloss:1.09839
# [174]	validation_0-mlogloss:1.09839
# [175]	validation_0-mlogloss:1.09839
# [176]	validation_0-mlogloss:1.09839
# [177]	validation_0-mlogloss:1.09839
# [178]	validation_0-mlogloss:1.09839
# [179]	validation_0-mlogloss:1.09839
# [180]	validation_0-mlogloss:1.09839
# [181]	validation_0-mlogloss:1.09839
# [182]	validation_0-mlogloss:1.09839
# [183]	validation_0-mlogloss:1.09839
# [184]	validation_0-mlogloss:1.09839
# [185]	validation_0-mlogloss:1.09839
# [186]	validation_0-mlogloss:1.09838
# [187]	validation_0-mlogloss:1.09838
# [188]	validation_0-mlogloss:1.09838
# [189]	validation_0-mlogloss:1.09838
# [190]	validation_0-mlogloss:1.09838
# [191]	validation_0-mlogloss:1.09838
# [192]	validation_0-mlogloss:1.09838
# [193]	validation_0-mlogloss:1.09838
# [194]	validation_0-mlogloss:1.09838
# [195]	validation_0-mlogloss:1.09838
# [196]	validation_0-mlogloss:1.09838
# [197]	validation_0-mlogloss:1.09838
# [198]	validation_0-mlogloss:1.09838
# [199]	validation_0-mlogloss:1.09838
# [200]	validation_0-mlogloss:1.09838
# [201]	validation_0-mlogloss:1.09838
# [202]	validation_0-mlogloss:1.09837
# [203]	validation_0-mlogloss:1.09837
# [204]	validation_0-mlogloss:1.09837
# [205]	validation_0-mlogloss:1.09837
# [206]	validation_0-mlogloss:1.09838
# [207]	validation_0-mlogloss:1.09837
# [208]	validation_0-mlogloss:1.09837
# [209]	validation_0-mlogloss:1.09837
# [210]	validation_0-mlogloss:1.09837
# [211]	validation_0-mlogloss:1.09837
# [212]	validation_0-mlogloss:1.09837
# [213]	validation_0-mlogloss:1.09837
# [214]	validation_0-mlogloss:1.09837
# [215]	validation_0-mlogloss:1.09837
# [216]	validation_0-mlogloss:1.09837
# [217]	validation_0-mlogloss:1.09837
# [218]	validation_0-mlogloss:1.09837
# [219]	validation_0-mlogloss:1.09837
# [220]	validation_0-mlogloss:1.09837
# [221]	validation_0-mlogloss:1.09837
# [222]	validation_0-mlogloss:1.09837
# [223]	validation_0-mlogloss:1.09837
# [224]	validation_0-mlogloss:1.09837
# [225]	validation_0-mlogloss:1.09837
# [226]	validation_0-mlogloss:1.09837
# [227]	validation_0-mlogloss:1.09837
# [228]	validation_0-mlogloss:1.09837
# [229]	validation_0-mlogloss:1.09837
# [230]	validation_0-mlogloss:1.09837
# [231]	validation_0-mlogloss:1.09837
# [232]	validation_0-mlogloss:1.09837
# [233]	validation_0-mlogloss:1.09837
# [234]	validation_0-mlogloss:1.09837
# [235]	validation_0-mlogloss:1.09837
# [236]	validation_0-mlogloss:1.09837
# [237]	validation_0-mlogloss:1.09837
# [238]	validation_0-mlogloss:1.09837
# [239]	validation_0-mlogloss:1.09837
# [240]	validation_0-mlogloss:1.09837
# [241]	validation_0-mlogloss:1.09837
# [242]	validation_0-mlogloss:1.09837
# [243]	validation_0-mlogloss:1.09837
# [244]	validation_0-mlogloss:1.09837
# [245]	validation_0-mlogloss:1.09837
# [246]	validation_0-mlogloss:1.09837
# [247]	validation_0-mlogloss:1.09837
# [248]	validation_0-mlogloss:1.09837
# [249]	validation_0-mlogloss:1.09837
# [250]	validation_0-mlogloss:1.09837
# [251]	validation_0-mlogloss:1.09837
# [252]	validation_0-mlogloss:1.09837
# [253]	validation_0-mlogloss:1.09837
# [254]	validation_0-mlogloss:1.09837
# [255]	validation_0-mlogloss:1.09837
# [256]	validation_0-mlogloss:1.09837
# [257]	validation_0-mlogloss:1.09837
# [258]	validation_0-mlogloss:1.09837
# [259]	validation_0-mlogloss:1.09837
# [260]	validation_0-mlogloss:1.09837
# [261]	validation_0-mlogloss:1.09837
# [262]	validation_0-mlogloss:1.09837
# Accuracy fold 2: 0.3405189620758483
# Fold 3
# [0]	validation_0-mlogloss:1.09861
# [1]	validation_0-mlogloss:1.09861
# [2]	validation_0-mlogloss:1.09861
# [3]	validation_0-mlogloss:1.09861
# [4]	validation_0-mlogloss:1.09860
# [5]	validation_0-mlogloss:1.09860
# [6]	validation_0-mlogloss:1.09859
# [7]	validation_0-mlogloss:1.09859
# [8]	validation_0-mlogloss:1.09859
# [9]	validation_0-mlogloss:1.09858
# [10]	validation_0-mlogloss:1.09858
# [11]	validation_0-mlogloss:1.09858
# [12]	validation_0-mlogloss:1.09857
# [13]	validation_0-mlogloss:1.09857
# [14]	validation_0-mlogloss:1.09857
# [15]	validation_0-mlogloss:1.09857
# [16]	validation_0-mlogloss:1.09856
# [17]	validation_0-mlogloss:1.09856
# [18]	validation_0-mlogloss:1.09856
# [19]	validation_0-mlogloss:1.09855
# [20]	validation_0-mlogloss:1.09855
# [21]	validation_0-mlogloss:1.09855
# [22]	validation_0-mlogloss:1.09855
# [23]	validation_0-mlogloss:1.09854
# [24]	validation_0-mlogloss:1.09854
# [25]	validation_0-mlogloss:1.09854
# [26]	validation_0-mlogloss:1.09853
# [27]	validation_0-mlogloss:1.09853
# [28]	validation_0-mlogloss:1.09853
# [29]	validation_0-mlogloss:1.09852
# [30]	validation_0-mlogloss:1.09852
# [31]	validation_0-mlogloss:1.09852
# [32]	validation_0-mlogloss:1.09852
# [33]	validation_0-mlogloss:1.09851
# [34]	validation_0-mlogloss:1.09851
# [35]	validation_0-mlogloss:1.09851
# [36]	validation_0-mlogloss:1.09851
# [37]	validation_0-mlogloss:1.09851
# [38]	validation_0-mlogloss:1.09851
# [39]	validation_0-mlogloss:1.09850
# [40]	validation_0-mlogloss:1.09850
# [41]	validation_0-mlogloss:1.09850
# [42]	validation_0-mlogloss:1.09850
# [43]	validation_0-mlogloss:1.09850
# [44]	validation_0-mlogloss:1.09849
# [45]	validation_0-mlogloss:1.09849
# [46]	validation_0-mlogloss:1.09849
# [47]	validation_0-mlogloss:1.09848
# [48]	validation_0-mlogloss:1.09848
# [49]	validation_0-mlogloss:1.09848
# [50]	validation_0-mlogloss:1.09848
# [51]	validation_0-mlogloss:1.09847
# [52]	validation_0-mlogloss:1.09847
# [53]	validation_0-mlogloss:1.09847
# [54]	validation_0-mlogloss:1.09847
# [55]	validation_0-mlogloss:1.09847
# [56]	validation_0-mlogloss:1.09846
# [57]	validation_0-mlogloss:1.09846
# [58]	validation_0-mlogloss:1.09846
# [59]	validation_0-mlogloss:1.09846
# [60]	validation_0-mlogloss:1.09846
# [61]	validation_0-mlogloss:1.09846
# [62]	validation_0-mlogloss:1.09846
# [63]	validation_0-mlogloss:1.09846
# [64]	validation_0-mlogloss:1.09846
# [65]	validation_0-mlogloss:1.09846
# [66]	validation_0-mlogloss:1.09846
# [67]	validation_0-mlogloss:1.09846
# [68]	validation_0-mlogloss:1.09846
# [69]	validation_0-mlogloss:1.09846
# [70]	validation_0-mlogloss:1.09846
# [71]	validation_0-mlogloss:1.09845
# [72]	validation_0-mlogloss:1.09845
# [73]	validation_0-mlogloss:1.09845
# [74]	validation_0-mlogloss:1.09845
# [75]	validation_0-mlogloss:1.09844
# [76]	validation_0-mlogloss:1.09844
# [77]	validation_0-mlogloss:1.09844
# [78]	validation_0-mlogloss:1.09844
# [79]	validation_0-mlogloss:1.09844
# [80]	validation_0-mlogloss:1.09843
# [81]	validation_0-mlogloss:1.09843
# [82]	validation_0-mlogloss:1.09843
# [83]	validation_0-mlogloss:1.09843
# [84]	validation_0-mlogloss:1.09843
# [85]	validation_0-mlogloss:1.09843
# [86]	validation_0-mlogloss:1.09842
# [87]	validation_0-mlogloss:1.09842
# [88]	validation_0-mlogloss:1.09842
# [89]	validation_0-mlogloss:1.09841
# [90]	validation_0-mlogloss:1.09841
# [91]	validation_0-mlogloss:1.09841
# [92]	validation_0-mlogloss:1.09841
# [93]	validation_0-mlogloss:1.09841
# [94]	validation_0-mlogloss:1.09841
# [95]	validation_0-mlogloss:1.09841
# [96]	validation_0-mlogloss:1.09841
# [97]	validation_0-mlogloss:1.09841
# [98]	validation_0-mlogloss:1.09841
# [99]	validation_0-mlogloss:1.09841
# [100]	validation_0-mlogloss:1.09841
# [101]	validation_0-mlogloss:1.09841
# [102]	validation_0-mlogloss:1.09841
# [103]	validation_0-mlogloss:1.09840
# [104]	validation_0-mlogloss:1.09840
# [105]	validation_0-mlogloss:1.09840
# [106]	validation_0-mlogloss:1.09840
# [107]	validation_0-mlogloss:1.09840
# [108]	validation_0-mlogloss:1.09840
# [109]	validation_0-mlogloss:1.09840
# [110]	validation_0-mlogloss:1.09840
# [111]	validation_0-mlogloss:1.09839
# [112]	validation_0-mlogloss:1.09839
# [113]	validation_0-mlogloss:1.09839
# [114]	validation_0-mlogloss:1.09839
# [115]	validation_0-mlogloss:1.09839
# [116]	validation_0-mlogloss:1.09839
# [117]	validation_0-mlogloss:1.09839
# [118]	validation_0-mlogloss:1.09839
# [119]	validation_0-mlogloss:1.09839
# [120]	validation_0-mlogloss:1.09839
# [121]	validation_0-mlogloss:1.09838
# [122]	validation_0-mlogloss:1.09838
# [123]	validation_0-mlogloss:1.09838
# [124]	validation_0-mlogloss:1.09838
# [125]	validation_0-mlogloss:1.09838
# [126]	validation_0-mlogloss:1.09838
# [127]	validation_0-mlogloss:1.09838
# [128]	validation_0-mlogloss:1.09838
# [129]	validation_0-mlogloss:1.09838
# [130]	validation_0-mlogloss:1.09838
# [131]	validation_0-mlogloss:1.09838
# [132]	validation_0-mlogloss:1.09838
# [133]	validation_0-mlogloss:1.09838
# [134]	validation_0-mlogloss:1.09838
# [135]	validation_0-mlogloss:1.09837
# [136]	validation_0-mlogloss:1.09837
# [137]	validation_0-mlogloss:1.09837
# [138]	validation_0-mlogloss:1.09837
# [139]	validation_0-mlogloss:1.09837
# [140]	validation_0-mlogloss:1.09837
# [141]	validation_0-mlogloss:1.09837
# [142]	validation_0-mlogloss:1.09837
# [143]	validation_0-mlogloss:1.09837
# [144]	validation_0-mlogloss:1.09837
# [145]	validation_0-mlogloss:1.09837
# [146]	validation_0-mlogloss:1.09837
# [147]	validation_0-mlogloss:1.09837
# [148]	validation_0-mlogloss:1.09837
# [149]	validation_0-mlogloss:1.09836
# [150]	validation_0-mlogloss:1.09836
# [151]	validation_0-mlogloss:1.09836
# [152]	validation_0-mlogloss:1.09836
# [153]	validation_0-mlogloss:1.09836
# [154]	validation_0-mlogloss:1.09836
# [155]	validation_0-mlogloss:1.09836
# [156]	validation_0-mlogloss:1.09836
# [157]	validation_0-mlogloss:1.09836
# [158]	validation_0-mlogloss:1.09836
# [159]	validation_0-mlogloss:1.09835
# [160]	validation_0-mlogloss:1.09835
# [161]	validation_0-mlogloss:1.09835
# [162]	validation_0-mlogloss:1.09835
# [163]	validation_0-mlogloss:1.09835
# [164]	validation_0-mlogloss:1.09835
# [165]	validation_0-mlogloss:1.09835
# [166]	validation_0-mlogloss:1.09835
# [167]	validation_0-mlogloss:1.09835
# [168]	validation_0-mlogloss:1.09835
# [169]	validation_0-mlogloss:1.09835
# [170]	validation_0-mlogloss:1.09835
# [171]	validation_0-mlogloss:1.09835
# [172]	validation_0-mlogloss:1.09835
# [173]	validation_0-mlogloss:1.09835
# [174]	validation_0-mlogloss:1.09835
# [175]	validation_0-mlogloss:1.09835
# [176]	validation_0-mlogloss:1.09834
# [177]	validation_0-mlogloss:1.09834
# [178]	validation_0-mlogloss:1.09834
# [179]	validation_0-mlogloss:1.09834
# [180]	validation_0-mlogloss:1.09834
# [181]	validation_0-mlogloss:1.09834
# [182]	validation_0-mlogloss:1.09834
# [183]	validation_0-mlogloss:1.09834
# [184]	validation_0-mlogloss:1.09833
# [185]	validation_0-mlogloss:1.09833
# [186]	validation_0-mlogloss:1.09833
# [187]	validation_0-mlogloss:1.09833
# [188]	validation_0-mlogloss:1.09833
# [189]	validation_0-mlogloss:1.09833
# [190]	validation_0-mlogloss:1.09833
# [191]	validation_0-mlogloss:1.09833
# [192]	validation_0-mlogloss:1.09833
# [193]	validation_0-mlogloss:1.09833
# [194]	validation_0-mlogloss:1.09833
# [195]	validation_0-mlogloss:1.09833
# [196]	validation_0-mlogloss:1.09833
# [197]	validation_0-mlogloss:1.09833
# [198]	validation_0-mlogloss:1.09833
# [199]	validation_0-mlogloss:1.09833
# [200]	validation_0-mlogloss:1.09833
# [201]	validation_0-mlogloss:1.09833
# [202]	validation_0-mlogloss:1.09833
# [203]	validation_0-mlogloss:1.09833
# [204]	validation_0-mlogloss:1.09832
# [205]	validation_0-mlogloss:1.09832
# [206]	validation_0-mlogloss:1.09832
# [207]	validation_0-mlogloss:1.09832
# [208]	validation_0-mlogloss:1.09832
# [209]	validation_0-mlogloss:1.09832
# [210]	validation_0-mlogloss:1.09832
# [211]	validation_0-mlogloss:1.09832
# [212]	validation_0-mlogloss:1.09832
# [213]	validation_0-mlogloss:1.09832
# [214]	validation_0-mlogloss:1.09832
# [215]	validation_0-mlogloss:1.09832
# [216]	validation_0-mlogloss:1.09831
# [217]	validation_0-mlogloss:1.09831
# [218]	validation_0-mlogloss:1.09831
# [219]	validation_0-mlogloss:1.09831
# [220]	validation_0-mlogloss:1.09831
# [221]	validation_0-mlogloss:1.09831
# [222]	validation_0-mlogloss:1.09831
# [223]	validation_0-mlogloss:1.09831
# [224]	validation_0-mlogloss:1.09831
# [225]	validation_0-mlogloss:1.09831
# [226]	validation_0-mlogloss:1.09831
# [227]	validation_0-mlogloss:1.09831
# [228]	validation_0-mlogloss:1.09831
# [229]	validation_0-mlogloss:1.09831
# [230]	validation_0-mlogloss:1.09831
# [231]	validation_0-mlogloss:1.09831
# [232]	validation_0-mlogloss:1.09831
# [233]	validation_0-mlogloss:1.09831
# [234]	validation_0-mlogloss:1.09831
# [235]	validation_0-mlogloss:1.09831
# [236]	validation_0-mlogloss:1.09831
# [237]	validation_0-mlogloss:1.09831
# [238]	validation_0-mlogloss:1.09831
# [239]	validation_0-mlogloss:1.09831
# [240]	validation_0-mlogloss:1.09831
# [241]	validation_0-mlogloss:1.09831
# [242]	validation_0-mlogloss:1.09831
# [243]	validation_0-mlogloss:1.09831
# [244]	validation_0-mlogloss:1.09831
# [245]	validation_0-mlogloss:1.09830
# [246]	validation_0-mlogloss:1.09830
# [247]	validation_0-mlogloss:1.09830
# [248]	validation_0-mlogloss:1.09830
# [249]	validation_0-mlogloss:1.09830
# [250]	validation_0-mlogloss:1.09830
# [251]	validation_0-mlogloss:1.09830
# [252]	validation_0-mlogloss:1.09830
# [253]	validation_0-mlogloss:1.09830
# [254]	validation_0-mlogloss:1.09830
# [255]	validation_0-mlogloss:1.09830
# [256]	validation_0-mlogloss:1.09830
# [257]	validation_0-mlogloss:1.09830
# [258]	validation_0-mlogloss:1.09830
# [259]	validation_0-mlogloss:1.09830
# [260]	validation_0-mlogloss:1.09830
# [261]	validation_0-mlogloss:1.09830
# [262]	validation_0-mlogloss:1.09830
# [263]	validation_0-mlogloss:1.09830
# [264]	validation_0-mlogloss:1.09830
# [265]	validation_0-mlogloss:1.09830
# [266]	validation_0-mlogloss:1.09830
# [267]	validation_0-mlogloss:1.09829
# [268]	validation_0-mlogloss:1.09829
# [269]	validation_0-mlogloss:1.09829
# [270]	validation_0-mlogloss:1.09829
# [271]	validation_0-mlogloss:1.09829
# [272]	validation_0-mlogloss:1.09829
# [273]	validation_0-mlogloss:1.09829
# [274]	validation_0-mlogloss:1.09829
# [275]	validation_0-mlogloss:1.09829
# [276]	validation_0-mlogloss:1.09829
# [277]	validation_0-mlogloss:1.09830
# [278]	validation_0-mlogloss:1.09829
# [279]	validation_0-mlogloss:1.09830
# [280]	validation_0-mlogloss:1.09830
# [281]	validation_0-mlogloss:1.09829
# [282]	validation_0-mlogloss:1.09830
# [283]	validation_0-mlogloss:1.09829
# [284]	validation_0-mlogloss:1.09829
# [285]	validation_0-mlogloss:1.09829
# [286]	validation_0-mlogloss:1.09829
# [287]	validation_0-mlogloss:1.09829
# [288]	validation_0-mlogloss:1.09829
# [289]	validation_0-mlogloss:1.09829
# [290]	validation_0-mlogloss:1.09829
# [291]	validation_0-mlogloss:1.09829
# [292]	validation_0-mlogloss:1.09829
# [293]	validation_0-mlogloss:1.09829
# [294]	validation_0-mlogloss:1.09829
# [295]	validation_0-mlogloss:1.09829
# [296]	validation_0-mlogloss:1.09829
# [297]	validation_0-mlogloss:1.09829
# [298]	validation_0-mlogloss:1.09829
# [299]	validation_0-mlogloss:1.09828
# [300]	validation_0-mlogloss:1.09829
# [301]	validation_0-mlogloss:1.09829
# [302]	validation_0-mlogloss:1.09829
# [303]	validation_0-mlogloss:1.09829
# [304]	validation_0-mlogloss:1.09829
# [305]	validation_0-mlogloss:1.09828
# [306]	validation_0-mlogloss:1.09828
# [307]	validation_0-mlogloss:1.09828
# [308]	validation_0-mlogloss:1.09828
# [309]	validation_0-mlogloss:1.09828
# [310]	validation_0-mlogloss:1.09828
# [311]	validation_0-mlogloss:1.09828
# [312]	validation_0-mlogloss:1.09828
# [313]	validation_0-mlogloss:1.09828
# [314]	validation_0-mlogloss:1.09828
# [315]	validation_0-mlogloss:1.09828
# [316]	validation_0-mlogloss:1.09828
# [317]	validation_0-mlogloss:1.09828
# [318]	validation_0-mlogloss:1.09827
# [319]	validation_0-mlogloss:1.09828
# [320]	validation_0-mlogloss:1.09828
# [321]	validation_0-mlogloss:1.09827
# [322]	validation_0-mlogloss:1.09827
# [323]	validation_0-mlogloss:1.09827
# [324]	validation_0-mlogloss:1.09827
# [325]	validation_0-mlogloss:1.09827
# [326]	validation_0-mlogloss:1.09827
# [327]	validation_0-mlogloss:1.09827
# [328]	validation_0-mlogloss:1.09827
# [329]	validation_0-mlogloss:1.09827
# [330]	validation_0-mlogloss:1.09827
# [331]	validation_0-mlogloss:1.09827
# [332]	validation_0-mlogloss:1.09827
# [333]	validation_0-mlogloss:1.09827
# [334]	validation_0-mlogloss:1.09827
# [335]	validation_0-mlogloss:1.09827
# [336]	validation_0-mlogloss:1.09827
# [337]	validation_0-mlogloss:1.09827
# [338]	validation_0-mlogloss:1.09827
# [339]	validation_0-mlogloss:1.09827
# [340]	validation_0-mlogloss:1.09827
# [341]	validation_0-mlogloss:1.09827
# [342]	validation_0-mlogloss:1.09827
# [343]	validation_0-mlogloss:1.09828
# [344]	validation_0-mlogloss:1.09828
# [345]	validation_0-mlogloss:1.09828
# [346]	validation_0-mlogloss:1.09828
# [347]	validation_0-mlogloss:1.09828
# [348]	validation_0-mlogloss:1.09828
# [349]	validation_0-mlogloss:1.09828
# [350]	validation_0-mlogloss:1.09828
# [351]	validation_0-mlogloss:1.09828
# [352]	validation_0-mlogloss:1.09828
# [353]	validation_0-mlogloss:1.09828
# [354]	validation_0-mlogloss:1.09828
# [355]	validation_0-mlogloss:1.09827
# [356]	validation_0-mlogloss:1.09827
# [357]	validation_0-mlogloss:1.09827
# [358]	validation_0-mlogloss:1.09827
# [359]	validation_0-mlogloss:1.09827
# [360]	validation_0-mlogloss:1.09827
# [361]	validation_0-mlogloss:1.09827
# [362]	validation_0-mlogloss:1.09827
# [363]	validation_0-mlogloss:1.09827
# [364]	validation_0-mlogloss:1.09827
# [365]	validation_0-mlogloss:1.09828
# [366]	validation_0-mlogloss:1.09827
# Accuracy fold 3: 0.3413565725691474
# Fold 4
# [0]	validation_0-mlogloss:1.09861
# [1]	validation_0-mlogloss:1.09861
# [2]	validation_0-mlogloss:1.09860
# [3]	validation_0-mlogloss:1.09860
# [4]	validation_0-mlogloss:1.09860
# [5]	validation_0-mlogloss:1.09859
# [6]	validation_0-mlogloss:1.09859
# [7]	validation_0-mlogloss:1.09859
# [8]	validation_0-mlogloss:1.09859
# [9]	validation_0-mlogloss:1.09858
# [10]	validation_0-mlogloss:1.09858
# [11]	validation_0-mlogloss:1.09858
# [12]	validation_0-mlogloss:1.09858
# [13]	validation_0-mlogloss:1.09857
# [14]	validation_0-mlogloss:1.09857
# [15]	validation_0-mlogloss:1.09857
# [16]	validation_0-mlogloss:1.09856
# [17]	validation_0-mlogloss:1.09856
# [18]	validation_0-mlogloss:1.09856
# [19]	validation_0-mlogloss:1.09856
# [20]	validation_0-mlogloss:1.09856
# [21]	validation_0-mlogloss:1.09856
# [22]	validation_0-mlogloss:1.09855
# [23]	validation_0-mlogloss:1.09855
# [24]	validation_0-mlogloss:1.09854
# [25]	validation_0-mlogloss:1.09854
# [26]	validation_0-mlogloss:1.09854
# [27]	validation_0-mlogloss:1.09853
# [28]	validation_0-mlogloss:1.09853
# [29]	validation_0-mlogloss:1.09853
# [30]	validation_0-mlogloss:1.09853
# [31]	validation_0-mlogloss:1.09853
# [32]	validation_0-mlogloss:1.09853
# [33]	validation_0-mlogloss:1.09853
# [34]	validation_0-mlogloss:1.09853
# [35]	validation_0-mlogloss:1.09853
# [36]	validation_0-mlogloss:1.09853
# [37]	validation_0-mlogloss:1.09852
# [38]	validation_0-mlogloss:1.09852
# [39]	validation_0-mlogloss:1.09852
# [40]	validation_0-mlogloss:1.09852
# [41]	validation_0-mlogloss:1.09852
# [42]	validation_0-mlogloss:1.09852
# [43]	validation_0-mlogloss:1.09851
# [44]	validation_0-mlogloss:1.09851
# [45]	validation_0-mlogloss:1.09851
# [46]	validation_0-mlogloss:1.09851
# [47]	validation_0-mlogloss:1.09850
# [48]	validation_0-mlogloss:1.09850
# [49]	validation_0-mlogloss:1.09850
# [50]	validation_0-mlogloss:1.09850
# [51]	validation_0-mlogloss:1.09849
# [52]	validation_0-mlogloss:1.09849
# [53]	validation_0-mlogloss:1.09849
# [54]	validation_0-mlogloss:1.09849
# [55]	validation_0-mlogloss:1.09849
# [56]	validation_0-mlogloss:1.09849
# [57]	validation_0-mlogloss:1.09849
# [58]	validation_0-mlogloss:1.09848
# [59]	validation_0-mlogloss:1.09848
# [60]	validation_0-mlogloss:1.09848
# [61]	validation_0-mlogloss:1.09848
# [62]	validation_0-mlogloss:1.09847
# [63]	validation_0-mlogloss:1.09847
# [64]	validation_0-mlogloss:1.09847
# [65]	validation_0-mlogloss:1.09847
# [66]	validation_0-mlogloss:1.09847
# [67]	validation_0-mlogloss:1.09847
# [68]	validation_0-mlogloss:1.09847
# [69]	validation_0-mlogloss:1.09847
# [70]	validation_0-mlogloss:1.09847
# [71]	validation_0-mlogloss:1.09847
# [72]	validation_0-mlogloss:1.09846
# [73]	validation_0-mlogloss:1.09846
# [74]	validation_0-mlogloss:1.09846
# [75]	validation_0-mlogloss:1.09846
# [76]	validation_0-mlogloss:1.09846
# [77]	validation_0-mlogloss:1.09846
# [78]	validation_0-mlogloss:1.09845
# [79]	validation_0-mlogloss:1.09846
# [80]	validation_0-mlogloss:1.09846
# [81]	validation_0-mlogloss:1.09846
# [82]	validation_0-mlogloss:1.09846
# [83]	validation_0-mlogloss:1.09846
# [84]	validation_0-mlogloss:1.09846
# [85]	validation_0-mlogloss:1.09846
# [86]	validation_0-mlogloss:1.09846
# [87]	validation_0-mlogloss:1.09846
# [88]	validation_0-mlogloss:1.09845
# [89]	validation_0-mlogloss:1.09845
# [90]	validation_0-mlogloss:1.09845
# [91]	validation_0-mlogloss:1.09845
# [92]	validation_0-mlogloss:1.09845
# [93]	validation_0-mlogloss:1.09845
# [94]	validation_0-mlogloss:1.09845
# [95]	validation_0-mlogloss:1.09845
# [96]	validation_0-mlogloss:1.09844
# [97]	validation_0-mlogloss:1.09844
# [98]	validation_0-mlogloss:1.09844
# [99]	validation_0-mlogloss:1.09844
# [100]	validation_0-mlogloss:1.09844
# [101]	validation_0-mlogloss:1.09844
# [102]	validation_0-mlogloss:1.09844
# [103]	validation_0-mlogloss:1.09844
# [104]	validation_0-mlogloss:1.09844
# [105]	validation_0-mlogloss:1.09844
# [106]	validation_0-mlogloss:1.09843
# [107]	validation_0-mlogloss:1.09844
# [108]	validation_0-mlogloss:1.09843
# [109]	validation_0-mlogloss:1.09843
# [110]	validation_0-mlogloss:1.09843
# [111]	validation_0-mlogloss:1.09843
# [112]	validation_0-mlogloss:1.09843
# [113]	validation_0-mlogloss:1.09843
# [114]	validation_0-mlogloss:1.09843
# [115]	validation_0-mlogloss:1.09843
# [116]	validation_0-mlogloss:1.09843
# [117]	validation_0-mlogloss:1.09843
# [118]	validation_0-mlogloss:1.09843
# [119]	validation_0-mlogloss:1.09843
# [120]	validation_0-mlogloss:1.09843
# [121]	validation_0-mlogloss:1.09843
# [122]	validation_0-mlogloss:1.09843
# [123]	validation_0-mlogloss:1.09843
# [124]	validation_0-mlogloss:1.09842
# [125]	validation_0-mlogloss:1.09842
# [126]	validation_0-mlogloss:1.09842
# [127]	validation_0-mlogloss:1.09842
# [128]	validation_0-mlogloss:1.09842
# [129]	validation_0-mlogloss:1.09842
# [130]	validation_0-mlogloss:1.09842
# [131]	validation_0-mlogloss:1.09842
# [132]	validation_0-mlogloss:1.09842
# [133]	validation_0-mlogloss:1.09842
# [134]	validation_0-mlogloss:1.09841
# [135]	validation_0-mlogloss:1.09842
# [136]	validation_0-mlogloss:1.09841
# [137]	validation_0-mlogloss:1.09841
# [138]	validation_0-mlogloss:1.09841
# [139]	validation_0-mlogloss:1.09841
# [140]	validation_0-mlogloss:1.09841
# [141]	validation_0-mlogloss:1.09841
# [142]	validation_0-mlogloss:1.09841
# [143]	validation_0-mlogloss:1.09841
# [144]	validation_0-mlogloss:1.09841
# [145]	validation_0-mlogloss:1.09841
# [146]	validation_0-mlogloss:1.09841
# [147]	validation_0-mlogloss:1.09841
# [148]	validation_0-mlogloss:1.09841
# [149]	validation_0-mlogloss:1.09841
# [150]	validation_0-mlogloss:1.09841
# [151]	validation_0-mlogloss:1.09840
# [152]	validation_0-mlogloss:1.09840
# [153]	validation_0-mlogloss:1.09840
# [154]	validation_0-mlogloss:1.09840
# [155]	validation_0-mlogloss:1.09841
# [156]	validation_0-mlogloss:1.09841
# [157]	validation_0-mlogloss:1.09840
# [158]	validation_0-mlogloss:1.09840
# [159]	validation_0-mlogloss:1.09840
# [160]	validation_0-mlogloss:1.09840
# [161]	validation_0-mlogloss:1.09840
# [162]	validation_0-mlogloss:1.09840
# [163]	validation_0-mlogloss:1.09840
# [164]	validation_0-mlogloss:1.09840
# [165]	validation_0-mlogloss:1.09840
# [166]	validation_0-mlogloss:1.09841
# [167]	validation_0-mlogloss:1.09841
# [168]	validation_0-mlogloss:1.09841
# [169]	validation_0-mlogloss:1.09841
# [170]	validation_0-mlogloss:1.09841
# [171]	validation_0-mlogloss:1.09841
# [172]	validation_0-mlogloss:1.09841
# [173]	validation_0-mlogloss:1.09841
# [174]	validation_0-mlogloss:1.09841
# [175]	validation_0-mlogloss:1.09841
# [176]	validation_0-mlogloss:1.09840
# [177]	validation_0-mlogloss:1.09840
# [178]	validation_0-mlogloss:1.09841
# [179]	validation_0-mlogloss:1.09841
# [180]	validation_0-mlogloss:1.09841
# [181]	validation_0-mlogloss:1.09841
# [182]	validation_0-mlogloss:1.09841
# [183]	validation_0-mlogloss:1.09840
# [184]	validation_0-mlogloss:1.09841
# [185]	validation_0-mlogloss:1.09841
# [186]	validation_0-mlogloss:1.09841
# [187]	validation_0-mlogloss:1.09841
# [188]	validation_0-mlogloss:1.09841
# [189]	validation_0-mlogloss:1.09841
# [190]	validation_0-mlogloss:1.09841
# Accuracy fold 4: 0.34051183347590536

# %%
model_pipeline.predict(X_test_)
#oof_results
# Out:
# array([0, 2, 0, ..., 2, 0, 0], dtype=int32)

# %%
oof_results.iloc[idx_valid,:]
oof_results.iloc[idx_valid,:] = occ_preds.flatten().reshape(-1,1)

# %%
#occ_test_pred.loc[:,i] = model_pipeline.predict(X_test_)
occ_test_pred_xgb.tail(10)
#oof_results.head()
# Out:
#          0  1  2  3  4
# id
# 1999975  1  0  1  1  1
# 1999983  1  0  1  0  0
# 1999986  1  0  0  0  0
# 1999990  0  2  0  0  2
# 1999991  1  0  0  1  1
# 1999992  0  0  1  0  0
# 1999995  1  1  1  1  1
# 1999996  2  2  2  2  2
# 1999998  0  0  0  0  0
# 1999999  0  0  1  1  0

# %% [markdown]
# #### **Model Staked**

# %%
X_ = df[df.Occupation.isna()==False].copy()
X_test = df[df.Occupation.isna()==True].copy()

RANDOM_SEED=42

X_test = X_test.drop(columns=["Occupation","Premium Amount"])
X = X_.drop(columns=["Occupation","Premium Amount"])
y = X_["Occupation"].copy()

cv = KFold(FOLDS, shuffle=True, random_state=RANDOM_SEED)
accuracy_fold = []

# Initialize the Stack
occ_test_pred_stck = pd.DataFrame(index=X_test.index, columns=list(range(FOLDS)))

i=0

oof_results = pd.DataFrame(columns=["Occ_oof"], index=X.index)

for idx_train, idx_valid in cv.split(X, y):

    print(f"Fold {i}")

    # Split the data into training and validation sets for the current fold
    X_train, y_train = X.iloc[idx_train], y.iloc[idx_train].to_numpy().reshape(-1,1)
    X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid].to_numpy().reshape(-1,1)

    # Initialize the TabNet Regressor model
    early_stop = EarlyStopping(rounds=31, metric_name="mlogloss")

    estimators = [
        ('lgbm', LGBMClassifier(objective="multiclass",num_class=3, metric="multi_error", max_depth=10,reg_alpha=0.001,reg_lambda=0.001,
                               random_state=RANDOM_SEED, n_estimators=350,subsample=0.9, colsample_bytree=0.95, learning_rate=0.01)),
        ('xgb', XGBClassifier(learning_rate=0.01,objective ="multi:softmax",n_estimators=350,max_depth=10,min_child_weight=1,subsample=0.85,eval_metric='mlogloss',
                              colsample_bytree=0.9,enable_categorical="True",reg_lambda=0.001,reg_alpha=0.001)),
        ('catboost', CatBoostClassifier(iterations=500, learning_rate=0.01, depth=8, l2_leaf_reg=3, loss_function='MultiClass', eval_metric='Accuracy',
                           random_seed=RANDOM_SEED, subsample=0.85, bootstrap_type='Bernoulli'))
            ]

    meta_model = LogisticRegression(C=1.0,  solver="saga", random_state=RANDOM_SEED, max_iter=250)

    # Create StackingRegressor
    stacking_model = StackingClassifier(estimators=estimators, final_estimator=meta_model)

    model_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                                      ("model",stacking_model)])



    # Train the model using the training set and validate using the validation set
    if i >= 5:
        # Fit the StackingRegressor
        # model_pipeline[:-1].fit(X_train, y_train)
        # X_val_ = model_pipeline[:-1].transform(X_valid) # Transform X_val using the same steps as X
        # eval_set = [(X_val_, y_valid)]


        model_pipeline.fit(X_train, y_train)
        obj = sio.dump(model_pipeline, f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_occ_base2_{i}.skops")

    else:
        unknown_types = sio.get_untrusted_types(file=f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_occ_base2_{i}.skops")
        model_pipeline = sio.load(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_occ_base2_{i}.skops", trusted=unknown_types)

    occ_preds = model_pipeline.predict(X_valid)

    oof_results.iloc[idx_valid,:] = occ_preds.flatten().reshape(-1,1)

    # Prepare the test data and make predictions
    accuracy_ = accuracy_score(y_valid, occ_preds)
    accuracy_fold.append(accuracy_)
    print(f"Accuracy fold {i}: {accuracy_}")

    X_test_ = X_test.copy()

    # Aggregate the predictions across the 5 folds (averaging for ensemble)
    occ_test_pred_stck.loc[:,i] = model_pipeline.predict(X_test_) #[:, 0] / FOLDS
    i += 1

    #del model_pipeline, X_test_, X_train, y_train, X_valid, y_valid
    gc.collect()
# Out:
# Fold 0
# Accuracy fold 0: 0.3413672654690619
# Fold 1
# Accuracy fold 1: 0.34261833475905334
# Fold 2
# Accuracy fold 2: 0.3412888508696892
# Fold 3
# Accuracy fold 3: 0.3424080410607357
# Fold 4
# Accuracy fold 4: 0.34052609067579126

# %%
print(accuracy_fold)
# Out:
# [0.3413672654690619, 0.34261833475905334, 0.3412888508696892, 0.3424080410607357, 0.34052609067579126]

# %% [markdown]
# [0.3412674650698603, 0.3424222982606216, 0.34102152837182775, 0.3416595380667237, 0.34048688337610494]

# %%
X_.Occupation.value_counts()/X_.shape[0]
# Out:
# Occupation
# 0.0    0.335988
# 1.0    0.335498
# 2.0    0.328514
# Name: count, dtype: float64

# %%
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

fig, ax = plt.subplots(figsize=(5, 5))
disp = ConfusionMatrixDisplay.from_predictions(y.values, np.ravel(oof_results.values).astype(int), ax=ax, normalize="pred")
ax.grid()
#ax.xaxis.set_ticklabels(target_names)
#ax.yaxis.set_ticklabels(target_names)

# %% [markdown]
# #### **Replace Values**

# %%
df.loc[df.Occupation.isna()==True,"Occupation"]=occ_test_pred_stck.median(axis=1).values
df[df.Occupation.isna()==True]["Occupation"]
# Out:
# Series([], Name: Occupation, dtype: object)

# %%
df.isna().sum()/df.shape[0]
# Out:
# Age                     0.015597
# Gender                  0.000000
# Annual Income           0.037405
# Marital Status          0.015433
# Number of Dependents    0.091401
# Education Level         0.000000
# Occupation              0.000000
# Health Score            0.061762
# Location                0.000000
# Policy Type             0.000000
# Previous Claims         0.303416
# Vehicle Age             0.000005
# Credit Score            0.114667
# Insurance Duration      0.000002
# Policy Start Date       0.000000
# Customer Feedback       0.065050
# Smoking Status          0.000000
# Exercise Frequency      0.000000
# Property Type           0.000000
# Premium Amount          0.400000
# dtype: float64

# %%
df.to_csv("df_na_step_occ.csv", index=False)

# %% [markdown]
# ### **AGE**

# %%
np.log(df["Premium Amount"]).plot(kind="hist", bins=81, color="tomato", alpha=0.5)
plt.show()

# %% [markdown]
# #### **Model Staked**

# %%
categorical_cols = ['Gender', 'Marital Status', 'Education Level', 'Occupation', 'Location', 'Policy Type', 'Customer Feedback', 'Smoking Status', 'Exercise Frequency', 'Property Type']
numerical_cols_no_age = ['Annual Income', 'Health Score', 'Number of Dependents', 'Vehicle Age', 'Credit Score', 'Insurance Duration', 'Previous Claims', 'Policy Start Date']

# Preprocessing for categorical features: Imputation + OneHotEncoding
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('Ordinal', OrdinalEncoder())
])

# Preprocessing for numerical features: Imputation + Scaling
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# Combine both transformations
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_cols),
        ('num', numerical_transformer, numerical_cols_no_age)
    ],
    remainder='drop', # Drop any columns not specified in transformers
    verbose_feature_names_out=True)

# %%
X_ = df[df.Age.isna()==False].copy()
X_test = df[df.Age.isna()==True].copy()

X_[X_.select_dtypes(include="object").columns] = X_[X_.select_dtypes(include="object").columns].astype('category')
X_test[X_test.select_dtypes(include="object").columns] = X_test[X_test.select_dtypes(include="object").columns].astype('category')

print(X_.shape, X_test.shape)

RANDOM_SEED=42

X_test = X_test.drop(columns=["Age","Premium Amount"])
X = X_.drop(columns=["Age","Premium Amount"])
y = X_["Age"].copy()

cv = KFold(FOLDS, shuffle=True, random_state=RANDOM_SEED)
rmse_fold = []

# Initialize the Stack
occ_test_pred_stck = pd.DataFrame(index=X_test.index, columns=list(range(FOLDS)))

i=0

oof_results = pd.DataFrame(columns=["Occ_oof"], index=X.index)

for idx_train, idx_valid in cv.split(X, y):

    print(f"Fold {i}")

    # Split the data into training and validation sets for the current fold
    X_train, y_train = X.iloc[idx_train], y.iloc[idx_train].to_numpy().reshape(-1,1)
    X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid].to_numpy().reshape(-1,1)

    # Initialize the TabNet Regressor model
    early_stop = EarlyStopping(rounds=31, metric_name="mlogloss")

    estimators = [
        ('lgbm', LGBMRegressor(objective="root_mean_squared_error", metric="rmse", max_depth=8,reg_alpha=0.001,reg_lambda=0.001,
                               random_state=RANDOM_SEED, n_estimators=1000,subsample=0.8, colsample_bytree=0.8, learning_rate=0.01,
                               categorical_feature=list(range(len(categorical_cols))), num_leaves=41)),
        ('xgb', XGBRegressor(learning_rate=0.01,objective ="reg:squarederror",n_estimators=1000,max_depth=8,subsample=0.80,eval_metric='rmse',
                              colsample_bytree=0.8,enable_categorical="True",reg_lambda=0.001,reg_alpha=0.001)),
        ('catboost', CatBoostRegressor(iterations=1000, learning_rate=0.01, depth=8, l2_leaf_reg=5, loss_function='RMSE', eval_metric='RMSE',
                           random_seed=RANDOM_SEED, subsample=0.80, bootstrap_type='Bernoulli'))
            ]

    meta_model = Ridge(alpha=0.1, positive=True, random_state=42)

    # Create StackingRegressor
    stacking_model = StackingRegressor(estimators=estimators, final_estimator=meta_model)

    model_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                                      ("model",stacking_model)])



    # Train the model using the training set and validate using the validation set
    if i >= 0:
        # Fit the StackingRegressor
        # model_pipeline[:-1].fit(X_train, y_train)
        # X_val_ = model_pipeline[:-1].transform(X_valid) # Transform X_val using the same steps as X
        # eval_set = [(X_val_, y_valid)]


        model_pipeline.fit(X_train, y_train)
        obj = sio.dump(model_pipeline, f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_age_base_{i}.skops")

    else:
        unknown_types = sio.get_untrusted_types(file=f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_age_base_{i}.skops")
        model_pipeline = sio.load(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_age_base_{i}.skops", trusted=unknown_types)

    occ_preds = model_pipeline.predict(X_valid)

    oof_results.iloc[idx_valid,:] = occ_preds.flatten().reshape(-1,1)

    # Prepare the test data and make predictions
    rmse_ = root_mean_squared_error(y_valid, occ_preds)
    rmse_fold.append(rmse_)
    print(f"RMSE fold {i}: {rmse_fold}")

    X_test_ = X_test.copy()

    # Aggregate the predictions across the 5 folds (averaging for ensemble)
    occ_test_pred_stck.loc[:,i] = model_pipeline.predict(X_test_) #[:, 0] / FOLDS
    i += 1

    #del model_pipeline, X_test_, X_train, y_train, X_valid, y_valid
    gc.collect()

# %%
print(rmse_fold)
# Out:
# [13.5166173141823, 13.525517964335535, 13.51596244191206, 13.509187077604151, 13.510856367922406]

# %%
occ_test_pred_stck["average"] = np.round(occ_test_pred_stck.mean(axis=1).astype(float),0)

# %%
occ_test_pred_stck["average"].value_counts()
# Out:
# average
# 41.0    16177
# 42.0     8609
# 40.0     5081
# 43.0      769
# 39.0      494
# 44.0       30
# 38.0       29
# 37.0        2
# 45.0        1
# 36.0        1
# 35.0        1
# Name: count, dtype: int64

# %% [markdown]
# #### **Replace Values**

# %%
df.loc[df.Age.isna()==True,"Age"]=occ_test_pred_stck["average"].values
df[df.Age.isna()==True]["Age"]
# Out:
# Series([], Name: Age, dtype: float64)

# %%
#df.to_csv("df_na_step_age.csv", index=False)

df = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/df_na_step_age.csv")

categorical_cols = ['Gender', 'Marital Status', 'Education Level', 'Occupation', 'Location', 'Policy Type', 'Customer Feedback', 'Smoking Status', 'Exercise Frequency', 'Property Type']
numerical_cols_nodip = ['Age', 'Annual Income', 'Health Score', 'Vehicle Age', 'Credit Score', 'Insurance Duration', 'Previous Claims', 'Policy Start Date',"Number of Dependents"]

df[numerical_cols_nodip] = df[numerical_cols_nodip].astype(float)
df[categorical_cols] = df[categorical_cols].astype("category")

# %%
df.isna().sum()/df.shape[0]
# Out:
# Age                     0.000000
# Gender                  0.000000
# Annual Income           0.037405
# Marital Status          0.015433
# Number of Dependents    0.091401
# Education Level         0.000000
# Occupation              0.000000
# Health Score            0.061762
# Location                0.000000
# Policy Type             0.000000
# Previous Claims         0.303416
# Vehicle Age             0.000005
# Credit Score            0.114667
# Insurance Duration      0.000002
# Policy Start Date       0.000000
# Customer Feedback       0.065050
# Smoking Status          0.000000
# Exercise Frequency      0.000000
# Property Type           0.000000
# Premium Amount          0.400000
# dtype: float64

# %%
df.head()
# Out:
#     Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 0  19.0  Female        10049.0        Married                   1.0
# 1  39.0  Female        31678.0       Divorced                   3.0
# 2  23.0    Male        25602.0       Divorced                   3.0
# 3  21.0    Male       141855.0        Married                   2.0
# 4  21.0    Male        39651.0         Single                   1.0
#
#   Education Level Occupation  Health Score  Location    Policy Type  \
# 0      Bachelor's        1.0     22.598761     Urban        Premium
# 1        Master's        0.0     15.569731     Rural  Comprehensive
# 2     High School        1.0     47.177549  Suburban        Premium
# 3      Bachelor's        2.0     10.938144     Rural          Basic
# 4      Bachelor's        1.0     20.376094     Rural        Premium
#
#    Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 0              2.0         17.0         372.0                 5.0
# 1              1.0         12.0         694.0                 2.0
# 2              1.0         14.0           NaN                 3.0
# 3              1.0          0.0         367.0                 1.0
# 4              0.0          8.0         598.0                 4.0
#
#    Policy Start Date Customer Feedback Smoking Status Exercise Frequency  \
# 0           0.955634              Poor             No             Weekly
# 1           1.487141           Average            Yes            Monthly
# 2           1.185771              Good            Yes             Weekly
# 3           0.484401              Poor            Yes              Daily
# 4           3.015908              Poor            Yes             Weekly
#
#   Property Type  Premium Amount
# 0         House          2869.0
# 1         House          1483.0
# 2         House           567.0
# 3     Apartment           765.0
# 4         House          2022.0

# %%
df_train.head()
# Out:
#      Age  Gender  Annual Income Marital Status  Number of Dependents  \
# id
# 0   19.0  Female        10049.0        Married                   1.0
# 1   39.0  Female        31678.0       Divorced                   3.0
# 2   23.0    Male        25602.0       Divorced                   3.0
# 3   21.0    Male       141855.0        Married                   2.0
# 4   21.0    Male        39651.0         Single                   1.0
#
#    Education Level     Occupation  Health Score  Location    Policy Type  \
# id
# 0       Bachelor's  Self-Employed     22.598761     Urban        Premium
# 1         Master's            NaN     15.569731     Rural  Comprehensive
# 2      High School  Self-Employed     47.177549  Suburban        Premium
# 3       Bachelor's            NaN     10.938144     Rural          Basic
# 4       Bachelor's  Self-Employed     20.376094     Rural        Premium
#
#     Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# id
# 0               2.0         17.0         372.0                 5.0
# 1               1.0         12.0         694.0                 2.0
# 2               1.0         14.0           NaN                 3.0
# 3               1.0          0.0         367.0                 1.0
# 4               0.0          8.0         598.0                 4.0
#
#     Policy Start Date Customer Feedback Smoking Status Exercise Frequency  \
# id
# 0            0.957233              Poor             No             Weekly
# 1            1.488740           Average            Yes            Monthly
# 2            1.187370              Good            Yes             Weekly
# 3            0.486000              Poor            Yes              Daily
# 4            3.017507              Poor            Yes             Weekly
#
#    Property Type  Premium Amount
# id
# 0          House          2869.0
# 1          House          1483.0
# 2          House           567.0
# 3      Apartment           765.0
# 4          House          2022.0

# %%
df["Age"].plot(kind="hist", bins=81, color="tomato", alpha=0.5)
#df["Age"].plot(kind="hist", bins=81, color="royalblue", alpha=1.0)
plt.show()

# %% [markdown]
# ### **Number of Dependents**

# %%
df["Number of Dependents"].plot(kind="hist", bins=81, color="tomato", alpha=0.5)
plt.show()

# %% [markdown]
# #### **Model Staked**

# %%
categorical_cols = ['Gender', 'Marital Status', 'Education Level', 'Occupation', 'Location', 'Policy Type', 'Customer Feedback', 'Smoking Status', 'Exercise Frequency', 'Property Type']
numerical_cols_nodip = ['Age', 'Annual Income', 'Health Score', 'Vehicle Age', 'Credit Score', 'Insurance Duration', 'Previous Claims', 'Policy Start Date']

# Preprocessing for categorical features: Imputation + OneHotEncoding
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('Ordinal', OrdinalEncoder())
])

# Preprocessing for numerical features: Imputation + Scaling
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# Combine both transformations
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_cols),
        ('num', numerical_transformer, numerical_cols_nodip)
    ],
    remainder='drop', # Drop any columns not specified in transformers
    verbose_feature_names_out=True)

# %%
X_ = df[df["Number of Dependents"].isna()==False].copy()
X_test = df[df["Number of Dependents"].isna()==True].copy()

X_[X_.select_dtypes(include="object").columns] = X_[X_.select_dtypes(include="object").columns].astype('category')
X_test[X_test.select_dtypes(include="object").columns] = X_test[X_test.select_dtypes(include="object").columns].astype('category')

print(X_.shape, X_test.shape)

RANDOM_SEED=42

X_test = X_test.drop(columns=["Number of Dependents","Premium Amount"])
X = X_.drop(columns=["Number of Dependents","Premium Amount"])
y = X_["Number of Dependents"].copy()

cv = KFold(FOLDS, shuffle=True, random_state=RANDOM_SEED)
rmse_fold = []

# Initialize the Stack
occ_test_pred_stck = pd.DataFrame(index=X_test.index, columns=list(range(FOLDS)))

i=0

oof_results = pd.DataFrame(columns=["dip_oof"], index=X.index)

for idx_train, idx_valid in cv.split(X, y):

    print(f"Fold {i}")

    # Split the data into training and validation sets for the current fold
    X_train, y_train = X.iloc[idx_train], y.iloc[idx_train].to_numpy().reshape(-1,1)
    X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid].to_numpy().reshape(-1,1)

    # Initialize the TabNet Regressor model
    estimators = [
        ('lgbm', LGBMClassifier(objective="multiclass",num_class=5, metric="multi_error", max_depth=8,reg_alpha=0.001,reg_lambda=0.001,
                               random_state=RANDOM_SEED, n_estimators=1000,subsample=0.8, colsample_bytree=0.8, learning_rate=0.01,
                               categorical_feature=list(range(len(categorical_cols))), num_leaves=41)),
        ('xgb', XGBClassifier(learning_rate=0.01,objective ="multi:softmax",n_estimators=1000,max_depth=8,subsample=0.80,eval_metric='mlogloss',
                              colsample_bytree=0.8,enable_categorical="True",reg_lambda=0.001,reg_alpha=0.001)),
        ('catboost', CatBoostClassifier(iterations=1000, learning_rate=0.01, depth=8, l2_leaf_reg=5, loss_function='MultiClass', eval_metric='Accuracy',
                           random_seed=RANDOM_SEED, subsample=0.80, bootstrap_type='Bernoulli'))
            ]

    meta_model = LogisticRegression(C=1.0,  solver="saga", random_state=RANDOM_SEED, max_iter=250)

    # Create StackingRegressor
    stacking_model = StackingClassifier(estimators=estimators, final_estimator=meta_model)

    model_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                                      ("model",stacking_model)])


    # Train the model using the training set and validate using the validation set
    if i >= 0:
        # Fit the StackingRegressor
        # model_pipeline[:-1].fit(X_train, y_train)
        # X_val_ = model_pipeline[:-1].transform(X_valid) # Transform X_val using the same steps as X
        # eval_set = [(X_val_, y_valid)]


        model_pipeline.fit(X_train, y_train)
        obj = sio.dump(model_pipeline, f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_dip_base_{i}.skops")

    else:
        unknown_types = sio.get_untrusted_types(file=f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_dip_base_{i}.skops")
        model_pipeline = sio.load(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_dip_base_{i}.skops", trusted=unknown_types)

    occ_preds = model_pipeline.predict(X_valid)

    oof_results.iloc[idx_valid,:] = occ_preds.flatten().reshape(-1,1)

    # Prepare the test data and make predictions
    accuracy_ = accuracy_score(y_valid, occ_preds)
    accuracy_fold.append(accuracy_)
    print(f"Accuracy fold {i}: {accuracy_}")

    X_test_ = X_test.copy()

    # Aggregate the predictions across the 5 folds (averaging for ensemble)
    occ_test_pred_stck.loc[:,i] = model_pipeline.predict(X_test_) #[:, 0] / FOLDS
    i += 1

    #del model_pipeline, X_test_, X_train, y_train, X_valid, y_valid
    gc.collect()
# Out:
# Streaming output truncated to the last 5000 lines.
# 385:	learn: 0.2417862	total: 3m 29s	remaining: 5m 33s
# 386:	learn: 0.2418128	total: 3m 29s	remaining: 5m 32s
# 387:	learn: 0.2418214	total: 3m 30s	remaining: 5m 32s
# 388:	learn: 0.2419169	total: 3m 31s	remaining: 5m 31s
# 389:	learn: 0.2419564	total: 3m 31s	remaining: 5m 30s
# 390:	learn: 0.2419925	total: 3m 32s	remaining: 5m 30s
# 391:	learn: 0.2420673	total: 3m 32s	remaining: 5m 29s
# 392:	learn: 0.2421009	total: 3m 33s	remaining: 5m 29s
# 45.0        1
# 36.0        1
# 35.0        1
# Name: count, dtype: int64

# %% [markdown]
# #### **Replace Values**

# %%
df.loc[df["Number of Dependents"].isna()==True,"Number of Dependents"]=occ_test_pred_stck.median(axis=1).values
df[df["Number of Dependents"].isna()==True]["Number of Dependents"]
# Out:
# Series([], Name: Age, dtype: float64)

# %%
#df.to_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/df_na_step_dip.csv", index=False)
df = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/df_na_step_dip.csv")

# %%
df.isna().sum()/df.shape[0]
# Out:
# Age                     0.000000
# Gender                  0.000000
# Annual Income           0.037405
# Marital Status          0.015433
# Number of Dependents    0.000000
# Education Level         0.000000
# Occupation              0.000000
# Health Score            0.061762
# Location                0.000000
# Policy Type             0.000000
# Previous Claims         0.303416
# Vehicle Age             0.000005
# Credit Score            0.114667
# Insurance Duration      0.000002
# Policy Start Date       0.000000
# Customer Feedback       0.065050
# Smoking Status          0.000000
# Exercise Frequency      0.000000
# Property Type           0.000000
# Premium Amount          0.400000
# dtype: float64

# %% [markdown]
# ### **Customer Feedback**

# %%
print(df["Customer Feedback"].unique())

le=OrdinalEncoder()
df["Customer Feedback"] = le.fit_transform(df[["Customer Feedback"]])

print(df["Customer Feedback"].unique())
# Out:
# ['Poor' 'Average' 'Good' nan]
# [ 2.  0.  1. nan]

# %%
df["Customer Feedback"].plot(kind="hist", bins=81, color="tomato", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Data columns (total 20 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Age                   float64
#  1   Gender                object
#  2   Annual Income         float64
#  3   Marital Status        object
#  4   Number of Dependents  float64
#  5   Education Level       object
#  6   Occupation            float64
#  7   Health Score          float64
#  8   Location              object
#  9   Policy Type           object
#  10  Previous Claims       float64
#  11  Vehicle Age           float64
#  12  Credit Score          float64
#  13  Insurance Duration    float64
#  14  Policy Start Date     float64
#  15  Customer Feedback     float64
#  16  Smoking Status        object
#  17  Exercise Frequency    object
#  18  Property Type         object
#  19  Premium Amount        float64
# dtypes: float64(12), object(8)
# memory usage: 305.2+ MB

# %% [markdown]
# #### **Model Staked**

# %%
categorical_cols_nocf = ['Gender', 'Marital Status', 'Education Level', 'Occupation', 'Location', 'Policy Type', 'Smoking Status', 'Exercise Frequency', 'Property Type']
numerical_cols = ['Age', 'Annual Income', 'Health Score', 'Vehicle Age', 'Credit Score', 'Insurance Duration', 'Previous Claims', 'Policy Start Date']

# Preprocessing for categorical features: Imputation + OneHotEncoding
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('Ordinal', OrdinalEncoder())
])

# Preprocessing for numerical features: Imputation + Scaling
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# Combine both transformations
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_cols_nocf),
        ('num', numerical_transformer, numerical_cols)
    ],
    remainder='drop', # Drop any columns not specified in transformers
    verbose_feature_names_out=True)

# %%
X_ = df[df["Customer Feedback"].isna()==False].copy()
X_test = df[df["Customer Feedback"].isna()==True].copy()

X_[X_.select_dtypes(include="object").columns] = X_[X_.select_dtypes(include="object").columns].astype('category')
X_test[X_test.select_dtypes(include="object").columns] = X_test[X_test.select_dtypes(include="object").columns].astype('category')

print(X_.shape, X_test.shape)

RANDOM_SEED=42
FOLDS=5

X_test = X_test.drop(columns=["Customer Feedback","Premium Amount"])
X = X_.drop(columns=["Customer Feedback","Premium Amount"])
y = X_["Customer Feedback"].copy()

cv = KFold(FOLDS, shuffle=True, random_state=RANDOM_SEED)
accuracy_fold = []

# Initialize the Stack
occ_test_pred_stck = pd.DataFrame(index=X_test.index, columns=list(range(FOLDS)))

i=0

oof_results = pd.DataFrame(columns=["cfb_oof"], index=X.index)

for idx_train, idx_valid in cv.split(X, y):

    print(f"Fold {i}")

    # Split the data into training and validation sets for the current fold
    X_train, y_train = X.iloc[idx_train], y.iloc[idx_train].to_numpy().reshape(-1,1)
    X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid].to_numpy().reshape(-1,1)

    # Initialize the TabNet Regressor model
    estimators = [
        ('lgbm', LGBMClassifier(objective="multiclass",num_class=3, metric="multi_error", max_depth=8,reg_alpha=0.001,reg_lambda=0.001,
                               random_state=RANDOM_SEED, n_estimators=1000,subsample=0.8, colsample_bytree=0.8, learning_rate=0.01,
                               categorical_feature=list(range(len(categorical_cols))), num_leaves=41)),
        ('xgb', XGBClassifier(learning_rate=0.01,objective ="multi:softmax",n_estimators=1000,max_depth=8,subsample=0.80,eval_metric='mlogloss',
                              colsample_bytree=0.8,enable_categorical="True",reg_lambda=0.001,reg_alpha=0.001)),
        ('catboost', CatBoostClassifier(iterations=1000, learning_rate=0.01, depth=8, l2_leaf_reg=5, loss_function='MultiClass', eval_metric='Accuracy',
                           random_seed=RANDOM_SEED, subsample=0.80, bootstrap_type='Bernoulli'))
            ]

    meta_model = LogisticRegression(C=1.0,  solver="saga", random_state=RANDOM_SEED, max_iter=250)

    # Create StackingRegressor
    stacking_model = StackingClassifier(estimators=estimators, final_estimator=meta_model)

    model_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                                      ("model",stacking_model)])


    # Train the model using the training set and validate using the validation set
    if i >= 0:
        # Fit the StackingRegressor
        # model_pipeline[:-1].fit(X_train, y_train)
        # X_val_ = model_pipeline[:-1].transform(X_valid) # Transform X_val using the same steps as X
        # eval_set = [(X_val_, y_valid)]


        model_pipeline.fit(X_train, y_train)
        obj = sio.dump(model_pipeline, f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_cf_base_{i}.skops")

    else:
        unknown_types = sio.get_untrusted_types(file=f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_cf_base_{i}.skops")
        model_pipeline = sio.load(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_cf_base_{i}.skops", trusted=unknown_types)

    occ_preds = model_pipeline.predict(X_valid)

    oof_results.iloc[idx_valid,:] = occ_preds.flatten().reshape(-1,1)

    # Prepare the test data and make predictions
    accuracy_ = accuracy_score(y_valid, occ_preds)
    accuracy_fold.append(accuracy_)
    print(f"Accuracy fold {i}: {accuracy_}")

    X_test_ = X_test.copy()

    # Aggregate the predictions across the 5 folds (averaging for ensemble)
    occ_test_pred_stck.loc[:,i] = model_pipeline.predict(X_test_) #[:, 0] / FOLDS
    i += 1

    #del model_pipeline, X_test_, X_train, y_train, X_valid, y_valid
# %%
print(accuracy_fold)
# Out:
# [0.3469115995507781, 0.3470586662388363, 0.3482138082250388, 0.3472485159634205, 0.3476656505695492]

# %%
occ_test_pred_stck.median(axis=1).value_counts()
# Out:
# 0.0    47780
# 2.0    45909
# 1.0    36411
# Name: count, dtype: int64

# %% [markdown]
# #### **Replace Values**

# %%
df.loc[df["Customer Feedback"].isna()==True,"Customer Feedback"]=occ_test_pred_stck.median(axis=1).values
df[df["Customer Feedback"].isna()==True]["Customer Feedback"]
# Out:
# Series([], Name: Customer Feedback, dtype: object)

# %%
#df.to_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/df_na_step_cf.csv", index=False)
df = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/df_na_step_cf.csv")

# %%
df.isna().sum()/df.shape[0]
# Out:
# Age                     0.000000
# Gender                  0.000000
# Annual Income           0.037405
# Marital Status          0.015433
# Number of Dependents    0.000000
# Education Level         0.000000
# Occupation              0.000000
# Health Score            0.061762
# Location                0.000000
# Policy Type             0.000000
# Previous Claims         0.303416
# Vehicle Age             0.000005
# Credit Score            0.114667
# Insurance Duration      0.000002
# Policy Start Date       0.000000
# Customer Feedback       0.000000
# Smoking Status          0.000000
# Exercise Frequency      0.000000
# Property Type           0.000000
# Premium Amount          0.400000
# dtype: float64

# %% [markdown]
# ### **Previous Claims**

# %%
df[categorical_cols] = df[categorical_cols].astype("category")
print(df["Previous Claims"].unique())

#le=OrdinalEncoder()
#df["Previous Claims"] = le.fit_transform(df[["Previous Claims"]])

#print(df["Previous Claims"].unique())
# Out:
# [ 2.  1.  0. nan  3.  4.  5.  6.  7.  8.  9.]

# %%
df["Previous Claims"].plot(kind="hist", bins=81, color="tomato", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Data columns (total 20 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Age                   float64
#  1   Gender                category
#  2   Annual Income         float64
#  3   Marital Status        category
#  4   Number of Dependents  float64
#  5   Education Level       category
#  6   Occupation            category
#  7   Health Score          float64
#  8   Location              category
#  9   Policy Type           category
#  10  Previous Claims       float64
#  11  Vehicle Age           float64
#  12  Credit Score          float64
#  13  Insurance Duration    float64
#  14  Policy Start Date     float64
#  15  Customer Feedback     category
#  16  Smoking Status        category
#  17  Exercise Frequency    category
#  18  Property Type         category
#  19  Premium Amount        float64
# dtypes: category(10), float64(10)
# memory usage: 171.7 MB

# %% [markdown]
# #### **Model Staked**

# %%
categorical_cols_nopc = ['Gender', 'Marital Status', 'Education Level', 'Occupation', 'Location', 'Policy Type', 'Smoking Status', 'Exercise Frequency', 'Property Type', 'Customer Feedback']
numerical_cols = ['Age', 'Annual Income', 'Health Score', 'Vehicle Age', 'Credit Score', 'Insurance Duration', 'Policy Start Date']

# Preprocessing for categorical features: Imputation + OneHotEncoding
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('Ordinal', OrdinalEncoder())
])

# Preprocessing for numerical features: Imputation + Scaling
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# Combine both transformations
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_cols_nopc),
        ('num', numerical_transformer, numerical_cols)
    ],
    remainder='drop', # Drop any columns not specified in transformers
    verbose_feature_names_out=True)

# %%
X_ = df[df["Previous Claims"].isna()==False].copy()
X_test = df[df["Previous Claims"].isna()==True].copy()

X_[X_.select_dtypes(include="object").columns] = X_[X_.select_dtypes(include="object").columns].astype('category')
X_test[X_test.select_dtypes(include="object").columns] = X_test[X_test.select_dtypes(include="object").columns].astype('category')

print(X_.shape, X_test.shape)

RANDOM_SEED=42
FOLDS=5

X_test = X_test.drop(columns=["Previous Claims","Premium Amount"])
X = X_.drop(columns=["Previous Claims","Premium Amount"])
y = X_["Previous Claims"].copy()

cv = KFold(FOLDS, shuffle=True, random_state=RANDOM_SEED)
accuracy_fold = []

# Initialize the Stack
occ_test_pred_stck = pd.DataFrame(index=X_test.index, columns=list(range(FOLDS)))

i=0

oof_results = pd.DataFrame(columns=["pc_oof"], index=X.index)

for idx_train, idx_valid in cv.split(X, y):

    print(f"Fold {i}")

    # Split the data into training and validation sets for the current fold
    X_train, y_train = X.iloc[idx_train], y.iloc[idx_train].to_numpy().reshape(-1,1)
    X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid].to_numpy().reshape(-1,1)

    # Initialize the TabNet Regressor model
    estimators = [
        ('lgbm', LGBMClassifier(objective='multiclass',num_class=10,metric='multi_error',boosting_type='gbdt',
                                num_leaves=31,max_depth=6,learning_rate=0.05,n_estimators=250,subsample=0.8,
                                colsample_bytree=0.8,reg_alpha=0.1,reg_lambda=0.1,categorical_feature=list(range(len(categorical_cols_nopc))),
                                n_jobs=-1,random_state=RANDOM_SEED)),
        ('xgb', XGBClassifier(objective='multi:softmax', num_class=10, eval_metric='mlogloss', n_estimators=250,learning_rate=0.05,
                              max_depth=7, subsample=0.80,colsample_bytree=0.80,enable_categorical="True",reg_lambda=0.1,reg_alpha=0.1)),
        ('catboost', CatBoostClassifier(iterations=250, learning_rate=0.05, depth=7, l2_leaf_reg=3, loss_function='MultiClass', eval_metric='Accuracy',
                           random_seed=RANDOM_SEED, subsample=0.80, bootstrap_type='Bernoulli'))
            ]

    meta_model = LogisticRegression(C=1.0,  solver="saga", random_state=RANDOM_SEED, max_iter=250)

    # Create StackingRegressor
    stacking_model = StackingClassifier(estimators=estimators, final_estimator=meta_model)

    model_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                                      ("model",stacking_model)])


    # Train the model using the training set and validate using the validation set
    if i >= 0:
        # Fit the StackingRegressor
        # model_pipeline[:-1].fit(X_train, y_train)
        # X_val_ = model_pipeline[:-1].transform(X_valid) # Transform X_val using the same steps as X
        # eval_set = [(X_val_, y_valid)]


        model_pipeline.fit(X_train, y_train)
        obj = sio.dump(model_pipeline, f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_pc_base_{i}.skops")

    else:
        unknown_types = sio.get_untrusted_types(file=f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_pc_base_{i}.skops")
        model_pipeline = sio.load(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_pc_base_{i}.skops", trusted=unknown_types)

    occ_preds = model_pipeline.predict(X_valid)

    oof_results.iloc[idx_valid,:] = occ_preds.flatten().reshape(-1,1)

    # Prepare the test data and make predictions
    accuracy_ = accuracy_score(y_valid, occ_preds)
    accuracy_fold.append(accuracy_)
    print(f"Accuracy fold {i}: {accuracy_}")

    X_test_ = X_test.copy()

    # Aggregate the predictions across the 5 folds (averaging for ensemble)
    occ_test_pred_stck.loc[:,i] = model_pipeline.predict(X_test_) #[:, 0] / FOLDS
    i += 1

    #del model_pipeline, X_test_, X_train, y_train, X_valid, y_valid
    gc.collect()
# Out:
# Streaming output truncated to the last 5000 lines.
# 112:	learn: 0.3912426	total: 57.7s	remaining: 1m 9s
# 113:	learn: 0.3913979	total: 58.2s	remaining: 1m 9s
# 114:	learn: 0.3914992	total: 58.7s	remaining: 1m 8s
# 115:	learn: 0.3914705	total: 59.2s	remaining: 1m 8s
# 116:	learn: 0.3914499	total: 59.7s	remaining: 1m 7s
# 117:	learn: 0.3916069	total: 1m	remaining: 1m 7s
# 118:	learn: 0.3915836	total: 1m	remaining: 1m 6s
# 119:	learn: 0.3916796	total: 1m 1s	remaining: 1m 6s
# 120:	learn: 0.3917442	total: 1m 1s	remaining: 1m 5s
# 121:	learn: 0.3918088	total: 1m 2s	remaining: 1m 5s
# 122:	learn: 0.3918276	total: 1m 2s	remaining: 1m 4s
# 123:	learn: 0.3919326	total: 1m 3s	remaining: 1m 4s
# 124:	learn: 0.3920044	total: 1m 3s	remaining: 1m 3s
# 125:	learn: 0.3920798	total: 1m 4s	remaining: 1m 3s
# 126:	learn: 0.3921668	total: 1m 4s	remaining: 1m 2s
# 127:	learn: 0.3922107	total: 1m 5s	remaining: 1m 2s
# 128:	learn: 0.3923723	total: 1m 6s	remaining: 1m 1s
# 129:	learn: 0.3923337	total: 1m 6s	remaining: 1m 1s
# 130:	learn: 0.3922960	total: 1m 7s	remaining: 1m
# 131:	learn: 0.3924162	total: 1m 7s	remaining: 1m
# 132:	learn: 0.3924674	total: 1m 8s	remaining: 59.8s
# 133:	learn: 0.3924521	total: 1m 8s	remaining: 59.3s
# 134:	learn: 0.3925158	total: 1m 9s	remaining: 58.8s
# 135:	learn: 0.3926333	total: 1m 9s	remaining: 58.3s
# 136:	learn: 0.3926459	total: 1m 10s	remaining: 57.7s
# 137:	learn: 0.3927527	total: 1m 10s	remaining: 57.2s
# 138:	learn: 0.3928433	total: 1m 11s	remaining: 56.7s
# 139:	learn: 0.3929187	total: 1m 11s	remaining: 56.2s
# 140:	learn: 0.3929232	total: 1m 11s	remaining: 55.7s
# 141:	learn: 0.3929644	total: 1m 12s	remaining: 55.1s
# 142:	learn: 0.3930389	total: 1m 12s	remaining: 54.6s
# 143:	learn: 0.3931591	total: 1m 13s	remaining: 54.1s
# 144:	learn: 0.3932713	total: 1m 13s	remaining: 53.6s
# 145:	learn: 0.3932820	total: 1m 14s	remaining: 53s
# 146:	learn: 0.3933700	total: 1m 14s	remaining: 52.5s
# 147:	learn: 0.3934373	total: 1m 15s	remaining: 52s
# 148:	learn: 0.3933861	total: 1m 16s	remaining: 51.5s
# 149:	learn: 0.3933655	total: 1m 16s	remaining: 51s
# 150:	learn: 0.3934418	total: 1m 17s	remaining: 50.6s
# 151:	learn: 0.3935629	total: 1m 17s	remaining: 50.1s
# 249:	learn: 0.4021908	total: 1m 42s	remaining: 0us
# Accuracy fold 4: 0.38773942784953686

# %%
print(accuracy_fold)
# Out:
# [0.38776315883919404, 0.3881435862098667, 0.38760165665353113, 0.3880395070235506, 0.38773942784953686]

# %%
occ_test_pred_stck.median(axis=1).value_counts()
# Out:
# 0.0    347503
# 1.0    185167
# 2.0     74157
# 3.0         4
# Name: count, dtype: int64

# %% [markdown]
# #### **Replace Values**

# %%
df.loc[df["Previous Claims"].isna()==True,"Previous Claims"]=occ_test_pred_stck.median(axis=1).values
df[df["Previous Claims"].isna()==True]["Previous Claims"]
# Out:
# Series([], Name: Previous Claims, dtype: object)

# %%
#df.to_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/df_na_step_pc.csv", index=False)
df = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/df_na_step_pc.csv")

# %%
df.isna().sum()/df.shape[0]
# Out:
# Age                     0.000000
# Gender                  0.000000
# Annual Income           0.037405
# Marital Status          0.015433
# Number of Dependents    0.000000
# Education Level         0.000000
# Occupation              0.000000
# Health Score            0.061762
# Location                0.000000
# Policy Type             0.000000
# Previous Claims         0.000000
# Vehicle Age             0.000005
# Credit Score            0.114667
# Insurance Duration      0.000002
# Policy Start Date       0.000000
# Customer Feedback       0.000000
# Smoking Status          0.000000
# Exercise Frequency      0.000000
# Property Type           0.000000
# Premium Amount          0.400000
# dtype: float64

# %% [markdown]
# ### **Health Score**

# %%
categorical_cols = ['Gender', 'Marital Status', 'Education Level', 'Occupation', 'Location', 'Policy Type', 'Customer Feedback', 'Smoking Status', 'Exercise Frequency', 'Previous Claims', 'Property Type']
numerical_cols = ['Age', 'Annual Income', 'Health Score', 'Vehicle Age', 'Credit Score', 'Insurance Duration', 'Policy Start Date']

# %%
df[categorical_cols] = df[categorical_cols].astype("category")
print(df["Health Score"].unique(),df["Health Score"].isna().sum())
# Out:
# [22.59876067 15.56973099 47.17754929 ...  8.14574808  6.63658341
#  15.9372478 ] 123525

# %%
df["Health Score"].plot(kind="hist", bins=81, color="tomato", alpha=0.5)
plt.show()

# %% [markdown]
# #### **Model Staked**

# %%
categorical_cols = ['Gender', 'Marital Status', 'Education Level', 'Occupation', 'Location', 'Policy Type', 'Customer Feedback', 'Smoking Status', 'Exercise Frequency', 'Previous Claims', 'Property Type']
numerical_cols_nohs = ['Age', 'Annual Income', 'Vehicle Age', 'Credit Score', 'Insurance Duration', 'Policy Start Date']

# Preprocessing for categorical features: Imputation + OneHotEncoding
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('Ordinal', OrdinalEncoder())
])

# Preprocessing for numerical features: Imputation + Scaling
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# Combine both transformations
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_cols),
        ('num', numerical_transformer, numerical_cols_nohs)
    ],
    remainder='drop', # Drop any columns not specified in transformers
    verbose_feature_names_out=True)

# %%
X_ = df[df["Health Score"].isna()==False].copy()
X_test = df[df["Health Score"].isna()==True].copy()

X_[X_.select_dtypes(include="object").columns] = X_[X_.select_dtypes(include="object").columns].astype('category')
X_test[X_test.select_dtypes(include="object").columns] = X_test[X_test.select_dtypes(include="object").columns].astype('category')

print(X_.shape, X_test.shape)

RANDOM_SEED=42
FOLDS=5

X_test = X_test.drop(columns=["Health Score","Premium Amount"])
X = X_.drop(columns=["Health Score","Premium Amount"])
y = X_["Health Score"].copy()

cv = KFold(FOLDS, shuffle=True, random_state=RANDOM_SEED)
rmse_fold = []

# Initialize the Stack
occ_test_pred_stck = pd.DataFrame(index=X_test.index, columns=list(range(FOLDS)))

i=0

oof_results = pd.DataFrame(columns=["Occ_oof"], index=X.index)

for idx_train, idx_valid in cv.split(X, y):

    print(f"Fold {i}")

    # Split the data into training and validation sets for the current fold
    X_train, y_train = X.iloc[idx_train], y.iloc[idx_train].to_numpy().reshape(-1,1)
    X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid].to_numpy().reshape(-1,1)

    estimators = [
        ('lgbm', LGBMRegressor(objective="root_mean_squared_error", metric="rmse", max_depth=6,reg_alpha=0.1,reg_lambda=0.1, boosting_type='gbdt',
                               random_state=RANDOM_SEED, n_estimators=300,subsample=0.8, colsample_bytree=0.8, learning_rate=0.05,
                               categorical_feature=list(range(len(categorical_cols))), num_leaves=31)),
        ('xgb', XGBRegressor(learning_rate=0.05,objective ="reg:squarederror",n_estimators=300,max_depth=7,subsample=0.80,eval_metric='rmse',
                              colsample_bytree=0.8,enable_categorical="True",reg_lambda=0.1,reg_alpha=0.1)),
        ('catboost', CatBoostRegressor(iterations=300, learning_rate=0.05, depth=7, l2_leaf_reg=3, loss_function='RMSE', eval_metric='RMSE',
                           random_seed=RANDOM_SEED, subsample=0.80, bootstrap_type='Bernoulli'))
            ]

    meta_model = Ridge(alpha=0.1, positive=True, random_state=42)

    # Create StackingRegressor
    stacking_model = StackingRegressor(estimators=estimators, final_estimator=meta_model)

    model_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                                      ("model",stacking_model)])



    # Train the model using the training set and validate using the validation set
    if i >= 5:
        # Fit the StackingRegressor
        # model_pipeline[:-1].fit(X_train, y_train)
        # X_val_ = model_pipeline[:-1].transform(X_valid) # Transform X_val using the same steps as X
        # eval_set = [(X_val_, y_valid)]


        model_pipeline.fit(X_train, y_train)
        obj = sio.dump(model_pipeline, f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_hs_base_{i}.skops")

    else:
        unknown_types = sio.get_untrusted_types(file=f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_hs_base_{i}.skops")
        model_pipeline = sio.load(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_hs_base_{i}.skops", trusted=unknown_types)

    occ_preds = model_pipeline.predict(X_valid)

    oof_results.iloc[idx_valid,:] = occ_preds.flatten().reshape(-1,1)

    # Prepare the test data and make predictions
    rmse_ = root_mean_squared_error(y_valid, occ_preds)
    rmse_fold.append(rmse_)
    print(f"RMSE fold {i}: {rmse_fold}")

    X_test_ = X_test.copy()

    # Aggregate the predictions across the 5 folds (averaging for ensemble)
    occ_test_pred_stck.loc[:,i] = model_pipeline.predict(X_test_) #[:, 0] / FOLDS
    i += 1

    #del model_pipeline, X_test_, X_train, y_train, X_valid, y_valid
    gc.collect()
# Out:
# (1876475, 20) (123525, 20)
# Fold 0
# RMSE fold 0: [12.12513839486027]
# Fold 1
# RMSE fold 1: [12.12513839486027, 12.114132477746866]
# Fold 2
# RMSE fold 2: [12.12513839486027, 12.114132477746866, 12.0989825120291]
# Fold 3
# RMSE fold 3: [12.12513839486027, 12.114132477746866, 12.0989825120291, 12.112184565435427]
# Fold 4
# RMSE fold 4: [12.12513839486027, 12.114132477746866, 12.0989825120291, 12.112184565435427, 12.115229996346146]

# %%
print(rmse_fold)
# Out:
# [12.12513839486027, 12.114132477746866, 12.0989825120291, 12.112184565435427, 12.115229996346146]

# %%
occ_test_pred_stck["average"] = np.round(occ_test_pred_stck.mean(axis=1).astype(float),0)

# %%
occ_test_pred_stck["average"].plot(kind="hist", bins=81, color="tomato", alpha=0.5)
plt.show()

# %% [markdown]
# #### **Replace Values**

# %%
df.loc[df["Health Score"].isna()==True,"Health Score"]=occ_test_pred_stck["average"].values
df[df["Health Score"].isna()==True]["Health Score"]
# Out:
# Series([], Name: Health Score, dtype: float64)

# %%
#df.to_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/df_na_step_hs.csv", index=False)
df = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/df_na_step_hs.csv")

categorical_cols = ['Gender', 'Marital Status', 'Education Level', 'Occupation', 'Location', 'Policy Type', 'Customer Feedback', 'Smoking Status', 'Exercise Frequency', 'Previous Claims', 'Property Type']
numerical_cols = ['Age', 'Annual Income', 'Health Score', 'Vehicle Age', 'Credit Score', 'Insurance Duration', 'Policy Start Date']

df[numerical_cols] = df[numerical_cols].astype(float)
df[categorical_cols] = df[categorical_cols].astype("category")

# %%
df.isna().sum()#/df.shape[0]
# Out:
# Age                          0
# Gender                       0
# Annual Income            74809
# Marital Status           30865
# Number of Dependents         0
# Education Level              0
# Occupation                   0
# Health Score                 0
# Location                     0
# Policy Type                  0
# Previous Claims              0
# Vehicle Age                  9
# Credit Score            229333
# Insurance Duration           3
# Policy Start Date            0
# Customer Feedback            0
# Smoking Status               0
# Exercise Frequency           0
# Property Type                0
# Premium Amount          800000
# dtype: int64

# %% [markdown]
# ### **Annual Income**

# %%
categorical_cols = ['Gender', 'Marital Status', 'Education Level', 'Occupation', 'Location', 'Policy Type', 'Customer Feedback', 'Smoking Status', 'Exercise Frequency', 'Previous Claims', 'Property Type']
numerical_cols = ['Age', 'Annual Income', 'Health Score', 'Vehicle Age', 'Credit Score', 'Insurance Duration', 'Policy Start Date']

# %%
df[categorical_cols] = df[categorical_cols].astype("category")
print(df["Annual Income"].unique(),df["Annual Income"].isna().sum())
# Out:
# [ 10049.  31678.  25602. ...  21802. 149751. 107572.] 74809

# %%
df["Annual Income"].min()
# Out:
# 1.0

# %%
df["Annual Income"].plot(kind="hist", bins=81, color="tomato", alpha=0.5)
plt.show()

# %% [markdown]
# #### **Model Staked**

# %%
categorical_cols = ['Gender', 'Marital Status', 'Education Level', 'Occupation', 'Location', 'Policy Type', 'Customer Feedback', 'Smoking Status', 'Exercise Frequency', 'Previous Claims', 'Property Type']
numerical_cols_noai = ['Age', 'Health Score', 'Vehicle Age', 'Credit Score', 'Insurance Duration', 'Policy Start Date']

# Preprocessing for categorical features: Imputation + OneHotEncoding
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('Ordinal', OrdinalEncoder())
])

# Preprocessing for numerical features: Imputation + Scaling
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# Combine both transformations
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_cols),
        ('num', numerical_transformer, numerical_cols_noai)
    ],
    remainder='drop', # Drop any columns not specified in transformers
    verbose_feature_names_out=True)

# %%
X_ = df[df["Annual Income"].isna()==False].copy()
X_test = df[df["Annual Income"].isna()==True].copy()

X_[X_.select_dtypes(include="object").columns] = X_[X_.select_dtypes(include="object").columns].astype('category')
X_test[X_test.select_dtypes(include="object").columns] = X_test[X_test.select_dtypes(include="object").columns].astype('category')

print(X_.shape, X_test.shape)

RANDOM_SEED=42
FOLDS=5

X_test = X_test.drop(columns=["Annual Income","Premium Amount"])
X = X_.drop(columns=["Annual Income","Premium Amount"])
y = np.log(X_["Annual Income"].copy())

cv = KFold(FOLDS, shuffle=True, random_state=RANDOM_SEED)
rmse_fold = []

# Initialize the Stack
occ_test_pred_stck = pd.DataFrame(index=X_test.index, columns=list(range(FOLDS)))

i=0

oof_results = pd.DataFrame(columns=["Occ_oof"], index=X.index)

for idx_train, idx_valid in cv.split(X, y):

    print(f"Fold {i}")

    # Split the data into training and validation sets for the current fold
    X_train, y_train = X.iloc[idx_train], y.iloc[idx_train].to_numpy().reshape(-1,1)
    X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid].to_numpy().reshape(-1,1)

    estimators = [
        ('lgbm', LGBMRegressor(objective="root_mean_squared_error", metric="rmse", max_depth=6,reg_alpha=0.1,reg_lambda=0.1, boosting_type='gbdt',
                               random_state=RANDOM_SEED, n_estimators=300,subsample=0.8, colsample_bytree=0.8, learning_rate=0.05,
                               categorical_feature=list(range(len(categorical_cols))), num_leaves=31)),
        ('xgb', XGBRegressor(learning_rate=0.05,objective ="reg:squarederror",n_estimators=300,max_depth=7,subsample=0.80,eval_metric='rmse',
                              colsample_bytree=0.8,enable_categorical="True",reg_lambda=0.1,reg_alpha=0.1)),
        ('catboost', CatBoostRegressor(iterations=300, learning_rate=0.05, depth=7, l2_leaf_reg=3, loss_function='RMSE', eval_metric='RMSE',
                           random_seed=RANDOM_SEED, subsample=0.80, bootstrap_type='Bernoulli'))
            ]

    meta_model = Ridge(alpha=0.1, positive=True, random_state=42)

    # Create StackingRegressor
    stacking_model = StackingRegressor(estimators=estimators, final_estimator=meta_model)

    model_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                                      ("model",stacking_model)])



    # Train the model using the training set and validate using the validation set
    if i >= 0:
        # Fit the StackingRegressor
        # model_pipeline[:-1].fit(X_train, y_train)
        # X_val_ = model_pipeline[:-1].transform(X_valid) # Transform X_val using the same steps as X
        # eval_set = [(X_val_, y_valid)]


        model_pipeline.fit(X_train, y_train)
        obj = sio.dump(model_pipeline, f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_ai_base_{i}.skops")

    else:
        unknown_types = sio.get_untrusted_types(file=f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_ai_base_{i}.skops")
        model_pipeline = sio.load(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_ai_base_{i}.skops", trusted=unknown_types)

    occ_preds = np.exp(model_pipeline.predict(X_valid))

    oof_results.iloc[idx_valid,:] = occ_preds.flatten().reshape(-1,1)

    # Prepare the test data and make predictions
    rmse_ = root_mean_squared_error(y_valid, occ_preds)
    rmse_fold.append(rmse_)
    print(f"RMSE fold {i}: {rmse_fold}")

    X_test_ = X_test.copy()

    # Aggregate the predictions across the 5 folds (averaging for ensemble)
    occ_test_pred_stck.loc[:,i] = np.exp(model_pipeline.predict(X_test_)) #[:, 0] / FOLDS
    i += 1

    #del model_pipeline, X_test_, X_train, y_train, X_valid, y_valid
    gc.collect()
# Out:
# Streaming output truncated to the last 5000 lines.
# 175:	learn: 1.3178566	total: 43.1s	remaining: 30.4s
# 176:	learn: 1.3178448	total: 43.3s	remaining: 30.1s
# 177:	learn: 1.3178342	total: 43.5s	remaining: 29.8s
# 178:	learn: 1.3177868	total: 43.7s	remaining: 29.5s
# 179:	learn: 1.3177752	total: 43.9s	remaining: 29.3s
# 180:	learn: 1.3177561	total: 44.1s	remaining: 29s
# 181:	learn: 1.3176803	total: 44.4s	remaining: 28.8s
# 182:	learn: 1.3176130	total: 44.6s	remaining: 28.5s
# 183:	learn: 1.3175543	total: 44.8s	remaining: 28.2s
# 184:	learn: 1.3175204	total: 45s	remaining: 28s
# 185:	learn: 1.3175068	total: 45.2s	remaining: 27.7s
# 186:	learn: 1.3174939	total: 45.4s	remaining: 27.4s
# 187:	learn: 1.3174836	total: 45.6s	remaining: 27.2s
# 188:	learn: 1.3174135	total: 45.8s	remaining: 26.9s
# 189:	learn: 1.3173949	total: 46.1s	remaining: 26.7s
# 190:	learn: 1.3173723	total: 46.2s	remaining: 26.4s
# 191:	learn: 1.3173625	total: 46.5s	remaining: 26.1s
# 192:	learn: 1.3172721	total: 46.7s	remaining: 25.9s
# 193:	learn: 1.3172522	total: 46.9s	remaining: 25.6s
# 194:	learn: 1.3172404	total: 47.1s	remaining: 25.4s
# 195:	learn: 1.3172256	total: 47.4s	remaining: 25.2s
# 196:	learn: 1.3172099	total: 47.8s	remaining: 25s
# 197:	learn: 1.3171966	total: 48.1s	remaining: 24.8s
# 198:	learn: 1.3171820	total: 48.5s	remaining: 24.6s
# 199:	learn: 1.3171728	total: 48.8s	remaining: 24.4s
# 200:	learn: 1.3170281	total: 49.2s	remaining: 24.2s
# 201:	learn: 1.3170147	total: 49.5s	remaining: 24s
# 202:	learn: 1.3170066	total: 49.9s	remaining: 23.8s
# 203:	learn: 1.3170008	total: 50.2s	remaining: 23.6s
# 204:	learn: 1.3169892	total: 50.5s	remaining: 23.4s
# 205:	learn: 1.3169766	total: 50.9s	remaining: 23.2s
# 206:	learn: 1.3169720	total: 51.2s	remaining: 23s
# 207:	learn: 1.3169363	total: 51.5s	remaining: 22.8s
# 208:	learn: 1.3168373	total: 51.9s	remaining: 22.6s
# 209:	learn: 1.3167982	total: 52.3s	remaining: 22.4s
# 210:	learn: 1.3167910	total: 52.6s	remaining: 22.2s
# 211:	learn: 1.3166773	total: 53s	remaining: 22s
# 263:	learn: 1.3141779	total: 1m 3s	remaining: 8.65s
# 264:	learn: 1.3141694	total: 1m 3s	remaining: 8.4s
# 265:	learn: 1.3141341	total: 1m 3s	remaining: 8.15s
# 266:	learn: 1.3141167	total: 1m 4s	remaining: 7.91s
# 267:	learn: 1.3141070	total: 1m 4s	remaining: 7.66s
# 268:	learn: 1.3140928	total: 1m 4s	remaining: 7.42s
# 269:	learn: 1.3140842	total: 1m 4s	remaining: 7.17s
# 270:	learn: 1.3140737	total: 1m 4s	remaining: 6.93s
# 271:	learn: 1.3140598	total: 1m 5s	remaining: 6.7s
# 272:	learn: 1.3140270	total: 1m 5s	remaining: 6.47s
# 273:	learn: 1.3140186	total: 1m 5s	remaining: 6.24s
# 274:	learn: 1.3140108	total: 1m 6s	remaining: 6.01s
# 275:	learn: 1.3139981	total: 1m 6s	remaining: 5.78s
# 276:	learn: 1.3139882	total: 1m 6s	remaining: 5.55s
# 277:	learn: 1.3139747	total: 1m 7s	remaining: 5.32s
# 278:	learn: 1.3139645	total: 1m 7s	remaining: 5.08s
# 279:	learn: 1.3139513	total: 1m 7s	remaining: 4.85s
# 280:	learn: 1.3139437	total: 1m 8s	remaining: 4.61s
# 281:	learn: 1.3139315	total: 1m 8s	remaining: 4.37s
# 282:	learn: 1.3139191	total: 1m 8s	remaining: 4.14s
# 283:	learn: 1.3138031	total: 1m 9s	remaining: 3.9s
# 284:	learn: 1.3137869	total: 1m 9s	remaining: 3.66s
# 285:	learn: 1.3137777	total: 1m 9s	remaining: 3.43s
# 286:	learn: 1.3137330	total: 1m 10s	remaining: 3.19s
# 287:	learn: 1.3136803	total: 1m 10s	remaining: 2.95s
# 288:	learn: 1.3136698	total: 1m 10s	remaining: 2.7s
# 289:	learn: 1.3136215	total: 1m 11s	remaining: 2.45s
# 290:	learn: 1.3135684	total: 1m 11s	remaining: 2.21s
# 291:	learn: 1.3135577	total: 1m 11s	remaining: 1.96s
# 292:	learn: 1.3135487	total: 1m 11s	remaining: 1.71s
# 293:	learn: 1.3135303	total: 1m 11s	remaining: 1.47s
# 294:	learn: 1.3134953	total: 1m 12s	remaining: 1.22s
# 295:	learn: 1.3134730	total: 1m 12s	remaining: 977ms
# 296:	learn: 1.3134134	total: 1m 12s	remaining: 732ms
# 297:	learn: 1.3133917	total: 1m 12s	remaining: 488ms
# 298:	learn: 1.3133775	total: 1m 12s	remaining: 244ms
# 299:	learn: 1.3133653	total: 1m 13s	remaining: 0us
# RMSE fold 4: [19390.684343715133, 19396.67541734738, 19380.54259046948, 19392.53958548167, 19440.077603214173]

# %%
print(rmse_fold)
# Out:
# [19390.684343715133, 19396.67541734738, 19380.54259046948, 19392.53958548167, 19440.077603214173]

# %%
occ_test_pred_stck["average"] = occ_test_pred_stck.mean(axis=1).astype(float)

# %%
occ_test_pred_stck["average"].plot(kind="hist", bins=81, color="tomato", alpha=0.5)
plt.show()

# %% [markdown]
# #### **Replace Values**

# %%
df.loc[df["Annual Income"].isna()==True,"Annual Income"]=occ_test_pred_stck["average"].values
df[df["Annual Income"].isna()==True]["Annual Income"]
# Out:
# Series([], Name: Annual Income, dtype: float64)

# %%
#df.to_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/df_na_step_ai.csv", index=False)
df = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/df_na_step_ai.csv")

categorical_cols = ['Gender', 'Marital Status', 'Education Level', 'Occupation', 'Location', 'Policy Type', 'Customer Feedback', 'Smoking Status', 'Exercise Frequency', 'Property Type', 'Number of Dependents']
numerical_cols = ['Age', 'Annual Income', 'Health Score', 'Vehicle Age', 'Credit Score', 'Insurance Duration', 'Previous Claims', 'Policy Start Date']

df[numerical_cols] = df[numerical_cols].astype(float)
df[categorical_cols] = df[categorical_cols].astype("category")

# %%
df.isna().sum()/df.shape[0]
# Out:
# Age                     0.000000
# Gender                  0.000000
# Annual Income           0.000000
# Marital Status          0.015433
# Number of Dependents    0.000000
# Education Level         0.000000
# Occupation              0.000000
# Health Score            0.000000
# Location                0.000000
# Policy Type             0.000000
# Previous Claims         0.000000
# Vehicle Age             0.000005
# Credit Score            0.114667
# Insurance Duration      0.000002
# Policy Start Date       0.000000
# Customer Feedback       0.000000
# Smoking Status          0.000000
# Exercise Frequency      0.000000
# Property Type           0.000000
# Premium Amount          0.400000
# dtype: float64

# %% [markdown]
# ### **Marital Status**

# %%
gc.collect()
# Out:
# 650

# %%
categorical_cols = ['Gender', 'Marital Status', 'Education Level', 'Occupation', 'Location', 'Policy Type', 'Customer Feedback', 'Smoking Status', 'Exercise Frequency', 'Property Type', 'Number of Dependents']
numerical_cols = ['Age', 'Annual Income', 'Health Score', 'Vehicle Age', 'Credit Score', 'Insurance Duration', 'Previous Claims', 'Policy Start Date']

# %%
df[categorical_cols] = df[categorical_cols].astype("category")
print(df["Marital Status"].unique())

le=OrdinalEncoder()
df["Marital Status"] = le.fit_transform(df[["Marital Status"]])

print(df["Marital Status"].unique())
# Out:
# [1.0, 0.0, 2.0, NaN]
# Categories (3, float64): [0.0, 1.0, 2.0]
# [ 1.  0.  2. nan]

# %%
df["Marital Status"].plot(kind="hist", bins=5, color="tomato", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Data columns (total 20 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Age                   float64
#  1   Gender                category
#  2   Annual Income         float64
#  3   Marital Status        float64
#  4   Number of Dependents  category
#  5   Education Level       category
#  6   Occupation            category
#  7   Health Score          float64
#  8   Location              category
#  9   Policy Type           category
#  10  Previous Claims       float64
#  11  Vehicle Age           float64
#  12  Credit Score          float64
#  13  Insurance Duration    float64
#  14  Policy Start Date     float64
#  15  Customer Feedback     category
#  16  Smoking Status        category
#  17  Exercise Frequency    category
#  18  Property Type         category
#  19  Premium Amount        float64
# dtypes: category(10), float64(10)
# memory usage: 171.7 MB

# %% [markdown]
# #### **Model Staked**

# %%
categorical_cols_noms = ['Gender', 'Education Level', 'Occupation', 'Location', 'Policy Type', 'Customer Feedback', 'Smoking Status', 'Exercise Frequency', 'Property Type', 'Number of Dependents']
numerical_cols = ['Age', 'Annual Income', 'Health Score', 'Vehicle Age', 'Credit Score', 'Insurance Duration', 'Previous Claims', 'Policy Start Date']

# Preprocessing for categorical features: Imputation + OneHotEncoding
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('Ordinal', OrdinalEncoder(dtype=np.int64))
])

# Preprocessing for numerical features: Imputation + Scaling
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# Combine both transformations
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_cols_noms),
        ('num', numerical_transformer, numerical_cols)
    ],
    remainder='drop', # Drop any columns not specified in transformers
    verbose_feature_names_out=True)

# %%
X_ = df[df['Marital Status'].isna()==False].copy()
X_test = df[df["Marital Status"].isna()==True].copy()

X_[X_.select_dtypes(include="object").columns] = X_[X_.select_dtypes(include="object").columns].astype('category')
X_test[X_test.select_dtypes(include="object").columns] = X_test[X_test.select_dtypes(include="object").columns].astype('category')

print(X_.shape, X_test.shape)

RANDOM_SEED=42
FOLDS=5

X_test = X_test.drop(columns=["Marital Status","Premium Amount"])
X = X_.drop(columns=["Marital Status","Premium Amount"])
y = X_["Marital Status"].copy()

cv = KFold(FOLDS, shuffle=True, random_state=RANDOM_SEED)
accuracy_fold = []

# Initialize the Stack
occ_test_pred_stck = pd.DataFrame(index=X_test.index, columns=list(range(FOLDS)))

i=0

oof_results = pd.DataFrame(columns=["pc_oof"], index=X.index)

for idx_train, idx_valid in cv.split(X, y):

    print(f"Fold {i}")

    # Split the data into training and validation sets for the current fold
    X_train, y_train = X.iloc[idx_train], y.iloc[idx_train].to_numpy().reshape(-1,1)
    X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid].to_numpy().reshape(-1,1)

    # Initialize the TabNet Regressor model
    estimators = [
        ('lgbm', LGBMClassifier(objective='multiclass',num_class=3,metric='multi_error',boosting_type='gbdt',
                                num_leaves=31,max_depth=6,learning_rate=0.05,n_estimators=250,subsample=0.8,
                                colsample_bytree=0.8,reg_alpha=0.1,reg_lambda=0.1,categorical_feature=list(range(len(categorical_cols_noms))),
                                n_jobs=-1,random_state=RANDOM_SEED)),
        ('xgb', XGBClassifier(objective='multi:softmax', num_class=3, eval_metric='mlogloss', n_estimators=250,learning_rate=0.05,
                              max_depth=7, subsample=0.80,colsample_bytree=0.80,enable_categorical="True",reg_lambda=0.1,reg_alpha=0.1)),
        ('catboost', CatBoostClassifier(iterations=250, learning_rate=0.05, depth=7, l2_leaf_reg=3, loss_function='MultiClass', eval_metric='Accuracy',
                           random_seed=RANDOM_SEED, subsample=0.80, bootstrap_type='Bernoulli'))
            ]

    meta_model = LogisticRegression(C=1.0,  solver="saga", random_state=RANDOM_SEED, max_iter=250)

    # Create StackingRegressor
    stacking_model = StackingClassifier(estimators=estimators, final_estimator=meta_model)

    model_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                                      ("model",stacking_model)])


    # Train the model using the training set and validate using the validation set
    if i >= 0:
        # Fit the StackingRegressor
        # model_pipeline[:-1].fit(X_train, y_train)
        # X_val_ = model_pipeline[:-1].transform(X_valid) # Transform X_val using the same steps as X
        # eval_set = [(X_val_, y_valid)]


        model_pipeline.fit(X_train, y_train)
        obj = sio.dump(model_pipeline, f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_ms_base_{i}.skops")

    else:
        unknown_types = sio.get_untrusted_types(file=f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_ms_base_{i}.skops")
        model_pipeline = sio.load(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_ms_base_{i}.skops", trusted=unknown_types)

    occ_preds = model_pipeline.predict(X_valid)

    oof_results.iloc[idx_valid,:] = occ_preds.flatten().reshape(-1,1)

    # Prepare the test data and make predictions
    accuracy_ = accuracy_score(y_valid, occ_preds)
    accuracy_fold.append(accuracy_)
    print(f"Accuracy fold {i}: {accuracy_}")

    X_test_ = X_test.copy()

    # Aggregate the predictions across the 5 folds (averaging for ensemble)
    occ_test_pred_stck.loc[:,i] = model_pipeline.predict(X_test_) #[:, 0] / FOLDS
    i += 1

    #del model_pipeline, X_test_, X_train, y_train, X_valid, y_valid
    gc.collect()
# Out:
# (1969135, 20) (30865, 20)
# Fold 0
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.083761 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1148
# [LightGBM] [Info] Number of data points in the train set: 1575308, number of used features: 18
# [LightGBM] [Info] Start training from score -1.102791
# [LightGBM] [Info] Start training from score -1.098235
# [LightGBM] [Info] Start training from score -1.094827

# %%
print(accuracy_fold)

# %%
occ_test_pred_stck.median(axis=1).value_counts()

# %% [markdown]
# #### **Replace Values**

# %%
df.loc[df["Marital Status"].isna()==True,"Marital Status"]=occ_test_pred_stck.median(axis=1).values
df[df["Marital Status"].isna()==True]["Marital Status"]

# %%
df.to_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/df_na_step_ms.csv", index=False)
#df = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/df_na_step_ms.csv")

categorical_cols = ['Gender', 'Marital Status', 'Education Level', 'Occupation', 'Location', 'Policy Type', 'Customer Feedback', 'Smoking Status', 'Exercise Frequency', 'Property Type', 'Number of Dependents']
numerical_cols = ['Age', 'Annual Income', 'Health Score', 'Vehicle Age', 'Credit Score', 'Insurance Duration', 'Previous Claims', 'Policy Start Date']

df[numerical_cols] = df[numerical_cols].astype(float)
df[categorical_cols] = df[categorical_cols].astype("category")

# %%
df.isna().sum()/df.shape[0]

# %% [markdown]
# ### **Credit Score**

# %%
categorical_cols = ['Gender', 'Marital Status', 'Education Level', 'Occupation', 'Location', 'Policy Type', 'Customer Feedback', 'Smoking Status', 'Exercise Frequency', 'Property Type', 'Number of Dependents']
numerical_cols = ['Age', 'Annual Income', 'Health Score', 'Vehicle Age', 'Credit Score', 'Insurance Duration', 'Previous Claims', 'Policy Start Date']

# %%
df[categorical_cols] = df[categorical_cols].astype("category")
print(df['Credit Score'].unique(),df['Credit Score'].isna().sum())

# %%
df['Credit Score'].min(),df['Credit Score'].max()

# %%
df['Credit Score'].plot(kind="hist", bins=81, color="tomato", alpha=0.5)
plt.show()

# %% [markdown]
# #### **Model Staked**

# %%
categorical_cols = ['Gender', 'Marital Status', 'Education Level', 'Occupation', 'Location', 'Policy Type', 'Customer Feedback', 'Smoking Status', 'Exercise Frequency', 'Property Type', 'Number of Dependents']
numerical_cols_nocs = ['Age', 'Annual Income', 'Health Score', 'Vehicle Age', 'Insurance Duration', 'Previous Claims', 'Policy Start Date']

# Preprocessing for categorical features: Imputation + OneHotEncoding
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('Ordinal', OrdinalEncoder())
])

# Preprocessing for numerical features: Imputation + Scaling
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# Combine both transformations
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_cols),
        ('num', numerical_transformer, numerical_cols_nocs)
    ],
    remainder='drop', # Drop any columns not specified in transformers
    verbose_feature_names_out=True)

# %%
X_ = df[df['Credit Score'].isna()==False].copy()
X_test = df[df['Credit Score'].isna()==True].copy()

X_[X_.select_dtypes(include="object").columns] = X_[X_.select_dtypes(include="object").columns].astype('category')
X_test[X_test.select_dtypes(include="object").columns] = X_test[X_test.select_dtypes(include="object").columns].astype('category')

print(X_.shape, X_test.shape)

RANDOM_SEED=42
FOLDS=5

X_test = X_test.drop(columns=['Credit Score',"Premium Amount"])
X = X_.drop(columns=['Credit Score',"Premium Amount"])
y = np.log(X_['Credit Score'].copy())

cv = KFold(FOLDS, shuffle=True, random_state=RANDOM_SEED)
rmse_fold = []

# Initialize the Stack
occ_test_pred_stck = pd.DataFrame(index=X_test.index, columns=list(range(FOLDS)))

i=0

oof_results = pd.DataFrame(columns=["Occ_oof"], index=X.index)

for idx_train, idx_valid in cv.split(X, y):

    print(f"Fold {i}")

    # Split the data into training and validation sets for the current fold
    X_train, y_train = X.iloc[idx_train], y.iloc[idx_train].to_numpy().reshape(-1,1)
    X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid].to_numpy().reshape(-1,1)

    estimators = [
        ('lgbm', LGBMRegressor(objective="root_mean_squared_error", metric="rmse", max_depth=6,reg_alpha=0.1,reg_lambda=0.1, boosting_type='gbdt',
                               random_state=RANDOM_SEED, n_estimators=300,subsample=0.8, colsample_bytree=0.8, learning_rate=0.05,
                               categorical_feature=list(range(len(categorical_cols))), num_leaves=31)),
        ('xgb', XGBRegressor(learning_rate=0.05,objective ="reg:squarederror",n_estimators=300,max_depth=7,subsample=0.80,eval_metric='rmse',
                              colsample_bytree=0.8,enable_categorical="True",reg_lambda=0.1,reg_alpha=0.1)),
        ('catboost', CatBoostRegressor(iterations=300, learning_rate=0.05, depth=7, l2_leaf_reg=3, loss_function='RMSE', eval_metric='RMSE',
                           random_seed=RANDOM_SEED, subsample=0.80, bootstrap_type='Bernoulli'))
            ]

    meta_model = Ridge(alpha=0.1, positive=True, random_state=42)

    # Create StackingRegressor
    stacking_model = StackingRegressor(estimators=estimators, final_estimator=meta_model)

    model_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                                      ("model",stacking_model)])



    # Train the model using the training set and validate using the validation set
    if i >= 0:
        # Fit the StackingRegressor
        # model_pipeline[:-1].fit(X_train, y_train)
        # X_val_ = model_pipeline[:-1].transform(X_valid) # Transform X_val using the same steps as X
        # eval_set = [(X_val_, y_valid)]


        model_pipeline.fit(X_train, y_train)
        obj = sio.dump(model_pipeline, f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_cs_base_{i}.skops")

    else:
        unknown_types = sio.get_untrusted_types(file=f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_cs_base_{i}.skops")
        model_pipeline = sio.load(f"/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S4E12/stack_cs_base_{i}.skops", trusted=unknown_types)

    occ_preds = np.exp(model_pipeline.predict(X_valid))

    oof_results.iloc[idx_valid,:] = occ_preds.flatten().reshape(-1,1)

    # Prepare the test data and make predictions
    rmse_ = root_mean_squared_error(y_valid, occ_preds)
    rmse_fold.append(rmse_)
    print(f"RMSE fold {i}: {rmse_fold}")

    X_test_ = X_test.copy()

    # Aggregate the predictions across the 5 folds (averaging for ensemble)
    occ_test_pred_stck.loc[:,i] = np.exp(model_pipeline.predict(X_test_)) #[:, 0] / FOLDS
    i += 1

    #del model_pipeline, X_test_, X_train, y_train, X_valid, y_valid
    gc.collect()
# Out:
# Streaming output truncated to the last 5000 lines.
# 175:	learn: 1.3178566	total: 43.1s	remaining: 30.4s
# 176:	learn: 1.3178448	total: 43.3s	remaining: 30.1s
# 177:	learn: 1.3178342	total: 43.5s	remaining: 29.8s
# 178:	learn: 1.3177868	total: 43.7s	remaining: 29.5s
# 179:	learn: 1.3177752	total: 43.9s	remaining: 29.3s
# 180:	learn: 1.3177561	total: 44.1s	remaining: 29s
# 181:	learn: 1.3176803	total: 44.4s	remaining: 28.8s
# 182:	learn: 1.3176130	total: 44.6s	remaining: 28.5s
# 183:	learn: 1.3175543	total: 44.8s	remaining: 28.2s
# 184:	learn: 1.3175204	total: 45s	remaining: 28s
# 185:	learn: 1.3175068	total: 45.2s	remaining: 27.7s
# 186:	learn: 1.3174939	total: 45.4s	remaining: 27.4s
# 187:	learn: 1.3174836	total: 45.6s	remaining: 27.2s
# 188:	learn: 1.3174135	total: 45.8s	remaining: 26.9s
# 189:	learn: 1.3173949	total: 46.1s	remaining: 26.7s
# 190:	learn: 1.3173723	total: 46.2s	remaining: 26.4s
# 191:	learn: 1.3173625	total: 46.5s	remaining: 26.1s
# 192:	learn: 1.3172721	total: 46.7s	remaining: 25.9s
# 193:	learn: 1.3172522	total: 46.9s	remaining: 25.6s
# 194:	learn: 1.3172404	total: 47.1s	remaining: 25.4s
# 195:	learn: 1.3172256	total: 47.4s	remaining: 25.2s
# 196:	learn: 1.3172099	total: 47.8s	remaining: 25s
# 197:	learn: 1.3171966	total: 48.1s	remaining: 24.8s
# 198:	learn: 1.3171820	total: 48.5s	remaining: 24.6s
# 199:	learn: 1.3171728	total: 48.8s	remaining: 24.4s
# 200:	learn: 1.3170281	total: 49.2s	remaining: 24.2s
# 201:	learn: 1.3170147	total: 49.5s	remaining: 24s
# 202:	learn: 1.3170066	total: 49.9s	remaining: 23.8s
# 203:	learn: 1.3170008	total: 50.2s	remaining: 23.6s
# 204:	learn: 1.3169892	total: 50.5s	remaining: 23.4s
# 205:	learn: 1.3169766	total: 50.9s	remaining: 23.2s
# 206:	learn: 1.3169720	total: 51.2s	remaining: 23s
# 207:	learn: 1.3169363	total: 51.5s	remaining: 22.8s
# 208:	learn: 1.3168373	total: 51.9s	remaining: 22.6s
# 209:	learn: 1.3167982	total: 52.3s	remaining: 22.4s
# 210:	learn: 1.3167910	total: 52.6s	remaining: 22.2s
# 211:	learn: 1.3166773	total: 53s	remaining: 22s
# 212:	learn: 1.3166522	total: 53.3s	remaining: 21.8s
# 264:	learn: 1.3141694	total: 1m 3s	remaining: 8.4s
# 265:	learn: 1.3141341	total: 1m 3s	remaining: 8.15s
# 266:	learn: 1.3141167	total: 1m 4s	remaining: 7.91s
# 267:	learn: 1.3141070	total: 1m 4s	remaining: 7.66s
# 268:	learn: 1.3140928	total: 1m 4s	remaining: 7.42s
# 269:	learn: 1.3140842	total: 1m 4s	remaining: 7.17s
# 270:	learn: 1.3140737	total: 1m 4s	remaining: 6.93s
# 271:	learn: 1.3140598	total: 1m 5s	remaining: 6.7s
# 272:	learn: 1.3140270	total: 1m 5s	remaining: 6.47s
# 273:	learn: 1.3140186	total: 1m 5s	remaining: 6.24s
# 274:	learn: 1.3140108	total: 1m 6s	remaining: 6.01s
# 275:	learn: 1.3139981	total: 1m 6s	remaining: 5.78s
# 276:	learn: 1.3139882	total: 1m 6s	remaining: 5.55s
# 277:	learn: 1.3139747	total: 1m 7s	remaining: 5.32s
# 278:	learn: 1.3139645	total: 1m 7s	remaining: 5.08s
# 279:	learn: 1.3139513	total: 1m 7s	remaining: 4.85s
# 280:	learn: 1.3139437	total: 1m 8s	remaining: 4.61s
# 281:	learn: 1.3139315	total: 1m 8s	remaining: 4.37s
# 282:	learn: 1.3139191	total: 1m 8s	remaining: 4.14s
# 283:	learn: 1.3138031	total: 1m 9s	remaining: 3.9s
# 284:	learn: 1.3137869	total: 1m 9s	remaining: 3.66s
# 285:	learn: 1.3137777	total: 1m 9s	remaining: 3.43s
# 286:	learn: 1.3137330	total: 1m 10s	remaining: 3.19s
# 287:	learn: 1.3136803	total: 1m 10s	remaining: 2.95s
# 288:	learn: 1.3136698	total: 1m 10s	remaining: 2.7s
# 289:	learn: 1.3136215	total: 1m 11s	remaining: 2.45s
# 290:	learn: 1.3135684	total: 1m 11s	remaining: 2.21s
# 291:	learn: 1.3135577	total: 1m 11s	remaining: 1.96s
# 292:	learn: 1.3135487	total: 1m 11s	remaining: 1.71s
# 293:	learn: 1.3135303	total: 1m 11s	remaining: 1.47s
# 294:	learn: 1.3134953	total: 1m 12s	remaining: 1.22s
# 295:	learn: 1.3134730	total: 1m 12s	remaining: 977ms
# 296:	learn: 1.3134134	total: 1m 12s	remaining: 732ms
# 297:	learn: 1.3133917	total: 1m 12s	remaining: 488ms
# 298:	learn: 1.3133775	total: 1m 12s	remaining: 244ms
# 299:	learn: 1.3133653	total: 1m 13s	remaining: 0us
# RMSE fold 4: [19390.684343715133, 19396.67541734738, 19380.54259046948, 19392.53958548167, 19440.077603214173]

# %%
print(rmse_fold)
# Out:
# [19390.684343715133, 19396.67541734738, 19380.54259046948, 19392.53958548167, 19440.077603214173]

# %%
occ_test_pred_stck["average"] = occ_test_pred_stck.mean(axis=1).astype(float)

# %%
occ_test_pred_stck["average"].plot(kind="hist", bins=81, color="tomato", alpha=0.5)
plt.show()

# %% [markdown]
# #### **Replace Values**

# %%
df.loc[df['Credit Score'].isna()==True,'Credit Score']=occ_test_pred_stck["average"].values
df[df['Credit Score'].isna()==True]['Credit Score']
# Out:
# Series([], Name: Annual Income, dtype: float64)

# %%
df.to_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/df_na_step_cs.csv", index=False)
#df = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S4E12/df_na_step_vs.csv")

categorical_cols = ['Gender', 'Marital Status', 'Education Level', 'Occupation', 'Location', 'Policy Type', 'Customer Feedback', 'Smoking Status', 'Exercise Frequency', 'Property Type', 'Number of Dependents']
numerical_cols = ['Age', 'Annual Income', 'Health Score', 'Vehicle Age', 'Credit Score', 'Insurance Duration', 'Previous Claims', 'Policy Start Date']

df[numerical_cols] = df[numerical_cols].astype(float)
df[categorical_cols] = df[categorical_cols].astype("category")

# %%
df.isna().sum()/df.shape[0]
# Out:
# Age                     0.000000
# Gender                  0.000000
# Annual Income           0.000000
# Marital Status          0.015433
# Number of Dependents    0.000000
# Education Level         0.000000
# Occupation              0.000000
# Health Score            0.000000
# Location                0.000000
# Policy Type             0.000000
# Previous Claims         0.000000
# Vehicle Age             0.000005
# Credit Score            0.114667
# Insurance Duration      0.000002
# Policy Start Date       0.000000
# Customer Feedback       0.000000
# Smoking Status          0.000000
# Exercise Frequency      0.000000
# Property Type           0.000000
# Premium Amount          0.400000
# dtype: float64

# %%
# Fit and transform the training data
X_preprocessed = preprocessor.fit_transform(df)

df_preprocessed = pd.DataFrame(X_preprocessed, columns=numerical_cols+categorical_cols_no_occ)
df_preprocessed["Target"] = df["Occupation"]
#df_preprocessed["Premium Amount"] = df["Premium Amount"]

# %%
#df_preprocessed.isna().sum()
df_preprocessed_train = df_preprocessed[df_preprocessed.Target.isna()==False]
df_preprocessed_test = df_preprocessed[df_preprocessed.Target.isna()==True]

df_preprocessed_train.shape, df_preprocessed_test.shape
# Out:
# ((1402800, 19), (597200, 19))

# %%
# Calculate the correlation matrix
corr_matrix = df.corr(numeric_only=False)

# Retrieve the correlations with `Occupation`
occupation_corr = corr_matrix['Previous Claims']

# Print the correlations
print(occupation_corr.to_markdown(numalign="left", stralign="left"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-ccaf1fad581d> in <cell line: 2>()
#       1 # Calculate the correlation matrix
# ----> 2 corr_matrix = df.corr(numeric_only=False)
#       3
#       4 # Retrieve the correlations with `Occupation`
#       5 occupation_corr = corr_matrix['Previous Claims']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in as_array(self, dtype, copy, na_value)
#    1692                 arr.flags.writeable = False
#    1693         else:
# -> 1694             arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695             # The underlying data was copied within _interleave, so no need
#    1696             # to further copy if copy=True or setting na_value
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in _interleave(self, dtype, na_value)
#    1751             else:
#    1752                 arr = blk.get_values(dtype)
# -> 1753             result[rl.indexer] = arr
#    1754             itemmask[rl.indexer] = 1
#    1755
#
# ValueError: could not convert string to float: 'Female'
