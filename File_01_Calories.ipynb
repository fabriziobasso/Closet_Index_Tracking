# %% [markdown]
# <a href="https://colab.research.google.com/github/fabriziobasso/Closet_Index_Tracking/blob/master/File_01_Calories.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PREDICTING CALOORIES BURNED
#
# ## RMSLE Metric and Competition Context
#
# This notebook is developed for a data science competition focused on predicting **Calories burned** during exercise. The evaluation metric for this competition is the **Root Mean Squared Logarithmic Error (RMSLE)**, which measures the square root of the mean squared difference between the logarithms of predicted and actual values. RMSLE is ideal for datasets with a wide range of target values, as it emphasizes **relative errors**, ensuring balanced performance across small and large calorie values.
#
# The RMSLE formula is:
#
# ![](https://miro.medium.com/v2/resize:fit:720/format:webp/0*AUzyQ1rc6mpQVYfn)
#
# ### Why RMSLE?
# - **Handles Wide Ranges**: RMSLE penalizes relative errors proportionally, making it robust for calorie values ranging from small (e.g., 10 calories) to large (e.g., 1000 calories).
# - **Balanced Evaluation**: Ensures models perform well across the entire spectrum of calorie burn.
# - **Competition Goal**: A lower RMSLE score indicates a precise and generalizable model, critical for ranking high on the leaderboard.
#
# ---
#
# ## Potential Effects of Features on Calorie Burn
#
# The dataset includes the following features to predict calorie burn: **Sex**, **Age**, **Height**, **Weight**, **Duration**, **Heart_Rate**, and **Body_Temp**. Below, we explore how each feature might influence calorie burn:
#
# ### 1. Sex
# - **Impact**: Differences in metabolic rates and muscle mass between males and females affect calorie burn. Males often have higher muscle mass, leading to greater calorie expenditure for the same exercise.
# - **Example**: A male running at the same pace and duration as a female may burn more calories due to higher energy demands.
#
# ### 2. Age
# - **Impact**: Basal metabolic rate (BMR) decreases with age, reducing calorie burn in older individuals due to lower metabolic rates and muscle mass (sarcopenia).
# - **Example**: A 20-year-old may burn more calories than a 50-year-old during identical workouts.
#
# ### 3. Height
# - **Impact**: Taller individuals have more body mass or muscle, requiring more energy for movement, thus burning more calories. Height’s effect is often linked to weight and exercise intensity.
# - **Example**: A taller person may expend more energy covering the same distance.
#
# ### 4. Weight
# - **Impact**: Heavier individuals burn more calories due to the energy required to move greater body mass. Body composition (fat vs. muscle) also influences calorie burn.
# - **Example**: A 90 kg individual burns more calories walking the same distance as a 60 kg individual.
#
# ### 5. Duration
# - **Impact**: Longer exercise sessions directly increase total calorie expenditure, though intensity and exercise type also matter.
# - **Example**: Running for 30 minutes burns more calories than running for 15 minutes.
#
# ### 6. Heart_Rate
# - **Impact**: Higher heart rates indicate greater exercise intensity and metabolic effort, leading to increased calorie burn. Fitness levels can modulate heart rate responses.
# - **Example**: High heart rate during a HIIT workout correlates with higher calorie burn.
#
# ### 7. Body_Temp
# - **Impact**: Rising body temperature during exercise reflects increased metabolic activity and thermoregulation, potentially increasing calorie burn. Environmental factors (e.g., heat) also play a role.
# - **Example**: Exercising in a hot environment may increase calorie expenditure due to thermoregulation.
#
# ---
#
# ## Transition to Analysis
#
# Understanding the relationships between these features and calorie burn is key to building a predictive model. In this notebook, we will:
#
# 1. **Explore Data**: Analyze the distribution of the target variable (**Calories**) and features using visualizations (e.g., histograms, boxplots).
# 2. **Correlation Analysis**: Identify relationships between features and the target using correlation matrices and polar plots.
# 3. **Outlier Detection**: Address anomalies that could skew model performance.
# 4. **Feature Engineering**: Apply techniques like quantile and equal-width binning to enhance model input.
# 5. **Model Development**: Build and evaluate models to minimize RMSLE, aligning with competition objectives.
#
# ### Visualization Strategy
# We will use:
# - **Histograms** and **boxplots** to examine feature distributions.
# - **Correlation matrices** to uncover feature relationships.
# - **Polar plots** for creative visualization of feature impacts.
# - **Pair plots** to explore pairwise relationships.
#
# By systematically analyzing the data, we aim to develop a robust model that accurately predicts calorie burn and excels in the competition.
#
# ---

# %% [markdown]
# # 0.0 Setting

# %% [markdown]
# ## 0.1 Import Libraries:

# %%
# !pip uninstall scikit-learn
# !pip install scikit-learn==1.4

# %%
# %%capture
#!pip install -qq pytorch_tabnet
# !pip install optuna
# !pip install --upgrade catboost
#!pip install optuna-integration-pytorch-tabnet

#from pytorch_tabnet.tab_model import TabNetRegressor

# !pip install --upgrade category-encoders
# !pip install optuna-integration
# !pip install colorama
#!pip install pyfiglet
#!pip install keras-tuner --upgrade
#!pip install keras-nlp
#!pip install BorutaShap
#!pip install scikit-learn==1.2.2
#!pip install scikit-lego
# !pip install skops

# %%
import sklearn
import lightgbm, xgboost, catboost
sklearn.__version__, lightgbm.__version__, xgboost.__version__, catboost.__version__
# Out:
# ('1.6.1', '4.5.0', '2.1.4', '1.2.8')

# %%
# Setup notebook
from pathlib import Path
import ipywidgets as widgets
import pandas as pd
import numpy as np
from pickle import load, dump
import json
import joblib
#from joblib import dump, load
#import calplot as cal

# Graphic Libraries:
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.image as mpimg
from termcolor import colored
# Set Style
sns.set_style("whitegrid",{"grid.linestyle":"--", 'grid.linewidth':0.2, 'grid.alpha':0.5});
sns.despine(left=True, bottom=True, top=False, right=False);
mpl.rcParams['figure.dpi'] = 120;
mpl.rc('axes', labelsize=12);
plt.rc('xtick',labelsize=10);
plt.rc('ytick',labelsize=10);

mpl.rcParams['axes.spines.top'] = False;
mpl.rcParams['axes.spines.right'] = False;
mpl.rcParams['axes.spines.left'] = True;

# Palette Setup
colors = ['#FB5B68','#FFEB48','#2676A1','#FFBDB0',]
colormap_0 = mpl.colors.LinearSegmentedColormap.from_list("",colors)
palette_1 = sns.color_palette("coolwarm", as_cmap=True)
palette_2 = sns.color_palette("YlOrBr", as_cmap=True)
palette_3 = sns.light_palette("red", as_cmap=True)
palette_4 = sns.color_palette("viridis", as_cmap=True)
palette_5 = sns.color_palette("rocket", as_cmap=True)
palette_6 = sns.color_palette("GnBu", as_cmap=True)
palette_7 = sns.color_palette("tab20c", as_cmap=False)
palette_8 = sns.color_palette("Set2", as_cmap=False)

palette_custom = ['#fbb4ae','#b3cde3','#ccebc5','#decbe4','#fed9a6','#ffffcc','#e5d8bd','#fddaec','#f2f2f2']
palette_9 = sns.color_palette(palette_custom, as_cmap=False)

# tool for Excel:
from openpyxl import load_workbook, Workbook
from openpyxl.drawing.image import Image
from openpyxl.styles import Border, Side, PatternFill, Font, GradientFill, Alignment
from openpyxl.worksheet.cell_range import CellRange

from openpyxl.formatting import Rule
from openpyxl.styles import Font, PatternFill, Border
from openpyxl.styles.differential import DifferentialStyle

# Bloomberg
#from xbbg import blp
from catboost import CatBoostRegressor, Pool, CatBoostClassifier
import xgboost as xgb
from xgboost import XGBRegressor, XGBClassifier
from xgboost.callback import EarlyStopping

import lightgbm as lgb
from lightgbm import (LGBMRegressor,
                      LGBMClassifier,
                      early_stopping,
                      record_evaluation,
                      log_evaluation)

# Time Management
from tqdm import tqdm
from datetime import date
from datetime import datetime
from pandas.tseries.offsets import BMonthEnd, QuarterEnd
import datetime
from pandas.tseries.offsets import BDay # BDay is business day, not birthday...
import datetime as dt
import click
import glob
import os
import gc
import re
import string

from ipywidgets import AppLayout
from ipywidgets import Dropdown, Layout, HTML, AppLayout, VBox, Label, HBox, BoundedFloatText, interact, Output

#from my_func import *

import optuna
from optuna.integration import TFKerasPruningCallback
from optuna.trial import TrialState
from optuna.visualization import plot_intermediate_values
from optuna.visualization import plot_optimization_history
from optuna.visualization import plot_param_importances
from optuna.visualization import plot_contour

os.environ["KERAS_BACKEND"] = "tensorflow"

import numpy as np
import tensorflow as tf
import keras
from keras import ops
from keras import layers

from keras.layers import Input, LSTM, Dense, Lambda, RepeatVector, Reshape
from keras.models import Model
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError

from keras.utils import FeatureSpace, plot_model

# Import libraries for Hypertuning
#import keras_tuner as kt
#from keras_tuner.tuners import RandomSearch, GridSearch, BayesianOptimization

#from my_func import *

# preprocessing modules
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, RepeatedKFold, cross_val_score, cross_validate, GroupKFold, GridSearchCV, RepeatedStratifiedKFold, cross_val_predict
from sklearn.experimental import enable_iterative_imputer  # noqa
from sklearn.impute import IterativeImputer

from sklearn.preprocessing import (LabelEncoder,
                                   StandardScaler,
                                   MinMaxScaler,
                                   OrdinalEncoder,
                                   RobustScaler,
                                   PowerTransformer,
                                   OneHotEncoder,
                                   QuantileTransformer,
                                   PolynomialFeatures,
                                   FunctionTransformer)

# metrics
import sklearn
#import skops.io as sio
from sklearn.metrics import (mean_squared_error,
                             root_mean_squared_error,
                             root_mean_squared_log_error,
                             r2_score,
                             mean_absolute_error,
                             mean_absolute_percentage_error,
                             classification_report,
                             confusion_matrix,
                             ConfusionMatrixDisplay,
                             multilabel_confusion_matrix,
                             accuracy_score,
                             roc_auc_score,
                             auc,
                             roc_curve,
                             log_loss,
                             make_scorer)
# modeling algos
from sklearn.linear_model import (LogisticRegression,
                                  Lasso,
                                  ridge_regression,
                                  LinearRegression,
                                  Ridge,
                                  RidgeCV,
                                  ElasticNet,
                                  BayesianRidge,
                                  HuberRegressor,
                                  TweedieRegressor,
                                  QuantileRegressor,
                                  ARDRegression,
                                  TheilSenRegressor,
                                  PoissonRegressor,
                                  GammaRegressor)

from sklearn.ensemble import (AdaBoostRegressor,
                              AdaBoostClassifier,
                              RandomForestRegressor,
                              RandomForestClassifier,
                              VotingRegressor,
                              GradientBoostingRegressor,
                              GradientBoostingClassifier,
                              StackingRegressor,
                              StackingClassifier,
                              HistGradientBoostingClassifier,
                              HistGradientBoostingRegressor,
                              ExtraTreesClassifier)

from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.base import clone
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from category_encoders import TargetEncoder, CatBoostEncoder, LeaveOneOutEncoder, OrdinalEncoder, CountEncoder

from yellowbrick.cluster import KElbowVisualizer

import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
# %matplotlib inline

from sklearn.linear_model import LinearRegression
import numpy as np
import seaborn as sns
from statsmodels.tsa.deterministic import CalendarFourier, DeterministicProcess

from sklearn.multioutput import RegressorChain

import itertools
import warnings
from openpyxl import load_workbook

from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor

import statsmodels.api as sm
from pylab import rcParams
import scipy.stats as ss

#from category_encoders.cat_boost import CatBoostEncoder
#from category_encoders.wrapper import PolynomialWrapper
#from category_encoders.count import CountEncoder
#from category_encoders import TargetEncoder

import skops.io as sio

warnings.filterwarnings('ignore')
#import pyfiglet
#plt.style.use('fivethirtyeight')

# %% [markdown]
# **Formatting and Settings:**

# %%
sns.set({"axes.facecolor"       : "#ffffff",
         "figure.facecolor"     : "#ffffff",
         "axes.edgecolor"       : "#000000",
         "grid.color"           : "#ffffff",
         "font.family"          : ['Cambria'],
         "axes.labelcolor"      : "#000000",
         "xtick.color"          : "#000000",
         "ytick.color"          : "#000000",
         "grid.linewidth"       : 0.5,
         'grid.alpha'           :0.5,
         "grid.linestyle"       : "--",
         "axes.titlecolor"      : 'black',
         'axes.titlesize'       : 12,
#         'axes.labelweight'     : "bold",
         'legend.fontsize'      : 7.0,
         'legend.title_fontsize': 7.0,
         'font.size'            : 7.5,
         'xtick.labelsize'      : 7.5,
         'ytick.labelsize'      : 7.5,
        });

sns.set_style("whitegrid",{"grid.linestyle":"--", 'grid.linewidth':0.2, 'grid.alpha':0.5})
# Set Style
mpl.rcParams['figure.dpi'] = 120;

# import font colors
from colorama import Fore, Style, init

# Making sklearn pipeline outputs as dataframe:-
pd.set_option('display.max_columns', 100);
pd.set_option('display.max_rows', 50);

sns.despine(left=True, bottom=True, top=False, right=False)

mpl.rcParams['axes.spines.left'] = True
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.bottom'] = True

init(autoreset=True)

# %%
from tqdm import tqdm
from itertools import product

import numpy as np
import pandas as pd
import gc
import matplotlib.pyplot as plt
import seaborn as sns

from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor

from sklearn.model_selection import GroupKFold
from sklearn.impute import SimpleImputer
import torch

import warnings
warnings.filterwarnings("ignore")

# Connect to Colab:#
from google.colab import drive
import os
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 0.2 Functions:

# %% [markdown]
# * **Plotting Functiss**

# %%
def plot_scatter(df, x="feat1", y="feat2", color_feature=None, cmap='viridis'):
    """
    Generates a scatter plot with points colored based on a third feature.

    Args:
        df: Pandas DataFrame containing the data.
        x: Name of the column to use for the x-axis.
        y: Name of the column to use for the y-axis.
        color_feature: Name of the column to use for coloring the points.
                       If None, points will be a single color.
        cmap: Colormap to use for coloring the points (e.g., 'viridis', 'plasma', 'magma', 'inferno', 'cividis').
              See matplotlib documentation for available colormaps.
    """

    plt.figure(figsize=(8, 5))

    if color_feature is not None:
        # Ensure the color feature exists
        if color_feature not in df.columns:
            raise ValueError(f"Color feature '{color_feature}' not found in DataFrame.")

        # Scatter plot with colors
        scatter = plt.scatter(df[x], df[y], c=df[color_feature], cmap=cmap)

        # Add a colorbar
        cbar = plt.colorbar(scatter)
        cbar.set_label(color_feature)  # Label the colorbar

    else:
        # Simple scatter plot (single color)
        plt.scatter(df[x], df[y],color="royalblue",alpha=0.6)

    plt.xlabel(x)
    plt.ylabel(y)
    plt.title("Scatter Plot")  # Add a title for better visualization
    plt.show()

# %% [markdown]
# * **Dataset Management Functions**:

# %%
class Config:

    state = 42
    n_splits = 10
    early_stop = 200

    target = 'Calories'
    train = pd.read_csv('/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/train.csv')
    test = pd.read_csv('/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/test.csv')
    submission = pd.read_csv( "/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/sample_submission.csv")
    #train_org = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/original.csv")

    original_data = 'N'
    outliers = 'N'
    log_trf = 'Y'
    scaler_trf = 'Y'
    feature_eng = 'N'
    missing = 'Y'
    sqrt_normalization="Y"
    impose_normalization="N"
    trg_enc = "N"
    problem = "Regression"
    metric_goal="LRMSE"
    direction_="minimize"
    log_trans_cols = ["Body_Temp"]
    sqrt_norm_cols = ["Age"]
    impose_norm_cols = []
    trg_enc_feat = []

class Preprocessing():

    def __init__(self):
        self.train = Config.train
        self.test = Config.test
        self.targets = Config.target

        self.prp_data()

    def prp_data(self):

        if Config.original_data == 'Y':
            self.train = pd.concat([self.train, Config.train_org], ignore_index=True).drop_duplicates(ignore_index=True)

        self.train = self.train.drop(['id'], axis=1)
        self.test = self.test.drop(['id'], axis=1)

        self.cat_features = self.train.drop(self.targets, axis=1).select_dtypes(include=['object', 'bool']).columns.tolist()
        self.num_features = self.train.drop(self.targets, axis=1).select_dtypes(exclude=['object', 'bool']).columns.tolist()

        self.train = self.reduce_mem(self.train)
        self.test = self.reduce_mem(self.test)
        return self

    def reduce_mem(self, df):

        numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64', "uint16", "uint32", "uint64"]

        for col in df.columns:
            col_type = df[col].dtypes

            if col_type in numerics:
                c_min = df[col].min()
                c_max = df[col].max()

                if "int" in str(col_type):
                    if c_min >= np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                        df[col] = df[col].astype(np.int32)
                    elif c_min >= np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                        df[col] = df[col].astype(np.int32)
                    elif c_min >= np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                        df[col] = df[col].astype(np.int32)
                    elif c_min >= np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                        df[col] = df[col].astype(np.int64)
                else:
                    if c_min >= np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                        df[col] = df[col].astype(np.float32)
                    if c_min >= np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                        df[col] = df[col].astype(np.float32)
                    else:
                        df[col] = df[col].astype(np.float64)

        return df

class EDA(Config, Preprocessing):

    def __init__(self):
        super().__init__()

        self.data_info()
        self.heatmap()
        self.dist_plots()
        self.cat_feature_plots()
        if Config.problem == 'Classification':
          self.target_pie()
        else:
          self.target_dist()

    def data_info(self):

        for data, label in zip([self.train, self.test], ['Train', 'Test']):
            table_style = [{'selector': 'th:not(.index_name)',
                            'props': [('background-color', 'slategrey'),
                                      ('color', '#FFFFFF'),
                                      ('font-weight', 'bold'),
                                      ('border', '1px solid #DCDCDC'),
                                      ('text-align', 'center')]
                            },
                            {'selector': 'tbody td',
                             'props': [('border', '1px solid #DCDCDC'),
                                       ('font-weight', 'normal')]
                            }]
            print(Style.BRIGHT+Fore.RED+f'\n{label} head\n')
            display(data.head().style.set_table_styles(table_style))

            print(Style.BRIGHT+Fore.RED+f'\n{label} info\n'+Style.RESET_ALL)
            display(data.info())

            print(Style.BRIGHT+Fore.RED+f'\n{label} describe\n')
            display(data.describe().drop(index='count', columns=self.targets, errors = 'ignore').T
                    .style.set_table_styles(table_style).format('{:.3f}'))

            print(Style.BRIGHT+Fore.RED+f'\n{label} missing values\n'+Style.RESET_ALL)
            display(data.isnull().sum())
        return self

    def heatmap(self):
        print(Style.BRIGHT+Fore.RED+f'\nCorrelation Heatmap\n')
        plt.figure(figsize=(7,7))
        corr = self.train.select_dtypes(exclude='object').corr(method='pearson')
        sns.heatmap(corr, fmt = '0.2f', cmap = 'Blues', annot=True, cbar=False)
        plt.show()

    def dist_plots(self):

        print(Style.BRIGHT+Fore.RED+f"\nDistribution analysis - Numerical\n")
        df = pd.concat([self.train[self.num_features].assign(Source = 'Train'),
                        self.test[self.num_features].assign(Source = 'Test'),],
                        axis=0, ignore_index = True)

        fig, axes = plt.subplots(len(self.num_features), 2 ,figsize = (13, len(self.num_features) * 4),
                                 gridspec_kw = {'hspace': 0.3,
                                                'wspace': 0.2,
                                                'width_ratios': [0.70, 0.30]
                                               }
                                )
        for i,col in enumerate(self.num_features):
            try:
                ax = axes[i,0]
            except:
                ax = axes[i]
            sns.kdeplot(data = df[[col, 'Source']], x = col, hue = 'Source',
                        palette = ['royalblue', 'tomato'], ax = ax, alpha=0.7, linewidth = 2
                       )
            ax.set(xlabel = '', ylabel = '')
            ax.set_title(f"\n{col}")
            ax.grid('--',alpha=0.7)

            try:
                ax = axes[i,1]
            except:
                ax = axes[1]
            sns.boxplot(data = df, y = col, x=df.Source, width = 0.5,
                        linewidth = 1, fliersize= 1,
                        ax = ax, palette=['royalblue', 'tomato']
                       )
            ax.set_title(f"\n{col}")
            ax.set(xlabel = '', ylabel = '')
            ax.tick_params(axis='both', which='major')
            ax.set_xticklabels(['Train', 'Test'])

        plt.tight_layout()
        plt.show()

    def cat_feature_plots(self):
        print(Style.BRIGHT+Fore.RED+f"\nDistribution analysis - Categorical\n")
        fig, axes = plt.subplots(len(self.cat_features), 2 ,figsize = (18, len(self.cat_features) * 6),
                                 gridspec_kw = {'hspace': 0.5,
                                                'wspace': 0.2,
                                               }
                                )

        for i, col in enumerate(self.cat_features):
            try:
                ax = axes[i,0]
            except:
                ax = axes[i]
            sns.barplot(data=self.train[col].value_counts().nlargest(10).reset_index(), x=col, y='count', ax=ax, color='royalblue', alpha=0.7)
            ax.set(xlabel = '', ylabel = '')
            ax.set_title(f"\n{col} Train")

            try:
                ax = axes[i,1]
            except:
                ax = axes[i+1]
            sns.barplot(data=self.test[col].value_counts().nlargest(10).reset_index(), x=col, y='count', ax=ax, color='tomato', alpha=0.7)
            ax.set(xlabel = '', ylabel = '')
            ax.set_title(f"\n{col} Test")

        plt.tight_layout()
        plt.show()

    def target_pie(self):
        print(Style.BRIGHT+Fore.RED+f"\nTarget feature distribution\n")
        targets = self.train[self.targets]
        plt.figure(figsize=(6, 6))
        plt.pie(targets.value_counts(), labels=targets.value_counts().index, autopct='%1.2f%%', colors=palette_9)
        plt.show()

    def target_dist(self):
        print(Style.BRIGHT+Fore.RED+f"\nTarget feature distribution\n")
        fig, axes = plt.subplots(1, 1, figsize=(7, 5))
        sns.histplot(self.train[self.targets], kde=True, ax=axes)
        axes.set_title('Distribution of Price')
        axes.set_xlabel(self.targets)
        axes.set_ylabel('Frequency')

# %% [markdown]
# # 1.0 EDA

# %% [markdown]
# ## 1.1 Experiment Area:

# %%
class CFG:
    SEED    = 333
    CV      = KFold(n_splits=15, shuffle=True, random_state=SEED)
    VERSION = '1'

class Data:
    path       = False
    or_path    = ''
    to_drop    = False
    target     = 'Calories'
    drop_duplicates = False

    def __init__(self):
        self.train      = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/df_train_01.csv",index_col=0).drop(columns=self.to_drop) if self.to_drop else pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/df_train_01.csv",index_col=0)
        self.test       = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/df_test_01.csv",index_col=0).drop(columns=self.to_drop) if self.to_drop else pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/df_test_01.csv",index_col=0)
        self.submission = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/sample_submission.csv",index_col=0)
        self.original   = pd.read_csv(self.or_path) if self.or_path else pd.DataFrame()

    @property
    def X(self):
        return self.train.drop(columns=self.target)
    @property
    def y(self):
        return np.log(self.train[[self.target]])
    @property
    def X_test(self):
        return self.test
    @property
    def X_original(self):
        if len(self.original) != 0:
            return self.original.drop(columns=self.target)
        return pd.DataFrame()
    @property
    def y_original(self):
        if len(self.original) != 0:
            return self.original[[self.target]]
        return pd.DataFrame()
    @property
    def cat_features(self):
        return self.X.select_dtypes(include=['category', 'bool', 'category','int']).columns.to_list()
    @property
    def num_features(self):
        return self.X.select_dtypes(exclude=['category', 'bool', 'category','int']).columns.to_list()

    def submit(self, sub: np.ndarray, desc: str):
        '''Submit the predictions in the adequate format'''
        self.submission[self.target] = sub
        self.submission.to_csv(f'SUB_{CFG.VERSION}_{desc}.csv', index=False)
        print(colored('Submission has been made.', color='green', attrs=['bold', 'dark']))

    @staticmethod
    def sep_line():
        print(colored(f'{"_____"*14}', color='black'))
        print('')
    @staticmethod
    def head(head_text):
        print(colored(f'{"    "} ➩ {head_text} ', color='green', attrs=['dark']))

    def display_data(self):
        self.head(f'𝐃𝐚𝐭𝐚𝐬𝐞𝐭 𝐬𝐡𝐚𝐩𝐞𝐬 — 𝐓𝐫𝐚𝐢𝐧 | 𝐓𝐞𝐬𝐭: {self.train.shape} | {self.test.shape}')
        self.sep_line()

        self.head('𝐓𝐫𝐚𝐢𝐧 𝐡𝐞𝐚𝐝')
        display(self.train.head(5))
        self.head('𝐓𝐞𝐬𝐭 𝐡𝐞𝐚𝐝')
        display(self.test.head(5))
        self.sep_line()

        self.head('𝐓𝐫𝐚𝐢𝐧 𝐢𝐧𝐟𝐨')
        display(self.train.info())
        self.head('𝐓𝐞𝐬𝐭 𝐢𝐧𝐟𝐨')
        display(self.test.info())
        self.sep_line()

        self.head('𝐓𝐫𝐚𝐢𝐧 𝐬𝐮𝐦𝐦𝐚𝐫𝐲 𝐬𝐭𝐚𝐭𝐬')
        display(self.train.describe().T)
        self.head('𝐓𝐞𝐬𝐭 𝐬𝐮𝐦𝐦𝐚𝐫𝐲 𝐬𝐭𝐚𝐭𝐬')
        display(self.test.describe().T)
        self.sep_line()

        def nunique_null(train, test):
            nunique_train, nunique_test = {}, {}
            nulls_train, nulls_test = {}, {}

            for col in test.columns:
                nunique_train[col], nunique_test[col] = train[col].nunique(), test[col].nunique()
                nulls_train[col], nulls_test[col] = train[col].isna().sum(), test[col].isna().sum()

            df = pd.DataFrame([nunique_train, nunique_test,
                               nulls_train, nulls_test],
                              index=['Train nunique', 'Test nunique',
                                     'Train null', 'Test null'])
            return df

        self.head('𝐍𝐮𝐧𝐢𝐪𝐮𝐞 𝐚𝐧𝐝 𝐧𝐮𝐥𝐥𝐬')
        display(nunique_null(self.train, self.test))
        self.sep_line()

        self.head('𝐃𝐮𝐩𝐥𝐢𝐜𝐚𝐭𝐞𝐬')
        display(f'Train duplicated: {self.train.duplicated().sum()}')
        display(f'Test duplicated: {self.test.duplicated().sum()}')

        if self.drop_duplicates==True:
          if self.train.duplicated().sum() > 0:
              self.train = self.train.drop_duplicates()
              print('Train duplicates dropped.')
          if self.test.duplicated().sum() > 0:
              #self.test = self.test.drop_duplicates()
              print('Test duplicates dropped.')
        self.sep_line()

        self.head('𝐍𝐮𝐧𝐢𝐪𝐮𝐞 𝐢𝐧 𝐭𝐫𝐚𝐢𝐧 𝐧𝐨𝐭 𝐢𝐧 𝐭𝐞𝐬𝐭/𝐢𝐧 𝐭𝐞𝐬𝐭 𝐧𝐨𝐭 𝐢𝐧 𝐭𝐫𝐚𝐢𝐧')
        cat_cols = [c for c in self.test.columns if self.train[c].nunique() <= 40 or
                    c in self.test.select_dtypes(include=['object', 'category']).columns]

        def compare_unique_categories(train, test, cat_cols):
            unique_train_dic, unique_test_dic = {}, {}

            for c in cat_cols:
                unique_train_c = train[c].unique()
                unique_test_c = test[c].unique()

                count_tr = sum(1 for cat in unique_train_c if cat not in unique_test_c and not pd.isna(cat))
                count_te = sum(1 for cat in unique_test_c if (cat not in unique_train_c and not pd.isna(cat)))

                unique_train_dic[c] = count_tr
                unique_test_dic[c] = count_te

            result_df = pd.DataFrame([unique_train_dic, unique_test_dic],
                                     index=['in train not in test', 'in test not in train'])

            return result_df

        display(compare_unique_categories(self.train, self.test, cat_cols))

data = Data()
data.display_data()
# Out:
#      ➩ 𝐃𝐚𝐭𝐚𝐬𝐞𝐭 𝐬𝐡𝐚𝐩𝐞𝐬 — 𝐓𝐫𝐚𝐢𝐧 | 𝐓𝐞𝐬𝐭: (765000, 13) | (250000, 12)
# ______________________________________________________________________
#
#      ➩ 𝐓𝐫𝐚𝐢𝐧 𝐡𝐞𝐚𝐝
#    Sex    Height    Weight  Heart_Rate  Body_Temp       BMI  Intensity  \
# 0    1  1.113015  0.489702    0.583480   1.236062 -0.938031   1.183180
# 1    0 -0.909676 -1.081265   -1.109199  -0.430898 -1.184666  -0.923712
# 2    0 -1.065268 -0.795635   -1.214992  -0.302671  0.209075  -1.017567
# 3    1  1.346402  1.060962    1.006650   0.851379  0.026339   1.161541
# 4    0 -0.676289 -1.009858    0.689273   0.723151 -1.479569   1.075158
#
#    Heart_Duration  Weight_Duration_Heart  Outliers_Duration_Heart_Temp  \
# 0       -0.952799               1.338352                             0
# 1        0.431582              -1.004625                             0
# 2        0.610071              -1.047153                             0
# 3       -0.852901               1.619162                             0
# 4       -0.890178               0.535818                             0
#
#     BMI_Age  Age_Group  Calories
# 0  0.899410          3     150.0
# 1 -0.783423          6      34.0
# 2 -0.920441          5      29.0
# 3  0.610264          1     140.0
# 4  0.794743          3     146.0
#      ➩ 𝐓𝐞𝐬𝐭 𝐡𝐞𝐚𝐝
#         Sex    Height    Weight  Heart_Rate  Body_Temp       BMI  Intensity  \
# 750000    1  0.179465  0.418294   -0.897614  -0.302671  0.978939  -0.995739
# 750001    1  1.968769  1.560816    0.583480   0.594924 -0.082149   0.507888
# 750002    0  1.035219  0.703924    0.689273   0.466696 -0.214836   0.093216
# 750003    0 -0.209514 -0.152967    1.218235   0.723151  0.199218   0.640408
# 750004    0 -0.131718 -0.581412   -0.157067   0.594924 -1.314534  -0.037914
#
#         Heart_Duration  Weight_Duration_Heart  Outliers_Duration_Heart_Temp  \
# 750000        0.661858              -0.890129                             0
# 750001       -0.611173               1.078027                             0
# 750002       -0.294981               0.309886                             0
# 750003       -0.533902               0.544812                             0
# 750004       -0.407071              -0.199594                             0
#
#          BMI_Age  Age_Group
# 750000 -0.910919          4
# 750001  0.200535          2
# 750002 -0.106216          2
# 750003  0.579460          3
# 750004 -0.269589          2
# ______________________________________________________________________
#
#      ➩ 𝐓𝐫𝐚𝐢𝐧 𝐢𝐧𝐟𝐨
# <class 'pandas.core.frame.DataFrame'>
# Index: 765000 entries, 0 to 1014999
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Sex                           765000 non-null  int64
#  1   Height                        765000 non-null  float64
#  2   Weight                        765000 non-null  float64
#  3   Heart_Rate                    765000 non-null  float64
#  4   Body_Temp                     765000 non-null  float64
#  5   BMI                           765000 non-null  float64
#  6   Intensity                     765000 non-null  float64
#  7   Heart_Duration                765000 non-null  float64
#  8   Weight_Duration_Heart         765000 non-null  float64
#  9   Outliers_Duration_Heart_Temp  765000 non-null  int64
#  10  BMI_Age                       765000 non-null  float64
#  11  Age_Group                     765000 non-null  int64
#  12  Calories                      765000 non-null  float64
# dtypes: float64(10), int64(3)
# memory usage: 81.7 MB
# None
#      ➩ 𝐓𝐞𝐬𝐭 𝐢𝐧𝐟𝐨
# <class 'pandas.core.frame.DataFrame'>
# Index: 250000 entries, 750000 to 999999
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Sex                           250000 non-null  int64
#  1   Height                        250000 non-null  float64
#  2   Weight                        250000 non-null  float64
#  3   Heart_Rate                    250000 non-null  float64
#  4   Body_Temp                     250000 non-null  float64
#  5   BMI                           250000 non-null  float64
#  6   Intensity                     250000 non-null  float64
#  7   Heart_Duration                250000 non-null  float64
#  8   Weight_Duration_Heart         250000 non-null  float64
#  9   Outliers_Duration_Heart_Temp  250000 non-null  int64
#  10  BMI_Age                       250000 non-null  float64
#  11  Age_Group                     250000 non-null  int64
# dtypes: float64(9), int64(3)
# memory usage: 24.8 MB
# None
# ______________________________________________________________________
#
#      ➩ 𝐓𝐫𝐚𝐢𝐧 𝐬𝐮𝐦𝐦𝐚𝐫𝐲 𝐬𝐭𝐚𝐭𝐬
#                                  count          mean        std       min  \
# Sex                           765000.0  4.989882e-01   0.499999  0.000000
# Height                        765000.0  5.077641e-16   1.000001 -4.021508
# Weight                        765000.0  1.343297e-16   1.000001 -2.795048
# Heart_Rate                    765000.0  6.856041e-16   1.000001 -3.013464
# Body_Temp                     765000.0  1.793228e-14   1.000001 -3.764820
# BMI                           765000.0 -3.013472e-15   1.000001 -7.934021
# Intensity                     765000.0  3.098059e-17   1.000001 -1.563858
# Heart_Duration                765000.0  1.517255e-15   1.000001 -1.390121
# Weight_Duration_Heart         765000.0  1.852636e-16   1.000001 -1.507367
# Outliers_Duration_Heart_Temp  765000.0  3.921569e-05   0.006262  0.000000
# BMI_Age                       765000.0  1.750443e-16   1.000001 -1.511686
# Age_Group                     765000.0  3.623880e+00   1.541745  1.000000
# Calories                      765000.0  8.830742e+01  62.396760  1.000000
#
#                                     25%        50%         75%         max
# Sex                            0.000000   0.000000    1.000000    1.000000
# Height                        -0.831880  -0.053922    0.801832    3.680276
# Weight                        -0.867043  -0.081559    0.846740    4.060081
# Heart_Rate                    -0.791822  -0.051275    0.795065    3.439877
# Body_Temp                     -0.559126   0.338468    0.851379    1.877201
# BMI                           -0.740093   0.011128    0.736294   14.593902
# Intensity                     -0.875844  -0.105610    0.840522    2.483148
# Heart_Duration                -0.757049  -0.333324    0.443798    4.005130
# Weight_Duration_Heart         -0.837452  -0.131506    0.702951    4.344034
# Outliers_Duration_Heart_Temp   0.000000   0.000000    0.000000    1.000000
# BMI_Age                       -0.850150  -0.126144    0.736107    4.030577
# Age_Group                      2.000000   3.000000    5.000000    7.000000
# Calories                      34.000000  77.000000  136.000000  314.000000
#      ➩ 𝐓𝐞𝐬𝐭 𝐬𝐮𝐦𝐦𝐚𝐫𝐲 𝐬𝐭𝐚𝐭𝐬
#                                  count      mean       std       min  \
# Sex                           250000.0  0.498876  0.500000  0.000000
# Height                        250000.0  0.002528  0.997501 -3.710325
# Weight                        250000.0  0.000396  0.998243 -2.580825
# Heart_Rate                    250000.0 -0.000591  0.999756 -3.013464
# Body_Temp                     250000.0  0.000066  0.998186 -3.764820
# BMI                           250000.0 -0.004298  0.999673 -6.959004
# Intensity                     250000.0 -0.000928  0.999746 -1.563333
# Heart_Duration                250000.0 -0.000380  0.997461 -1.312222
# Weight_Duration_Heart         250000.0 -0.000767  0.999786 -1.505219
# Outliers_Duration_Heart_Temp  250000.0  0.000028  0.005291  0.000000
# BMI_Age                       250000.0 -0.001029  0.999830 -1.508818
# Age_Group                     250000.0  3.623832  1.538621  1.000000
#
#                                    25%       50%       75%        max
# Sex                           0.000000  0.000000  1.000000   1.000000
# Height                       -0.831880 -0.053922  0.801832   3.446889
# Weight                       -0.867043 -0.081559  0.846740   3.631636
# Heart_Rate                   -0.791822 -0.051275  0.795065   3.439877
# Body_Temp                    -0.559126  0.338468  0.723151   1.877201
# BMI                          -0.740093  0.008131  0.728037  13.467574
# Intensity                    -0.876596 -0.107700  0.834455   2.493177
# Heart_Duration               -0.757049 -0.326515  0.437294   3.835281
# Weight_Duration_Heart        -0.837925 -0.134480  0.699004   4.053276
# Outliers_Duration_Heart_Temp  0.000000  0.000000  0.000000   1.000000
# BMI_Age                      -0.850105 -0.127124  0.732317   3.487105
# Age_Group                     2.000000  3.000000  5.000000   7.000000
# ______________________________________________________________________
#
#      ➩ 𝐍𝐮𝐧𝐢𝐪𝐮𝐞 𝐚𝐧𝐝 𝐧𝐮𝐥𝐥𝐬
#                Sex  Height  Weight  Heart_Rate  Body_Temp   BMI  Intensity  \
# Train nunique    2      92      92          63         75  2261      11378
# Test nunique     2      85      84          61         51  1838       9097
# Train null       0       0       0           0          0     0          0
# Test null        0       0       0           0          0     0          0
#
#                Heart_Duration  Weight_Duration_Heart  \
# Train nunique            1102                  21630
# Test nunique              973                  19010
# Train null                  0                      0
# Test null                   0                      0
#
#                Outliers_Duration_Heart_Temp  BMI_Age  Age_Group
# Train nunique                             2   755720          7
# Test nunique                              2   248943          7
# Train null                                0        0          0
# Test null                                 0        0          0
# ______________________________________________________________________
#
#      ➩ 𝐃𝐮𝐩𝐥𝐢𝐜𝐚𝐭𝐞𝐬
# 'Train duplicated: 2893'
# 'Test duplicated: 918'
# ______________________________________________________________________
#
#      ➩ 𝐍𝐮𝐧𝐢𝐪𝐮𝐞 𝐢𝐧 𝐭𝐫𝐚𝐢𝐧 𝐧𝐨𝐭 𝐢𝐧 𝐭𝐞𝐬𝐭/𝐢𝐧 𝐭𝐞𝐬𝐭 𝐧𝐨𝐭 𝐢𝐧 𝐭𝐫𝐚𝐢𝐧
#                       Sex  Outliers_Duration_Heart_Temp  Age_Group
# in train not in test    0                             0          0
# in test not in train    0                             0          0

# %%
data.X.shape, data.y.shape, data.X_test.shape
# Out:
# ((765000, 12), (765000, 1), (250000, 12))

# %%
print(data.cat_features)
# Out:
# ['Sex', 'Outliers_Duration_Heart_Temp', 'Age_Group']

# %%
plot_scatter(pd.concat([data.X,data.y],axis=1), x="BMI_Age", y="Intensity", color_feature="Calories")

# %%
data.X.info(),data.X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 765000 entries, 0 to 1014999
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Sex                           765000 non-null  int64
#  1   Height                        765000 non-null  float64
#  2   Weight                        765000 non-null  float64
#  3   Heart_Rate                    765000 non-null  float64
#  4   Body_Temp                     765000 non-null  float64
#  5   BMI                           765000 non-null  float64
#  6   Intensity                     765000 non-null  float64
#  7   Heart_Duration                765000 non-null  float64
#  8   Weight_Duration_Heart         765000 non-null  float64
#  9   Outliers_Duration_Heart_Temp  765000 non-null  int64
#  10  BMI_Age                       765000 non-null  float64
#  11  Age_Group                     765000 non-null  int64
# dtypes: float64(9), int64(3)
# memory usage: 75.9 MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 250000 entries, 750000 to 999999
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Sex                           250000 non-null  int64
#  1   Height                        250000 non-null  float64
#  2   Weight                        250000 non-null  float64
#  3   Heart_Rate                    250000 non-null  float64
#  4   Body_Temp                     250000 non-null  float64
#  5   BMI                           250000 non-null  float64
#  6   Intensity                     250000 non-null  float64
#  7   Heart_Duration                250000 non-null  float64
#  8   Weight_Duration_Heart         250000 non-null  float64
#  9   Outliers_Duration_Heart_Temp  250000 non-null  int64
#  10  BMI_Age                       250000 non-null  float64
#  11  Age_Group                     250000 non-null  int64
# dtypes: float64(9), int64(3)
# memory usage: 24.8 MB
# (None, None)

# %% [markdown]
# # 4. Modeling
# ### 4.1 Stacking

# %%
class TrainModels:
    def __init__(self, X, y, X_test, X_original, y_original, models):
        self.models     = models
        self.X          = X
        self.y          = y
        self.X_original = X_original
        self.y_original = y_original
        self.X_test     = X_test
        self._OOF_train = pd.DataFrame()
        self._OOF_test  = pd.DataFrame()
        self.categorical_features = X.select_dtypes(include=['category', 'bool', 'category','int']).columns.to_list()

    @staticmethod
    def convert_cat(df_):
        '''
        A function to convert dtypes to categorical if the catboost with all categorical
        features is called
        '''
        df = df_.copy()
        for c in df.columns.to_list():
            df[c] = df[c].astype(str).astype('category')
        return df


    def fit_model(self, name, model_, train_flag):
        oof_train = np.zeros(self.X.shape[0])
        oof_test  = np.zeros(self.X_test.shape[0])
        scores_train = []
        scores_val   = []

        CB_CAT_FLAG = True if 'CB_CAT' in name.upper() else False

        os.chdir('/content/drive/MyDrive/Exercises/Studies_Structured_Data/Models/S5E5/layers_3_staked_models')

        for fold, (train_idx, val_idx) in enumerate(CFG.CV.split(self.X, self.y)):
            x_train, y_train = self.X.iloc[train_idx], self.y.iloc[train_idx]
            x_val,   y_val   = self.X.iloc[val_idx],   self.y.iloc[val_idx]

            # Adds the original data to training set only
            if self.X_original is not None:
                x_train = pd.concat([x_train, self.X_original], axis=0)
                y_train = pd.concat([y_train, self.y_original], axis=0)

            # -- Create a special block to convert all features to categorical
            if CB_CAT_FLAG:
                x_train = self.convert_cat(x_train)
                x_val   = self.convert_cat(x_val)

            model = clone(model_)

            if 'CB' in name.upper():
              if train_flag==True:
                model.fit(x_train,y_train,eval_set=[(x_val,y_val)], early_stopping_rounds=101)
                model.save_model(f"{name}_{fold}.bin")
              else:
                print("Load Model")
                model = CatBoostRegressor()
                model.load_model(f"{name}_{fold}.bin")

            elif 'LGBMR' in name.upper():
              early_stop = early_stopping(stopping_rounds=101)
              if train_flag==True:
                model.fit(x_train, y_train, eval_set=[(x_val, y_val)], callbacks=[early_stop],categorical_feature=self.categorical_features)
                model.booster_.save_model(f'{name}_{fold}.txt')
              else:
                print("Load Model")
                model = lgb.Booster(model_file=f'{name}_{fold}.txt')

            elif 'LGBMP' in name.upper():
              # Fit the model
              if train_flag==True:
                model.fit(x_train, y_train)
                joblib.dump(model, f'{name}_{fold}.pkl')
              else:
                print("Load Model")
                model = joblib.load(f'{name}_{fold}.pkl')

            elif 'XGBR' in name.upper():
              if train_flag==True:
                model.fit(x_train, y_train, eval_set=[(x_val, y_val)],verbose=250)
                model.save_model(f'{name}_{fold}.json')
              else:
                print("Load Model")
                model = XGBRegressor()  # Create an instance of the model
                model.load_model(f'{name}_{fold}.json')

            elif 'LGBM_2' in name.upper():
              model.fit(x_train, y_train, eval_set=[(x_val, y_val)])


            elif 'HGB_' in name.upper():
              if train_flag==True:
                model.fit(x_train, y_train)
                joblib.dump(model, f'{name}_{fold}.pkl')
              else:
                print("Load Model")
                model = joblib.load(f'{name}_{fold}.pkl')

            else:

              model.fit(x_train, y_train)

            y_pred_train = model.predict(x_train).ravel()
            y_pred_val   = model.predict(x_val).ravel()
            y_pred_test  = model.predict(self.X_test if not CB_CAT_FLAG else self.convert_cat(self.X_test)).ravel()

            oof_train[val_idx] = y_pred_val
            oof_test   += y_pred_test/CFG.CV.get_n_splits()

            train_score = np.sqrt(mean_squared_error(y_train, y_pred_train))
            val_score   = np.sqrt(mean_squared_error(y_val, y_pred_val))

            print(f'Fold {fold+1} → Training set Score: {train_score:.5f} | Validation set Score: {val_score:.5f}')

            scores_train.append(train_score)
            scores_val.append(val_score)

        self._OOF_train[name] = oof_train
        self._OOF_test[name]  = oof_test

        os.chdir('/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5')

        print(colored(f'Overall → Training set Score: {np.mean(scores_train):.5f}±{np.std(scores_train):.7f} | Validation set Score: {np.mean(scores_val):.5f}±{np.std(scores_val):.7f}',
              color='green', attrs=['bold', 'dark']))

    def fit_models(self):
        for name, model in list(self.models.items()):
            print(colored(f'{" "*4} Fitting {name}', color='red', attrs=['dark', 'bold']))
            self.fit_model(name, model[0], model[1])
            print("")

    @property
    def OOF_train(self):
        return self._OOF_train
    @property
    def OOF_test(self):
        return self._OOF_test

    def save_predictions(self):
        self._OOF_train.to_csv('OOF_train_many_models.csv', index=False)
        self._OOF_test.to_csv('OOF_test_many_models.csv', index=False)

# %% [markdown]
# #### 4.1.1 First Level of Stacking
# We define a bunch of tree-based methods with many different hyperparameters configurations to aggregate diversity.

# %%
os.chdir('/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5')

# %%
lgbm_params_4 = {'max_depth': 8, 'learning_rate': 0.02, 'n_estimators': 1001, 'num_leaves': 40}
lgbm_params_5 = {'max_depth': 5, 'learning_rate': 0.055, 'n_estimators': 3000, 'num_leaves': 31}
lgbm_params_6 = {'max_depth': 9, 'learning_rate': 0.02, 'n_estimators': 2000, 'num_leaves': 31, "subsample":0.85, "colsample_bytree":0.85,
                 "reg_alpha":0.01, "reg_lambda":0.01, "boosting_type":"gbdt" }

cb_cat_params_4   = {'one_hot_max_size': 2, 'learning_rate': 0.055, 'grow_policy': 'Depthwise'}

models={
    'LGBMR1': [LGBMRegressor(verbose=-1, random_state=CFG.SEED, boosting_type='GBDT', device='gpu',n_estimators=3000),False],
    'LGBMR2': [LGBMRegressor(verbose=-1, random_state=CFG.SEED, boosting_type='dart', device='gpu',n_estimators=1001),False],
    'LGBMR3': [LGBMRegressor(verbose=-1, random_state=CFG.SEED, data_sample_strategy='GOSS', device='gpu',n_estimators=1001),False],
    'LGBMP4': [make_pipeline(CatBoostEncoder(), LGBMRegressor(verbose=-1, random_state=CFG.SEED, **lgbm_params_4, device='gpu', boosting_type='GBDT')),True],
    'LGBMR5': [LGBMRegressor(verbose=-1, random_state=CFG.SEED, **lgbm_params_5, device='gpu', boosting_type='GBDT'),False],
    'LGBMR6': [LGBMRegressor(verbose=-1, random_state=CFG.SEED, **lgbm_params_6, device='gpu'),False],

    'CB1'   :[CatBoostRegressor(verbose=0, random_state=CFG.SEED, cat_features=data.cat_features, loss_function='RMSE', task_type='GPU', iterations=3000),False],
    'CB2'   : [CatBoostRegressor(verbose=0, random_state=CFG.SEED, cat_features=data.cat_features, grow_policy='Depthwise', loss_function='RMSE', task_type='GPU', iterations=3000),False],
    'CB3'   : [CatBoostRegressor(verbose=0, random_state=CFG.SEED, cat_features=data.cat_features, grow_policy='Lossguide', loss_function='RMSE', task_type='GPU', iterations=3000),False],
    'CB4'   : [CatBoostRegressor(verbose=0, random_state=CFG.SEED, cat_features=data.cat_features, **cb_cat_params_4, loss_function='RMSE', task_type='GPU', iterations=3000),False],
    'CB5'   : [CatBoostRegressor(verbose=0, random_state=CFG.SEED, cat_features=data.cat_features, iterations=3000, task_type='GPU'),False],
 #   'CB_CAT1': [CatBoostRegressor(verbose=0, random_state=CFG.SEED, cat_features=data.test.columns.to_list(), iterations=750, task_type='GPU'),True],
    'CB_CAT2': [CatBoostRegressor(verbose=0, random_state=CFG.SEED, cat_features=data.test.columns.to_list(), **cb_cat_params_4, loss_function='RMSE', task_type='GPU'),False],

    'XGBR1' : [XGBRegressor(random_state=CFG.SEED, enable_categorical=True, device='gpu', early_stopping_rounds=101, tree_method= 'gpu_hist',n_estimators=2000,verbosity=0),False],
    'XGBR2' : [XGBRegressor(random_state=CFG.SEED, enable_categorical=True, max_depth=4, learning_rate=0.04, device='gpu', early_stopping_rounds=101,tree_method= 'gpu_hist',n_estimators=2000),False],


    'HGB_TE': [make_pipeline(TargetEncoder(), HistGradientBoostingRegressor(random_state=CFG.SEED, max_iter=5000,
                                                                           learning_rate=0.035, max_depth=8,validation_fraction=0.15,
                                                                           early_stopping=True, l2_regularization=0.03,
                                                                            )),True],

    'HGB_CE': [make_pipeline(CountEncoder(), HistGradientBoostingRegressor(random_state=CFG.SEED, max_iter=5000,
                                                                            learning_rate=0.055, max_depth=5,
                                                                            early_stopping=True,  validation_fraction=0.15
                                                                          )),True],


}

TM = TrainModels(X=data.X, y=data.y, X_test=data.X_test, X_original=None, y_original=None, models=models)
TM.fit_models()
# Out:
#      Fitting LGBMR1
# Load Model
# Fold 1 → Training set Score: 0.06365 | Validation set Score: 0.06670
# Load Model
# Fold 2 → Training set Score: 0.06363 | Validation set Score: 0.06836
# Load Model
# Fold 3 → Training set Score: 0.06245 | Validation set Score: 0.06947
# Load Model
# Fold 4 → Training set Score: 0.06226 | Validation set Score: 0.06632
# Load Model
# Fold 5 → Training set Score: 0.06264 | Validation set Score: 0.06941
# Load Model
# Fold 6 → Training set Score: 0.06316 | Validation set Score: 0.06925
# Load Model
# Fold 7 → Training set Score: 0.05931 | Validation set Score: 0.06640
# Load Model
# Fold 8 → Training set Score: 0.06172 | Validation set Score: 0.06866
# Load Model
# Fold 9 → Training set Score: 0.06183 | Validation set Score: 0.06659
# Load Model
# Fold 10 → Training set Score: 0.06200 | Validation set Score: 0.06536
# Load Model
# Fold 11 → Training set Score: 0.06348 | Validation set Score: 0.06770
# Load Model
# Fold 12 → Training set Score: 0.06332 | Validation set Score: 0.06717
# Load Model
# Fold 13 → Training set Score: 0.06225 | Validation set Score: 0.06732
# Load Model
# Fold 14 → Training set Score: 0.06012 | Validation set Score: 0.06747
# Load Model
# Fold 15 → Training set Score: 0.06281 | Validation set Score: 0.06716
# Overall → Training set Score: 0.06231±0.0011970 | Validation set Score: 0.06756±0.0012004
#
#      Fitting LGBMR2
# Load Model
# Fold 1 → Training set Score: 0.10051 | Validation set Score: 0.10053
# Load Model
# Fold 2 → Training set Score: 0.10046 | Validation set Score: 0.10222
# Load Model
# Fold 3 → Training set Score: 0.10037 | Validation set Score: 0.10263
# Load Model
# Fold 4 → Training set Score: 0.10051 | Validation set Score: 0.10021
# Load Model
# Fold 5 → Training set Score: 0.10050 | Validation set Score: 0.10262
# Load Model
# Fold 6 → Training set Score: 0.10042 | Validation set Score: 0.10271
# Load Model
# Fold 7 → Training set Score: 0.10052 | Validation set Score: 0.10127
# Load Model
# Fold 8 → Training set Score: 0.10046 | Validation set Score: 0.10240
# Load Model
# Fold 9 → Training set Score: 0.10053 | Validation set Score: 0.10053
# Load Model
# Fold 10 → Training set Score: 0.10056 | Validation set Score: 0.10001
# Load Model
# Fold 11 → Training set Score: 0.10050 | Validation set Score: 0.10138
# Load Model
# Fold 12 → Training set Score: 0.10050 | Validation set Score: 0.10140
# Load Model
# Fold 13 → Training set Score: 0.10048 | Validation set Score: 0.10125
# Load Model
# Fold 14 → Training set Score: 0.10047 | Validation set Score: 0.10189
# Load Model
# Fold 15 → Training set Score: 0.10048 | Validation set Score: 0.10138
# Overall → Training set Score: 0.10048±0.0000449 | Validation set Score: 0.10150±0.0008722
#
#      Fitting LGBMR3
# Load Model
# Fold 1 → Training set Score: 0.06173 | Validation set Score: 0.06653
# Load Model
# Fold 2 → Training set Score: 0.06126 | Validation set Score: 0.06826
# Load Model
# Fold 3 → Training set Score: 0.06265 | Validation set Score: 0.06917
# Load Model
# Fold 4 → Training set Score: 0.06334 | Validation set Score: 0.06607
# Load Model
# Fold 5 → Training set Score: 0.06280 | Validation set Score: 0.06917
# Load Model
# Fold 6 → Training set Score: 0.06141 | Validation set Score: 0.06934
# Load Model
# Fold 7 → Training set Score: 0.06130 | Validation set Score: 0.06679
# Load Model
# Fold 8 → Training set Score: 0.06278 | Validation set Score: 0.06844
# Load Model
# Fold 9 → Training set Score: 0.06273 | Validation set Score: 0.06618
# Load Model
# Fold 10 → Training set Score: 0.06164 | Validation set Score: 0.06521
# Load Model
# Fold 11 → Training set Score: 0.06419 | Validation set Score: 0.06804
# Load Model
# Fold 12 → Training set Score: 0.06317 | Validation set Score: 0.06709
# Load Model
# Fold 13 → Training set Score: 0.06163 | Validation set Score: 0.06732
# Load Model
# Fold 14 → Training set Score: 0.06146 | Validation set Score: 0.06749
# Load Model
# Fold 15 → Training set Score: 0.06439 | Validation set Score: 0.06728
# Overall → Training set Score: 0.06243±0.0010025 | Validation set Score: 0.06749±0.0011945
#
#      Fitting LGBMP4
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 1 → Training set Score: 0.06570 | Validation set Score: 0.06668
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 2 → Training set Score: 0.06558 | Validation set Score: 0.06852
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 3 → Training set Score: 0.06546 | Validation set Score: 0.06959
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 4 → Training set Score: 0.06565 | Validation set Score: 0.06618
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 5 → Training set Score: 0.06550 | Validation set Score: 0.06948
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 6 → Training set Score: 0.06551 | Validation set Score: 0.06985
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 7 → Training set Score: 0.06566 | Validation set Score: 0.06763
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 8 → Training set Score: 0.06551 | Validation set Score: 0.06900
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 9 → Training set Score: 0.06570 | Validation set Score: 0.06648
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 10 → Training set Score: 0.06570 | Validation set Score: 0.06561
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 11 → Training set Score: 0.06562 | Validation set Score: 0.06754
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 12 → Training set Score: 0.06566 | Validation set Score: 0.06707
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 13 → Training set Score: 0.06568 | Validation set Score: 0.06750
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 14 → Training set Score: 0.06558 | Validation set Score: 0.06826
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 15 → Training set Score: 0.06565 | Validation set Score: 0.06715
# Overall → Training set Score: 0.06561±0.0000791 | Validation set Score: 0.06777±0.0012624
#
#      Fitting LGBMR5
# Load Model
# Fold 1 → Training set Score: 0.06335 | Validation set Score: 0.06632
# Load Model
# Fold 2 → Training set Score: 0.06406 | Validation set Score: 0.06823
# Load Model
# Fold 3 → Training set Score: 0.06313 | Validation set Score: 0.06890
# Load Model
# Fold 4 → Training set Score: 0.06394 | Validation set Score: 0.06587
# Load Model
# Fold 5 → Training set Score: 0.06427 | Validation set Score: 0.06892
# Load Model
# Fold 6 → Training set Score: 0.06311 | Validation set Score: 0.06920
# Load Model
# Fold 7 → Training set Score: 0.06250 | Validation set Score: 0.06642
# Load Model
# Fold 8 → Training set Score: 0.06356 | Validation set Score: 0.06829
# Load Model
# Fold 9 → Training set Score: 0.06343 | Validation set Score: 0.06613
# Load Model
# Fold 10 → Training set Score: 0.06377 | Validation set Score: 0.06524
# Load Model
# Fold 11 → Training set Score: 0.06506 | Validation set Score: 0.06758
# Load Model
# Fold 12 → Training set Score: 0.06435 | Validation set Score: 0.06658
# Load Model
# Fold 13 → Training set Score: 0.06358 | Validation set Score: 0.06680
# Load Model
# Fold 14 → Training set Score: 0.06298 | Validation set Score: 0.06765
# Load Model
# Fold 15 → Training set Score: 0.06464 | Validation set Score: 0.06688
# Overall → Training set Score: 0.06372±0.0006604 | Validation set Score: 0.06727±0.0011878
#
#      Fitting LGBMR6
# Load Model
# Fold 1 → Training set Score: 0.06422 | Validation set Score: 0.06650
# Load Model
# Fold 2 → Training set Score: 0.06426 | Validation set Score: 0.06806
# Load Model
# Fold 3 → Training set Score: 0.06403 | Validation set Score: 0.06921
# Load Model
# Fold 4 → Training set Score: 0.06427 | Validation set Score: 0.06582
# Load Model
# Fold 5 → Training set Score: 0.06408 | Validation set Score: 0.06911
# Load Model
# Fold 6 → Training set Score: 0.06412 | Validation set Score: 0.06939
# Load Model
# Fold 7 → Training set Score: 0.06424 | Validation set Score: 0.06715
# Load Model
# Fold 8 → Training set Score: 0.06411 | Validation set Score: 0.06852
# Load Model
# Fold 9 → Training set Score: 0.06451 | Validation set Score: 0.06622
# Load Model
# Fold 10 → Training set Score: 0.06426 | Validation set Score: 0.06524
# Load Model
# Fold 11 → Training set Score: 0.06448 | Validation set Score: 0.06728
# Load Model
# Fold 12 → Training set Score: 0.06423 | Validation set Score: 0.06670
# Load Model
# Fold 13 → Training set Score: 0.06415 | Validation set Score: 0.06730
# Load Model
# Fold 14 → Training set Score: 0.06414 | Validation set Score: 0.06759
# Load Model
# Fold 15 → Training set Score: 0.06431 | Validation set Score: 0.06680
# Overall → Training set Score: 0.06423±0.0001300 | Validation set Score: 0.06739±0.0012141
#
#      Fitting CB1
# Load Model
# Fold 1 → Training set Score: 0.06464 | Validation set Score: 0.06724
# Load Model
# Fold 2 → Training set Score: 0.06498 | Validation set Score: 0.06892
# Load Model
# Fold 3 → Training set Score: 0.06445 | Validation set Score: 0.06993
# Load Model
# Fold 4 → Training set Score: 0.06548 | Validation set Score: 0.06642
# Load Model
# Fold 5 → Training set Score: 0.06423 | Validation set Score: 0.06988
# Load Model
# Fold 6 → Training set Score: 0.06334 | Validation set Score: 0.06960
# Load Model
# Fold 7 → Training set Score: 0.06303 | Validation set Score: 0.06709
# Load Model
# Fold 8 → Training set Score: 0.06462 | Validation set Score: 0.06919
# Load Model
# Fold 9 → Training set Score: 0.06410 | Validation set Score: 0.06679
# Load Model
# Fold 10 → Training set Score: 0.06453 | Validation set Score: 0.06590
# Load Model
# Fold 11 → Training set Score: 0.06422 | Validation set Score: 0.06828
# Load Model
# Fold 12 → Training set Score: 0.06500 | Validation set Score: 0.06744
# Load Model
# Fold 13 → Training set Score: 0.06439 | Validation set Score: 0.06759
# Load Model
# Fold 14 → Training set Score: 0.06373 | Validation set Score: 0.06814
# Load Model
# Fold 15 → Training set Score: 0.06555 | Validation set Score: 0.06806
# Overall → Training set Score: 0.06442±0.0006791 | Validation set Score: 0.06803±0.0012226
#
#      Fitting CB2
# Load Model
# Fold 1 → Training set Score: 0.06375 | Validation set Score: 0.06774
# Load Model
# Fold 2 → Training set Score: 0.06447 | Validation set Score: 0.06927
# Load Model
# Fold 3 → Training set Score: 0.06320 | Validation set Score: 0.06981
# Load Model
# Fold 4 → Training set Score: 0.06307 | Validation set Score: 0.06626
# Load Model
# Fold 5 → Training set Score: 0.06395 | Validation set Score: 0.07008
# Load Model
# Fold 6 → Training set Score: 0.06349 | Validation set Score: 0.06931
# Load Model
# Fold 7 → Training set Score: 0.06139 | Validation set Score: 0.06744
# Load Model
# Fold 8 → Training set Score: 0.06150 | Validation set Score: 0.06903
# Load Model
# Fold 9 → Training set Score: 0.06356 | Validation set Score: 0.06698
# Load Model
# Fold 10 → Training set Score: 0.06294 | Validation set Score: 0.06579
# Load Model
# Fold 11 → Training set Score: 0.06490 | Validation set Score: 0.06853
# Load Model
# Fold 12 → Training set Score: 0.06363 | Validation set Score: 0.06743
# Load Model
# Fold 13 → Training set Score: 0.06409 | Validation set Score: 0.06822
# Load Model
# Fold 14 → Training set Score: 0.06232 | Validation set Score: 0.06834
# Load Model
# Fold 15 → Training set Score: 0.06192 | Validation set Score: 0.06776
# Overall → Training set Score: 0.06321±0.0010083 | Validation set Score: 0.06813±0.0012067
#
#      Fitting CB3
# Load Model
# Fold 1 → Training set Score: 0.06524 | Validation set Score: 0.06794
# Load Model
# Fold 2 → Training set Score: 0.06595 | Validation set Score: 0.06982
# Load Model
# Fold 3 → Training set Score: 0.06355 | Validation set Score: 0.07012
# Load Model
# Fold 4 → Training set Score: 0.06368 | Validation set Score: 0.06660
# Load Model
# Fold 5 → Training set Score: 0.06435 | Validation set Score: 0.07033
# Load Model
# Fold 6 → Training set Score: 0.06304 | Validation set Score: 0.06972
# Load Model
# Fold 7 → Training set Score: 0.06276 | Validation set Score: 0.06755
# Load Model
# Fold 8 → Training set Score: 0.06305 | Validation set Score: 0.06959
# Load Model
# Fold 9 → Training set Score: 0.06214 | Validation set Score: 0.06691
# Load Model
# Fold 10 → Training set Score: 0.06241 | Validation set Score: 0.06640
# Load Model
# Fold 11 → Training set Score: 0.06403 | Validation set Score: 0.06897
# Load Model
# Fold 12 → Training set Score: 0.06418 | Validation set Score: 0.06770
# Load Model
# Fold 13 → Training set Score: 0.06429 | Validation set Score: 0.06819
# Load Model
# Fold 14 → Training set Score: 0.06387 | Validation set Score: 0.06865
# Load Model
# Fold 15 → Training set Score: 0.06379 | Validation set Score: 0.06786
# Overall → Training set Score: 0.06375±0.0009797 | Validation set Score: 0.06842±0.0012503
#
#      Fitting CB4
# Load Model
# Fold 1 → Training set Score: 0.06303 | Validation set Score: 0.06734
# Load Model
# Fold 2 → Training set Score: 0.06364 | Validation set Score: 0.06935
# Load Model
# Fold 3 → Training set Score: 0.06290 | Validation set Score: 0.06972
# Load Model
# Fold 4 → Training set Score: 0.06360 | Validation set Score: 0.06598
# Load Model
# Fold 5 → Training set Score: 0.06386 | Validation set Score: 0.06992
# Load Model
# Fold 6 → Training set Score: 0.06121 | Validation set Score: 0.06912
# Load Model
# Fold 7 → Training set Score: 0.06101 | Validation set Score: 0.06703
# Load Model
# Fold 8 → Training set Score: 0.06302 | Validation set Score: 0.06933
# Load Model
# Fold 9 → Training set Score: 0.06344 | Validation set Score: 0.06674
# Load Model
# Fold 10 → Training set Score: 0.06153 | Validation set Score: 0.06571
# Load Model
# Fold 11 → Training set Score: 0.06364 | Validation set Score: 0.06806
# Load Model
# Fold 12 → Training set Score: 0.06401 | Validation set Score: 0.06739
# Load Model
# Fold 13 → Training set Score: 0.06377 | Validation set Score: 0.06769
# Load Model
# Fold 14 → Training set Score: 0.06133 | Validation set Score: 0.06814
# Load Model
# Fold 15 → Training set Score: 0.06316 | Validation set Score: 0.06774
# Overall → Training set Score: 0.06288±0.0010226 | Validation set Score: 0.06795±0.0012731
#
#      Fitting CB5
# Load Model
# Fold 1 → Training set Score: 0.06464 | Validation set Score: 0.06724
# Load Model
# Fold 2 → Training set Score: 0.06498 | Validation set Score: 0.06892
# Load Model
# Fold 3 → Training set Score: 0.06445 | Validation set Score: 0.06993
# Load Model
# Fold 4 → Training set Score: 0.06414 | Validation set Score: 0.06618
# Load Model
# Fold 5 → Training set Score: 0.06363 | Validation set Score: 0.06976
# Load Model
# Fold 6 → Training set Score: 0.06390 | Validation set Score: 0.06962
# Load Model
# Fold 7 → Training set Score: 0.06311 | Validation set Score: 0.06710
# Load Model
# Fold 8 → Training set Score: 0.06433 | Validation set Score: 0.06882
# Load Model
# Fold 9 → Training set Score: 0.06372 | Validation set Score: 0.06676
# Load Model
# Fold 10 → Training set Score: 0.06449 | Validation set Score: 0.06592
# Load Model
# Fold 11 → Training set Score: 0.06481 | Validation set Score: 0.06827
# Load Model
# Fold 12 → Training set Score: 0.06496 | Validation set Score: 0.06737
# Load Model
# Fold 13 → Training set Score: 0.06542 | Validation set Score: 0.06775
# Load Model
# Fold 14 → Training set Score: 0.06372 | Validation set Score: 0.06805
# Load Model
# Fold 15 → Training set Score: 0.06480 | Validation set Score: 0.06797
# Overall → Training set Score: 0.06434±0.0006081 | Validation set Score: 0.06798±0.0012129
#
#      Fitting CB_CAT2
# Load Model
# Fold 1 → Training set Score: 0.10924 | Validation set Score: 0.11039
# Load Model
# Fold 2 → Training set Score: 0.10830 | Validation set Score: 0.11181
# Load Model
# Fold 3 → Training set Score: 0.10947 | Validation set Score: 0.11317
# Load Model
# Fold 4 → Training set Score: 0.10879 | Validation set Score: 0.11092
# Load Model
# Fold 5 → Training set Score: 0.10961 | Validation set Score: 0.11388
# Load Model
# Fold 6 → Training set Score: 0.10827 | Validation set Score: 0.11176
# Load Model
# Fold 7 → Training set Score: 0.10942 | Validation set Score: 0.11195
# Load Model
# Fold 8 → Training set Score: 0.11057 | Validation set Score: 0.11234
# Load Model
# Fold 9 → Training set Score: 0.10906 | Validation set Score: 0.10931
# Load Model
# Fold 10 → Training set Score: 0.10820 | Validation set Score: 0.10971
# Load Model
# Fold 11 → Training set Score: 0.10869 | Validation set Score: 0.10908
# Load Model
# Fold 12 → Training set Score: 0.10934 | Validation set Score: 0.10891
# Load Model
# Fold 13 → Training set Score: 0.10858 | Validation set Score: 0.11068
# Load Model
# Fold 14 → Training set Score: 0.11027 | Validation set Score: 0.11274
# Load Model
# Fold 15 → Training set Score: 0.10936 | Validation set Score: 0.10949
# Overall → Training set Score: 0.10914±0.0006740 | Validation set Score: 0.11107±0.0015331
#
#      Fitting XGBR1
# Load Model
# Fold 1 → Training set Score: 0.06062 | Validation set Score: 0.06762
# Load Model
# Fold 2 → Training set Score: 0.05881 | Validation set Score: 0.07050
# Load Model
# Fold 3 → Training set Score: 0.06071 | Validation set Score: 0.07027
# Load Model
# Fold 4 → Training set Score: 0.06045 | Validation set Score: 0.06685
# Load Model
# Fold 5 → Training set Score: 0.06245 | Validation set Score: 0.07052
# Load Model
# Fold 6 → Training set Score: 0.06028 | Validation set Score: 0.06953
# Load Model
# Fold 7 → Training set Score: 0.05969 | Validation set Score: 0.06800
# Load Model
# Fold 8 → Training set Score: 0.05981 | Validation set Score: 0.07034
# Load Model
# Fold 9 → Training set Score: 0.06107 | Validation set Score: 0.06750
# Load Model
# Fold 10 → Training set Score: 0.06012 | Validation set Score: 0.06708
# Load Model
# Fold 11 → Training set Score: 0.06124 | Validation set Score: 0.06835
# Load Model
# Fold 12 → Training set Score: 0.06142 | Validation set Score: 0.06822
# Load Model
# Fold 13 → Training set Score: 0.06189 | Validation set Score: 0.06913
# Load Model
# Fold 14 → Training set Score: 0.06066 | Validation set Score: 0.06862
# Load Model
# Fold 15 → Training set Score: 0.06012 | Validation set Score: 0.06847
# Overall → Training set Score: 0.06062±0.0008808 | Validation set Score: 0.06873±0.0012148
#
#      Fitting XGBR2
# Load Model
# Fold 1 → Training set Score: 0.06510 | Validation set Score: 0.06727
# Load Model
# Fold 2 → Training set Score: 0.06495 | Validation set Score: 0.06866
# Load Model
# Fold 3 → Training set Score: 0.06478 | Validation set Score: 0.06928
# Load Model
# Fold 4 → Training set Score: 0.06504 | Validation set Score: 0.06557
# Load Model
# Fold 5 → Training set Score: 0.06489 | Validation set Score: 0.06917
# Load Model
# Fold 6 → Training set Score: 0.06488 | Validation set Score: 0.06938
# Load Model
# Fold 7 → Training set Score: 0.06488 | Validation set Score: 0.06705
# Load Model
# Fold 8 → Training set Score: 0.06487 | Validation set Score: 0.06848
# Load Model
# Fold 9 → Training set Score: 0.06496 | Validation set Score: 0.06630
# Load Model
# Fold 10 → Training set Score: 0.06504 | Validation set Score: 0.06598
# Load Model
# Fold 11 → Training set Score: 0.06494 | Validation set Score: 0.06765
# Load Model
# Fold 12 → Training set Score: 0.06494 | Validation set Score: 0.06657
# Load Model
# Fold 13 → Training set Score: 0.06494 | Validation set Score: 0.06700
# Load Model
# Fold 14 → Training set Score: 0.06492 | Validation set Score: 0.06814
# Load Model
# Fold 15 → Training set Score: 0.06504 | Validation set Score: 0.06723
# Overall → Training set Score: 0.06495±0.0000799 | Validation set Score: 0.06758±0.0011853
#
#      Fitting HGB_TE
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 1 → Training set Score: 0.06549 | Validation set Score: 0.06684
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 2 → Training set Score: 0.06538 | Validation set Score: 0.06812
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 3 → Training set Score: 0.06586 | Validation set Score: 0.06976
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 4 → Training set Score: 0.06612 | Validation set Score: 0.06641
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 5 → Training set Score: 0.06504 | Validation set Score: 0.06932
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 6 → Training set Score: 0.06557 | Validation set Score: 0.06943
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 7 → Training set Score: 0.06565 | Validation set Score: 0.06784
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 8 → Training set Score: 0.06507 | Validation set Score: 0.06881
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 9 → Training set Score: 0.06600 | Validation set Score: 0.06652
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 10 → Training set Score: 0.06579 | Validation set Score: 0.06579
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 11 → Training set Score: 0.06573 | Validation set Score: 0.06804
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 12 → Training set Score: 0.06602 | Validation set Score: 0.06711
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 13 → Training set Score: 0.06539 | Validation set Score: 0.06748
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 14 → Training set Score: 0.06583 | Validation set Score: 0.06842
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 15 → Training set Score: 0.06520 | Validation set Score: 0.06693
# Overall → Training set Score: 0.06561±0.0003305 | Validation set Score: 0.06779±0.0011626
#
#      Fitting HGB_CE
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 1 → Training set Score: 0.06599 | Validation set Score: 0.06714
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 2 → Training set Score: 0.06648 | Validation set Score: 0.06863
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 3 → Training set Score: 0.06661 | Validation set Score: 0.06985
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 4 → Training set Score: 0.06568 | Validation set Score: 0.06626
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 5 → Training set Score: 0.06645 | Validation set Score: 0.06974
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 6 → Training set Score: 0.06547 | Validation set Score: 0.06949
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 7 → Training set Score: 0.06568 | Validation set Score: 0.06768
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 8 → Training set Score: 0.06513 | Validation set Score: 0.06869
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 9 → Training set Score: 0.06546 | Validation set Score: 0.06646
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 10 → Training set Score: 0.06570 | Validation set Score: 0.06587
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 11 → Training set Score: 0.06544 | Validation set Score: 0.06811
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 12 → Training set Score: 0.06604 | Validation set Score: 0.06694
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 13 → Training set Score: 0.06552 | Validation set Score: 0.06747
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 14 → Training set Score: 0.06627 | Validation set Score: 0.06876
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 15 → Training set Score: 0.06547 | Validation set Score: 0.06712
# Overall → Training set Score: 0.06583±0.0004380 | Validation set Score: 0.06788±0.0012339

# %% [markdown]
# #### 4.1.2 Second Level of Stacking
# We take the out-of-folds predictions from the previous models and fed them into simple linear methods like Ridge and Lasso. The alpha parameters have been tuned manually (i.e., trial and error).

# %%
models2 = {
    'Ridge2': [Ridge(alpha=1),True],
    'Lasso2': [Lasso(alpha=0.0002),True],
    'LGBM_2' : [LGBMRegressor(max_depth=2, random_state=CFG.SEED, verbose=-1, device='gpu', n_estimators=250),True],
}

TM2 = TrainModels(X=TM.OOF_train, y=data.y, X_test=TM.OOF_test, X_original=None, y_original=None, models=models2)
TM2.fit_models()
# Out:
#      Fitting Ridge2
# Fold 1 → Training set Score: 0.06667 | Validation set Score: 0.06583
# Fold 2 → Training set Score: 0.06654 | Validation set Score: 0.06770
# Fold 3 → Training set Score: 0.06649 | Validation set Score: 0.06839
# Fold 4 → Training set Score: 0.06674 | Validation set Score: 0.06491
# Fold 5 → Training set Score: 0.06649 | Validation set Score: 0.06840
# Fold 6 → Training set Score: 0.06650 | Validation set Score: 0.06825
# Fold 7 → Training set Score: 0.06667 | Validation set Score: 0.06590
# Fold 8 → Training set Score: 0.06654 | Validation set Score: 0.06769
# Fold 9 → Training set Score: 0.06670 | Validation set Score: 0.06548
# Fold 10 → Training set Score: 0.06676 | Validation set Score: 0.06458
# Fold 11 → Training set Score: 0.06661 | Validation set Score: 0.06672
# Fold 12 → Training set Score: 0.06665 | Validation set Score: 0.06611
# Fold 13 → Training set Score: 0.06664 | Validation set Score: 0.06635
# Fold 14 → Training set Score: 0.06661 | Validation set Score: 0.06674
# Fold 15 → Training set Score: 0.06663 | Validation set Score: 0.06636
# Overall → Training set Score: 0.06661±0.0000848 | Validation set Score: 0.06663±0.0011897
#
#      Fitting Lasso2
# Fold 1 → Training set Score: 0.06734 | Validation set Score: 0.06641
# Fold 2 → Training set Score: 0.06721 | Validation set Score: 0.06811
# Fold 3 → Training set Score: 0.06714 | Validation set Score: 0.06919
# Fold 4 → Training set Score: 0.06737 | Validation set Score: 0.06595
# Fold 5 → Training set Score: 0.06714 | Validation set Score: 0.06915
# Fold 6 → Training set Score: 0.06716 | Validation set Score: 0.06902
# Fold 7 → Training set Score: 0.06735 | Validation set Score: 0.06619
# Fold 8 → Training set Score: 0.06719 | Validation set Score: 0.06838
# Fold 9 → Training set Score: 0.06735 | Validation set Score: 0.06624
# Fold 10 → Training set Score: 0.06743 | Validation set Score: 0.06507
# Fold 11 → Training set Score: 0.06727 | Validation set Score: 0.06734
# Fold 12 → Training set Score: 0.06730 | Validation set Score: 0.06688
# Fold 13 → Training set Score: 0.06729 | Validation set Score: 0.06701
# Fold 14 → Training set Score: 0.06728 | Validation set Score: 0.06719
# Fold 15 → Training set Score: 0.06730 | Validation set Score: 0.06687
# Overall → Training set Score: 0.06727±0.0000857 | Validation set Score: 0.06727±0.0012156
#
#      Fitting LGBM_2
# Fold 1 → Training set Score: 0.06930 | Validation set Score: 0.06913
# Fold 2 → Training set Score: 0.06913 | Validation set Score: 0.07041
# Fold 3 → Training set Score: 0.06910 | Validation set Score: 0.07092
# Fold 4 → Training set Score: 0.06935 | Validation set Score: 0.06799
# Fold 5 → Training set Score: 0.06920 | Validation set Score: 0.07152
# Fold 6 → Training set Score: 0.06905 | Validation set Score: 0.07144
# Fold 7 → Training set Score: 0.06927 | Validation set Score: 0.06887
# Fold 8 → Training set Score: 0.06923 | Validation set Score: 0.07119
# Fold 9 → Training set Score: 0.06934 | Validation set Score: 0.06823
# Fold 10 → Training set Score: 0.06941 | Validation set Score: 0.06777
# Fold 11 → Training set Score: 0.06907 | Validation set Score: 0.07004
# Fold 12 → Training set Score: 0.06924 | Validation set Score: 0.06881
# Fold 13 → Training set Score: 0.06920 | Validation set Score: 0.06890
# Fold 14 → Training set Score: 0.06910 | Validation set Score: 0.07008
# Fold 15 → Training set Score: 0.06923 | Validation set Score: 0.06930
# Overall → Training set Score: 0.06921±0.0001046 | Validation set Score: 0.06964±0.0012163

# %%
TM2.OOF_test.mean(axis=1)
# Out:
# 0         3.304890
# 1         4.681355
# 2         4.475593
# 3         4.843332
# 4         4.338348
#             ...
# 249995    3.270158
# 249996    2.248927
# 249997    4.279678
# 249998    5.127182
# 249999    4.343360
# Length: 250000, dtype: float64

# %%
df_sub = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/sample_submission.csv",index_col=0)
df_sub.head()
# Out:
#         Calories
# id
# 750000    88.283
# 750001    88.283
# 750002    88.283
# 750003    88.283
# 750004    88.283

# %%
plt.hist(x=TM2.OOF_test.mean(axis=1), bins=20)
plt.show()

# %%
df_subm_stack_level = df_sub.copy()
df_subm_stack_level["Calories"]=np.exp(TM2.OOF_test.mean(axis=1)).values
df_subm_stack_level.head()
# Out:
#           Calories
# id
# 750000   27.245556
# 750001  107.916204
# 750002   87.846661
# 750003  126.891403
# 750004   76.580958

# %%
plt.hist(x=df_subm_stack_level, bins=20)
plt.show()

# %%
oof_results_stack = TM2.OOF_train

# %%
oof_results_stack_level = np.exp(oof_results_stack.astype(float).mean(axis=1))

# %%
df_subm_stack_level.to_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/stacking_level_2_01.csv")
oof_results_stack_level.to_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/oof_stacking_level_2_01.csv")

# %%
plt.hist(x=df_subm_stack_level, bins=20)
plt.show()

# %% [markdown]
# #### 4.1.3 Third Level of Stacking
# At this stage, the first level and second level out-of-fold predictions are incorporated into the original training data. This is then fed into another level of models to output the final stage of out-of-fold predictions which are finally averaged.

# %%
#pd.concat([data.X.reset_index(drop=True),      TM.OOF_train.reset_index(drop=True), TM2.OOF_train.reset_index(drop=True)], axis=1)
# Out:
#         Sex    Height    Weight  Heart_Rate  Body_Temp       BMI  Intensity  \
# 0         1  1.113015  0.489702    0.583480   1.236062 -0.938031   1.183180
# 1         0 -0.909676 -1.081265   -1.109199  -0.430898 -1.184666  -0.923712
# 2         0 -1.065268 -0.795635   -1.214992  -0.302671  0.209075  -1.017567
# 3         1  1.346402  1.060962    1.006650   0.851379  0.026339   1.161541
# 4         0 -0.676289 -1.009858    0.689273   0.723151 -1.479569   1.075158
# ...     ...       ...       ...         ...        ...       ...        ...
# 764995    0  1.424198  0.775332   -0.368652   0.466696 -0.850623  -0.560972
# 764996    0 -0.754084 -0.724227   -1.109199  -1.072037 -0.330047  -1.106638
# 764997    0 -1.220859 -1.224081   -0.580237   0.082013 -0.946994  -0.120654
# 764998    1  1.424198  1.560816   -1.214992  -2.226087  1.102151  -1.460728
# 764999    1 -0.131718  0.275479   -0.368652   0.594924  1.336790   0.122865
#
#         Heart_Duration  Weight_Duration_Heart  Outliers_Duration_Heart_Temp  \
# 0            -0.952799               1.338352                             0
# 1             0.431582              -1.004625                             0
# 2             0.610071              -1.047153                             0
# 3            -0.852901               1.619162                             0
# 4            -0.890178               0.535818                             0
# ...                ...                    ...                           ...
# 764995        0.086193              -0.383991                             0
# 764996        0.856191              -1.107321                             0
# 764997       -0.466212              -0.431137                             0
# 764998        2.520034              -1.333575                             0
# 764999       -0.595126               0.203888                             0
#
#          BMI_Age  Age_Group    LGBMR1    LGBMR2    LGBMR3    LGBMP4    LGBMR5  \
# 0       0.899410          3  4.988858  4.893294  4.993734  4.999432  4.998988
# 1      -0.783423          6  3.595808  3.519749  3.594857  3.589121  3.586837
# 2      -0.920441          5  3.368434  3.308055  3.378464  3.363548  3.359587
# 3       0.610264          1  4.938059  4.852364  4.941858  4.928930  4.930230
# 4       0.794743          3  4.979697  4.893399  4.980460  4.981397  4.983377
# ...          ...        ...       ...       ...       ...       ...       ...
# 764995 -0.763220          1  3.811389  3.771386  3.811342  3.816488  3.791732
# 764996 -1.128295          2  3.159886  3.073417  3.150216  3.144805  3.136483
# 764997 -0.152274          4  4.319714  4.235952  4.313415  4.311534  4.319849
# 764998 -1.338740          7  2.279142  2.196075  2.279927  2.291227  2.278904
# 764999  0.517671          6  4.596067  4.514506  4.613297  4.589380  4.602278
#
#           LGBMR6       CB1       CB2       CB3       CB4       CB5   CB_CAT2  \
# 0       4.986314  4.988748  4.992637  5.003987  4.992233  4.989494  4.944664
# 1       3.577919  3.588838  3.585261  3.582000  3.595717  3.587885  3.586945
# 2       3.378553  3.342727  3.366954  3.339691  3.361360  3.343838  3.291928
# 3       4.931140  4.931576  4.932236  4.932510  4.924428  4.927410  4.919208
# 4       4.983203  4.988483  4.976497  4.970919  4.977401  4.987387  4.883451
# ...          ...       ...       ...       ...       ...       ...       ...
# 764995  3.813570  3.775666  3.805623  3.797295  3.772802  3.775968  3.850987
# 764996  3.129895  3.114819  3.099203  3.112496  3.107386  3.114526  3.109072
# 764997  4.317353  4.313090  4.293398  4.297593  4.303713  4.312085  4.292739
# 764998  2.284195  2.219194  2.240391  2.229262  2.264701  2.221806  2.491414
# 764999  4.600948  4.602064  4.596203  4.588385  4.610039  4.600087  4.570269
#
#            XGBR1     XGBR2    HGB_TE    HGB_CE    Ridge2    Lasso2    LGBM_2
# 0       4.986333  4.990296  4.994427  5.006954  4.987856  4.988058  4.999790
# 1       3.583465  3.561894  3.585047  3.577501  3.585606  3.594044  3.563786
# 2       3.364270  3.372107  3.367827  3.376737  3.366900  3.367435  3.340032
# 3       4.931746  4.929569  4.924085  4.922801  4.933673  4.937972  4.936519
# 4       4.976444  4.977590  4.981420  4.978540  4.981896  4.980238  5.002795
# ...          ...       ...       ...       ...       ...       ...       ...
# 764995  3.859438  3.803236  3.816129  3.815717  3.811336  3.813932  3.796842
# 764996  3.123218  3.155513  3.106365  3.108275  3.133583  3.154474  3.138082
# 764997  4.309221  4.307518  4.307529  4.309620  4.313042  4.318532  4.321366
# 764998  2.325469  2.268222  2.263906  2.243277  2.266982  2.272972  2.260419
# 764999  4.606150  4.590868  4.596094  4.591422  4.603789  4.596407  4.588145
#
# [765000 rows x 31 columns]

# %%
train = pd.concat([data.X.reset_index(drop=True),      TM.OOF_train.reset_index(drop=True), TM2.OOF_train.reset_index(drop=True)], axis=1)
test  = pd.concat([data.X_test.reset_index(drop=True), TM.OOF_test.reset_index(drop=True),  TM2.OOF_test.reset_index(drop=True)], axis=1)

models3 = {
    'LGBM_21' : [LGBMRegressor(verbose=-1, random_state=CFG.SEED, max_depth=4, device='gpu', n_estimators=501),True],
    'CB_3'   : [CatBoostRegressor(verbose=0, random_state=CFG.SEED, cat_features=data.cat_features, task_type='GPU',iterations=501),True],
    'Ridge_3': [make_pipeline(TargetEncoder(), Ridge(alpha=3)),True],
    'Lasso_3': [make_pipeline(TargetEncoder(), Lasso(alpha=0.001)),True],
}

TM3  = TrainModels(X=train, y=data.y.reset_index(drop=True), X_test=test, X_original=None, y_original=None, models=models3)
TM3.fit_models()

#TM3.save_predictions()
# Out:
#      Fitting LGBM_21
# Fold 1 → Training set Score: 0.06513 | Validation set Score: 0.06652
# Fold 2 → Training set Score: 0.06505 | Validation set Score: 0.06848
# Fold 3 → Training set Score: 0.06496 | Validation set Score: 0.06898
# Fold 4 → Training set Score: 0.06516 | Validation set Score: 0.06561
# Fold 5 → Training set Score: 0.06502 | Validation set Score: 0.06890
# Fold 6 → Training set Score: 0.06504 | Validation set Score: 0.06891
# Fold 7 → Training set Score: 0.06516 | Validation set Score: 0.06647
# Fold 8 → Training set Score: 0.06506 | Validation set Score: 0.06872
# Fold 9 → Training set Score: 0.06521 | Validation set Score: 0.06612
# Fold 10 → Training set Score: 0.06521 | Validation set Score: 0.06519
# Fold 11 → Training set Score: 0.06501 | Validation set Score: 0.06768
# Fold 12 → Training set Score: 0.06506 | Validation set Score: 0.06636
# Fold 13 → Training set Score: 0.06512 | Validation set Score: 0.06689
# Fold 14 → Training set Score: 0.06508 | Validation set Score: 0.06727
# Fold 15 → Training set Score: 0.06512 | Validation set Score: 0.06683
# Overall → Training set Score: 0.06509±0.0000717 | Validation set Score: 0.06726±0.0012316
#
#      Fitting CB_3
# Fold 1 → Training set Score: 0.06553 | Validation set Score: 0.06774
# Fold 2 → Training set Score: 0.06582 | Validation set Score: 0.06962
# Fold 3 → Training set Score: 0.06541 | Validation set Score: 0.07056
# Fold 4 → Training set Score: 0.06561 | Validation set Score: 0.06694
# Fold 5 → Training set Score: 0.06541 | Validation set Score: 0.07040
# Fold 6 → Training set Score: 0.06534 | Validation set Score: 0.07033
# Fold 7 → Training set Score: 0.06562 | Validation set Score: 0.06752
# Fold 8 → Training set Score: 0.06536 | Validation set Score: 0.06985
# Fold 9 → Training set Score: 0.06557 | Validation set Score: 0.06711
# Fold 10 → Training set Score: 0.06560 | Validation set Score: 0.06607
# Fold 11 → Training set Score: 0.06553 | Validation set Score: 0.06881
# Fold 12 → Training set Score: 0.06554 | Validation set Score: 0.06785
# Fold 13 → Training set Score: 0.06549 | Validation set Score: 0.06830
# Fold 14 → Training set Score: 0.06554 | Validation set Score: 0.06863
# Fold 15 → Training set Score: 0.06549 | Validation set Score: 0.06801
# Overall → Training set Score: 0.06552±0.0001158 | Validation set Score: 0.06852±0.0013405
#
#      Fitting Ridge_3
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 1 → Training set Score: 0.06659 | Validation set Score: 0.06593
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 2 → Training set Score: 0.06646 | Validation set Score: 0.06764
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 3 → Training set Score: 0.06641 | Validation set Score: 0.06844
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 4 → Training set Score: 0.06667 | Validation set Score: 0.06478
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 5 → Training set Score: 0.06642 | Validation set Score: 0.06826
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 6 → Training set Score: 0.06641 | Validation set Score: 0.06833
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 7 → Training set Score: 0.06659 | Validation set Score: 0.06589
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 8 → Training set Score: 0.06648 | Validation set Score: 0.06754
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 9 → Training set Score: 0.06662 | Validation set Score: 0.06541
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 10 → Training set Score: 0.06668 | Validation set Score: 0.06453
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 11 → Training set Score: 0.06653 | Validation set Score: 0.06672
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 12 → Training set Score: 0.06659 | Validation set Score: 0.06593
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 13 → Training set Score: 0.06656 | Validation set Score: 0.06629
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 14 → Training set Score: 0.06652 | Validation set Score: 0.06682
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 15 → Training set Score: 0.06658 | Validation set Score: 0.06613
# Overall → Training set Score: 0.06654±0.0000862 | Validation set Score: 0.06658±0.0012081
#
#      Fitting Lasso_3
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 1 → Training set Score: 0.06736 | Validation set Score: 0.06644
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 2 → Training set Score: 0.06723 | Validation set Score: 0.06813
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 3 → Training set Score: 0.06716 | Validation set Score: 0.06921
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 4 → Training set Score: 0.06740 | Validation set Score: 0.06599
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 5 → Training set Score: 0.06716 | Validation set Score: 0.06917
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 6 → Training set Score: 0.06718 | Validation set Score: 0.06903
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 7 → Training set Score: 0.06737 | Validation set Score: 0.06619
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 8 → Training set Score: 0.06721 | Validation set Score: 0.06840
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 9 → Training set Score: 0.06737 | Validation set Score: 0.06628
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 10 → Training set Score: 0.06745 | Validation set Score: 0.06510
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 11 → Training set Score: 0.06730 | Validation set Score: 0.06738
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 12 → Training set Score: 0.06732 | Validation set Score: 0.06689
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 13 → Training set Score: 0.06731 | Validation set Score: 0.06704
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 14 → Training set Score: 0.06731 | Validation set Score: 0.06720
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Fold 15 → Training set Score: 0.06733 | Validation set Score: 0.06688
# Overall → Training set Score: 0.06730±0.0000855 | Validation set Score: 0.06729±0.0012121

# %%
TM3.OOF_test.mean(axis=1).head()
# Out:
# 0    3.307108
# 1    4.680728
# 2    4.473514
# 3    4.844640
# 4    4.338924
# dtype: float64

# %%
df_sub = pd.read_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/sample_submission.csv",index_col=0)
df_sub.head()
# Out:
#         Calories
# id
# 750000    88.283
# 750001    88.283
# 750002    88.283
# 750003    88.283
# 750004    88.283

# %%
plt.hist(x=TM3.OOF_test.mean(axis=1), bins=20)
plt.show()

# %%
df_subm_stack_level = df_sub.copy()
df_subm_stack_level["Calories"]=np.exp(TM3.OOF_test.mean(axis=1)).values
df_subm_stack_level.head()
# Out:
#           Calories
# id
# 750000   27.306044
# 750001  107.848526
# 750002   87.664215
# 750003  127.057520
# 750004   76.625038

# %%
plt.hist(x=df_subm_stack_level, bins=20)
plt.show()

# %%
oof_results_stack = TM3.OOF_train

# %%
oof_results_stack_level = np.exp(oof_results_stack.astype(float).mean(axis=1))

# %%
df_subm_stack_level.to_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/stacking_level_3_02.csv")
oof_results_stack_level.to_csv("/content/drive/MyDrive/Exercises/Studies_Structured_Data/Data/S5E5/oof_stacking_level_3_02.csv")

# %%
plt.hist(x=df_subm_stack_level, bins=20)
plt.show()

# %%
TM3.OOF_test.mean(axis=1)
# Out:
# 0         3.307108
# 1         4.680728
# 2         4.473514
# 3         4.844640
# 4         4.338924
#             ...
# 249995    3.273099
# 249996    2.247443
# 249997    4.279500
# 249998    5.129623
# 249999    4.347137
# Length: 250000, dtype: float64
